# %%
#from wordcloud import STOPWORDS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## read in data from csv
realOrFake = pd.read_csv('fake_or_real_news.csv')
realOrFake.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
## dropped unnamed column- it is unique identifier/non-predictive
realOrFake.drop(realOrFake.columns[realOrFake.columns.str.contains('unnamed',case = False)], axis=1, inplace=True)
realOrFake.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
#convert label to int
d = {'FAKE': 1, 'REAL': 0}
# value of 1 indicates Partner = Yes
realOrFake['Fake'] = realOrFake['label'].map(d)
realOrFake.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label  Fake
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE     1
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE     1
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL     0
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE     1
# 4  It's primary day in New York and front-runners...  REAL     0

# %%
realOrFake.drop(['label'], axis=1, inplace=True)
realOrFake.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text  Fake
# 0  Daniel Greenfield, a Shillman Journalism Fello...     1
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...     1
# 2  U.S. Secretary of State John F. Kerry said Mon...     0
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...     1
# 4  It's primary day in New York and front-runners...     0

# %%
realOrFake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6335 entries, 0 to 6334
# Data columns (total 3 columns):
# title    6335 non-null object
# text     6335 non-null object
# Fake     6335 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 148.6+ KB

# %%
realOrFake.iloc[0]
# Out:
# title                         You Can Smell Hillary’s Fear
# text     Daniel Greenfield, a Shillman Journalism Fello...
# Fake                                                     1
# Name: 0, dtype: object

# %%
fake = realOrFake[(realOrFake['Fake']==1)]
fake.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 3  Bernie supporters on Twitter erupt in anger ag...
# 5                                        Tehran, USA
# 6  Girl Horrified At What She Watches Boyfriend D...
#
#                                                 text  Fake
# 0  Daniel Greenfield, a Shillman Journalism Fello...     1
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...     1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...     1
# 5    \nI’m not an immigrant, but my grandparents ...     1
# 6  Share This Baylee Luciani (left), Screenshot o...     1

# %%
real = realOrFake[(realOrFake['Fake']==0)]
real.head()
# Out:
#                                                title  \
# 2        Kerry to go to Paris in gesture of sympathy
# 4   The Battle of New York: Why This Primary Matters
# 7                  ‘Britain’s Schindler’ Dies at 106
# 8  Fact check: Trump and Clinton at the 'commande...
# 9  Iran reportedly makes new push for uranium con...
#
#                                                 text  Fake
# 2  U.S. Secretary of State John F. Kerry said Mon...     0
# 4  It's primary day in New York and front-runners...     0
# 7  A Czech stockbroker who saved more than 650 Je...     0
# 8  Hillary Clinton and Donald Trump made some ina...     0
# 9  Iranian negotiators reportedly have made a las...     0

# %%
fake.count()
# Out:
# title    3164
# text     3164
# Fake     3164
# dtype: int64

# %%
real.count()
# Out:
# title    3171
# text     3171
# Fake     3171
# dtype: int64

# %% [markdown]
# Note: fake and real samples are ~equal number of real and fake news articles so no need to balance the classes

# %% [markdown]
# ### Train Test Split

# %%
y = realOrFake['Fake']

# %%
X = realOrFake['text']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=53)

# %% [markdown]
# ### Model 1: Count vectorizer- Text only

# %%
from sklearn.feature_extraction.text import CountVectorizer

#ignore english stop words
cv = CountVectorizer(stop_words='english')

count_train = cv.fit_transform(X_train)

# %%
cv.vocabulary_
# Out:
# {'report': 42470,
#  'copyright': 12105,
#  'violation': 54177,
#  'think': 50628,
#  'doom': 15924,
#  'sayers': 44520,
#  'trump': 51896,
#  'office': 35783,
#  'notice': 35256,
#  'glp': 21881,
#  'republican': 42534,
#  'bush': 8399,
#  'left': 29531,
#  'doomsaying': 15927,
#  'increases': 25686,
#  'sure': 49203,
#  'effect': 16814,
#  'opposite': 36087,
#  'gets': 21568,
#  'increase': 25684,
#  'political': 38823,
#  'spectrum': 47506,
#  'page': 36831,
#  'election': 16972,
#  '232': 762,
#  'photos': 38140,
#  '43': 1127,
#  'numbers': 35403,
#  '131': 229,
#  'quotes': 40794,
#  'candidates': 8779,
#  'center': 9445,
#  'email': 17139,
#  'wonder': 55615,
#  'mind': 32729,
#  'today': 51050,
#  'notable': 35236,
#  'people': 37695,
#  'don': 15867,
#  'miss': 32983,
#  'unbelievable': 52435,
#  'roundup': 43680,
#  'best': 6494,
#  'talked': 49772,
#  'day': 13519,
#  'course': 12424,
#  'schindler': 44691,
#  'list': 30107,
#  'saddest': 44042,
#  'movies': 33689,
#  'time': 50906,
#  'going': 21981,
#  'brag': 7659,
#  'chance': 9616,
#  'liam': 29814,
#  'neeson': 34495,
#  'humility': 24774,
#  'microwave': 32543,
#  'like': 29953,
#  'whisper': 55162,
#  'sending': 45279,
#  'solitary': 47165,
#  'fun': 20927,
#  'little': 30164,
#  'joke': 27596,
#  'food': 20218,
#  'laugh': 29302,
#  'knowing': 28660,
#  'coming': 11055,
#  'soon': 47240,
#  'lorena': 30445,
#  'garcia': 21218,
#  'good': 22033,
#  'stuff': 48690,
#  'love': 30510,
#  'kyle': 28948,
#  'chandler': 9621,
#  'wells': 55013,
#  'fargo': 19068,
#  'rotting': 43658,
#  '139': 240,
#  'just': 27842,
#  'thought': 50690,
#  'surely': 49205,
#  'big': 6635,
#  'banker': 5675,
#  'greed': 22361,
#  'bottomed': 7531,
#  '2008': 634,
#  'wall': 54583,
#  'street': 48562,
#  'crash': 12570,
#  'bailout': 5520,
#  'comes': 11036,
#  'burrowing': 8379,
#  'deeper': 13846,
#  'ethical': 18067,
#  'slime': 46712,
#  'reach': 41311,
#  'previously': 39589,
#  'unimaginable': 52884,
#  'level': 29744,
#  'corporate': 12178,
#  'depravity': 14391,
#  'thing': 50625,
#  'finance': 19650,
#  'giants': 21629,
#  'cook': 12033,
#  'books': 7397,
#  'defraud': 13966,
#  'investors': 26736,
#  'executives': 18407,
#  'profiteering': 39826,
#  'years': 56100,
#  'literally': 30136,
#  'forcing': 20276,
#  'employees': 17311,
#  'rob': 43367,
#  'bank': 5672,
#  'customers': 13130,
#  'culture': 13020,
#  'service': 45415,
#  'pushed': 40471,
#  'high': 23968,
#  'pressure': 39524,
#  'sales': 44172,
#  '2009': 635,
#  'demanding': 14128,
#  'frontline': 20802,
#  'meet': 32093,
#  'extreme': 18722,
#  'quotas': 40790,
#  'selling': 45229,
#  'myriad': 34067,
#  'unnecessary': 53016,
#  'products': 39789,
#  'common': 11141,
#  'depositors': 14384,
#  'wanted': 54648,
#  'simple': 46335,
#  'checking': 9800,
#  'account': 2172,
#  'photo': 38126,
#  'shutterstock': 46136,
#  'expected': 18517,
#  'load': 30228,
#  'customer': 13129,
#  'accounts': 2179,
#  'monitored': 33346,
#  'constantly': 11735,
#  'meeting': 32094,
#  'quota': 40788,
#  'fail': 18892,
#  'fired': 19729,
#  'bosses': 7501,
#  'turned': 52108,
#  'syndicate': 49566,
#  'robbers': 43374,
#  'thievery': 50620,
#  'systemic': 49604,
#  'wasn': 54746,
#  'subtle': 48866,
#  'half': 22960,
#  'million': 32694,
#  'secretly': 45090,
#  'issued': 26997,
#  'credit': 12638,
#  'debit': 13636,
#  'cards': 8962,
#  'didn': 14871,
#  'request': 42560,
#  'fake': 18936,
#  'online': 35980,
#  'services': 45422,
#  'set': 45438,
#  'knowledge': 28663,
#  'money': 33327,
#  'moved': 33680,
#  'signatures': 46252,
#  'forged': 20355,
#  'collected': 10882,
#  'fees': 19325,
#  'bogus': 7259,
#  'transactions': 51456,
#  'boosting': 7426,
#  'profits': 39829,
#  'ceo': 9486,
#  'john': 27568,
#  'stumpf': 48702,
#  'recently': 41541,
#  'forced': 20268,
#  'scandal': 44567,
#  'board': 7184,
#  'directors': 15056,
#  'highly': 23980,
#  'paid': 36845,
#  'partners': 37249,
#  'crime': 12692,
#  'rotten': 43655,
#  'apple': 4093,
#  'isn': 26966,
#  'case': 9120,
#  'bankers': 5676,
#  'gone': 22019,
#  'rogue': 43462,
#  'head': 23468,
#  'donald': 15870,
#  'eased': 16618,
#  'fears': 19259,
#  'tuesday': 52020,
#  'night': 34863,
#  'declared': 13750,
#  'intention': 26409,
#  'stay': 48139,
#  'inside': 26214,
#  'party': 37256,
#  'angst': 3706,
#  'temporarily': 50221,
#  'prospect': 40045,
#  'loses': 30463,
#  'face': 18809,
#  'far': 19049,
#  'troubling': 51852,
#  'increasingly': 25688,
#  'plausible': 38539,
#  'question': 40701,
#  'happens': 23157,
#  'wins': 55447,
#  'standard': 47987,
#  'bearer': 6069,
#  'gop': 22069,
#  'suddenly': 48927,
#  'asked': 4630,
#  'rally': 41023,
#  'candidate': 8778,
#  'called': 8655,
#  'primary': 39633,
#  'foes': 20151,
#  'cancer': 8767,
#  'conservatism': 11673,
#  'unhinged': 52854,
#  'drunk': 16263,
#  'driver': 16201,
#  'helping': 23727,
#  'enemy': 17466,
#  'prominent': 39908,
#  'conservative': 11674,
#  'national': 34314,
#  'security': 45117,
#  'expert': 18561,
#  'max': 31758,
#  'boot': 7428,
#  'flatly': 19911,
#  'labeled': 28970,
#  'fascist': 19112,
#  'rhetoric': 43056,
#  'stronger': 48645,
#  'private': 39698,
#  'conversations': 11995,
#  've': 53792,
#  'republicans': 42536,
#  'moderate': 33169,
#  'stripes': 48620,
#  'usual': 53500,
#  'intraparty': 26630,
#  'battles': 5977,
#  'kind': 28455,
#  'resolved': 42674,
#  'handshakes': 23101,
#  'convention': 11982,
#  'banners': 5695,
#  'stake': 47941,
#  'ground': 22532,
#  'positions': 39053,
#  'strongly': 48649,
#  'suggesting': 48967,
#  'nomination': 35035,
#  'create': 12613,
#  'fissure': 19787,
#  'deep': 13841,
#  'indivisible': 25814,
#  'american': 3441,
#  'history': 24130,
#  'driven': 16200,
#  'ideology': 25074,
#  'questions': 40709,
#  'personal': 37882,
#  'character': 9667,
#  'operatives': 36048,
#  'right': 43172,
#  'running': 43875,
#  'run': 43867,
#  'threat': 50710,
#  'turn': 52104,
#  'leave': 29486,
#  'contributors': 11953,
#  'foot': 20235,
#  'soldiers': 47137,
#  'painful': 36850,
#  'choices': 10019,
#  'look': 30390,
#  'landscape': 29146,
#  'rules': 43847,
#  'insurgencies': 26353,
#  'suggests': 48971,
#  '2016': 649,
#  'year': 56091,
#  'offered': 35775,
#  'reasonable': 41430,
#  'win': 55388,
#  'white': 55176,
#  'house': 24590,
#  'total': 51247,
#  'control': 11958,
#  'apparatus': 4053,
#  'disaster': 15122,
#  'nominee': 35037,
#  'unity': 52934,
#  'fronts': 20810,
#  'victory': 54055,
#  'represent': 42489,
#  'triumph': 51787,
#  'insurgent': 26355,
#  'movement': 33681,
#  'impulse': 25499,
#  'historically': 24127,
#  'speaking': 47453,
#  'exactly': 18287,
#  'guarantees': 22620,
#  'civil': 10276,
#  'war': 54656,
#  'striking': 48610,
#  'examples': 18307,
#  'politics': 38836,
#  'come': 11024,
#  'broke': 8000,
#  'long': 30369,
#  'pattern': 37423,
#  'accommodating': 2144,
#  'different': 14895,
#  'factions': 18854,
#  'decisively': 13738,
#  'happened': 23154,
#  'democrats': 14172,
#  'twice': 52175,
#  'rights': 43186,
#  'embraced': 17196,
#  'cause': 9287,
#  'north': 35190,
#  'welcoming': 54997,
#  'segregationists': 45173,
#  'supremacists': 49188,
#  'south': 47342,
#  '1948': 528,
#  'embrace': 17195,
#  'plank': 38490,
#  'led': 29510,
#  'southern': 47348,
#  'delegations': 14036,
#  'walk': 54571,
#  'carolina': 9042,
#  'governor': 22146,
#  'strom': 48642,
#  'thurmond': 50798,
#  'states': 48084,
#  'democratic': 14163,
#  'dixiecrats': 15678,
#  'won': 55614,
#  'president': 39504,
#  'harry': 23284,
#  'truman': 51893,
#  'barely': 5762,
#  'defeated': 13875,
#  'tom': 51101,
#  'dewey': 14757,
#  'ohio': 35836,
#  'california': 8643,
#  'electoral': 16980,
#  'college': 10898,
#  'deadlocked': 13574,
#  'choice': 10017,
#  'thrown': 50755,
#  'representatives': 42493,
#  'holding': 24258,
#  'balance': 5552,
#  'power': 39174,
#  'later': 29272,
#  'alabama': 2999,
#  'george': 21497,
#  'wallace': 54585,
#  'similar': 46318,
#  'anti': 3864,
#  'relatively': 42171,
#  'small': 46805,
#  'shift': 45838,
#  'voters': 54393,
#  'cases': 9123,
#  'dramatic': 16114,
#  'significant': 46258,
#  'defections': 13887,
#  'losing': 30464,
#  '1964': 551,
#  'conservatives': 11678,
#  'succeeded': 48895,
#  'nominating': 35034,
#  'divisive': 15666,
#  'champion': 9606,
#  'barry': 5847,
#  'goldwater': 22007,
#  'liberal': 29825,
#  'things': 50627,
#  'new': 34699,
#  'york': 56196,
#  'nelson': 34558,
#  'rockefeller': 43412,
#  'michigan': 32514,
#  'romney': 43518,
#  'refused': 41948,
#  'endorse': 17439,
#  'shockingly': 45930,
#  'herald': 23777,
#  'tribune': 51710,
#  'semi': 45252,
#  'official': 35790,
#  'voice': 54324,
#  'establishment': 18018,
#  'endorsed': 17440,
#  'lyndon': 30744,
#  'johnson': 27579,
#  'democrat': 14162,
#  'supported': 49167,
#  'split': 47652,
#  'went': 55027,
#  'flames': 19870,
#  'deeply': 13850,
#  'divided': 15651,
#  'nominated': 35032,
#  'hero': 23827,
#  'mcgovern': 31893,
#  'meany': 31986,
#  'afl': 2710,
#  'cio': 10204,
#  'position': 39049,
#  'neutrality': 34682,
#  'richard': 43101,
#  'nixon': 34956,
#  'labor': 28976,
#  'texas': 50419,
#  'connally': 11607,
#  'openly': 36030,
#  'backed': 5386,
#  'countless': 12397,
#  'disempowered': 15253,
#  'emergence': 17210,
#  'simply': 46350,
#  'sat': 44409,
#  'hands': 23099,
#  'lost': 30467,
#  'landslide': 29151,
#  'example': 18306,
#  'yes': 56134,
#  'ideological': 25068,
#  'sense': 45300,
#  'radical': 40882,
#  'moving': 33690,
#  'officials': 35793,
#  'holders': 24257,
#  'alienated': 3136,
#  'media': 32031,
#  'tribunes': 51711,
#  'rush': 43893,
#  'limbaugh': 29987,
#  'sean': 45025,
#  'hannity': 23138,
#  'mark': 31433,
#  'levin': 29763,
#  'ann': 3739,
#  'coulter': 12327,
#  'laura': 29322,
#  'ingraham': 26050,
#  'vocal': 54307,
#  'defending': 13902,
#  'assailing': 4676,
#  'branded': 7701,
#  'unacceptable': 52357,
#  'undermine': 52612,
#  'thesis': 50584,
#  'influential': 25986,
#  'book': 7383,
#  'decides': 13714,
#  'argues': 4323,
#  'preferences': 39382,
#  'insiders': 26218,
#  'critical': 12745,
#  'outcome': 36393,
#  'contest': 11864,
#  'possibility': 39070,
#  'provoked': 40156,
#  'strong': 48643,
#  'feelings': 19317,
#  'old': 35872,
#  'school': 44735,
#  'says': 44523,
#  'self': 45215,
#  'described': 14487,
#  'structural': 48655,
#  'sycophantic': 49506,
#  'involved': 26764,
#  'levels': 29750,
#  'campaigns': 8724,
#  'decades': 13664,
#  'hillary': 24011,
#  'bad': 5441,
#  'country': 12400,
#  'worse': 55740,
#  'battle': 5969,
#  'influence': 25981,
#  'explains': 18576,
#  'defection': 13886,
#  'ranks': 41110,
#  'hold': 24254,
#  'particular': 37227,
#  'peril': 37773,
#  'arises': 4349,
#  'belief': 6267,
#  'chosen': 10059,
#  'unfit': 52789,
#  'temperament': 50204,
#  'occasion': 35669,
#  'politician': 38825,
#  'sacrificed': 44031,
#  'chances': 9618,
#  '1986': 576,
#  'senator': 45273,
#  'adlai': 2469,
#  'stevenson': 48286,
#  'iii': 25152,
#  'reason': 41429,
#  'believe': 6272,
#  'following': 20194,
#  'father': 19146,
#  'footsteps': 20256,
#  'illinois': 25182,
#  'mansion': 31282,
#  'earlier': 16580,
#  'race': 40832,
#  'fewer': 19482,
#  '000': 1,
#  'disputed': 15449,
#  'votes': 54394,
#  'easy': 16641,
#  'march': 31349,
#  'overshadowed': 36648,
#  'ballot': 5589,
#  'followers': 20192,
#  'larouche': 29227,
#  'cultish': 13008,
#  'conspiracy': 11722,
#  'minded': 32734,
#  'demagogue': 14122,
#  'nominations': 35036,
#  'lieutenant': 29895,
#  'secretary': 45087,
#  'state': 48072,
#  'horrified': 24507,
#  'placing': 38461,
#  'acolytes': 2263,
#  'bolted': 7311,
#  'line': 30029,
#  'instead': 26288,
#  'independent': 25742,
#  'sen': 45270,
#  'alan': 3007,
#  'dixon': 15679,
#  'remained': 42254,
#  'easily': 16626,
#  'reelection': 41823,
#  'faced': 18815,
#  'issue': 26996,
#  '1991': 584,
#  'klansman': 28562,
#  'david': 13491,
#  'duke': 16354,
#  'gubernatorial': 22641,
#  'runoff': 43877,
#  'louisiana': 30496,
#  'proclaimed': 39753,
#  'roundly': 43676,
#  'rejected': 42137,
#  'outgoing': 36414,
#  'edwin': 16801,
#  'edwards': 16799,
#  'overwhelmingly': 36710,
#  'campaign': 8719,
#  'remembered': 42276,
#  'bumper': 8275,
#  'sticker': 48302,
#  'touting': 51306,
#  'ethically': 18068,
#  'challenged': 9590,
#  'vote': 54388,
#  'crook': 12784,
#  'important': 25426,
#  'offers': 35778,
#  'parallel': 37077,
#  'want': 54647,
#  'sulfurous': 48996,
#  'assaults': 4690,
#  'editorial': 16764,
#  'pages': 36834,
#  'times': 50920,
#  'comments': 11104,
#  'msnbc': 33741,
#  'personalities': 37883,
#  'voices': 54329,
#  'world': 55712,
#  'review': 42961,
#  'weekly': 54939,
#  'commentary': 11097,
#  'columns': 10987,
#  'deplore': 14350,
#  'deviations': 14717,
#  'canon': 8820,
#  'reagan': 41350,
#  'aide': 2876,
#  'onetime': 35971,
#  'fcc': 19239,
#  'chairman': 9568,
#  'dennis': 14268,
#  'patrick': 37395,
#  'summarizes': 49022,
#  'way': 54822,
#  'colleagues': 10880,
#  'administration': 2481,
#  'hard': 23193,
#  'pulling': 40319,
#  'lever': 29752,
#  'weren': 55030,
#  'difficult': 14904,
#  'square': 47803,
#  'principled': 39659,
#  'theory': 50551,
#  'governance': 22138,
#  'policy': 38809,
#  'stirred': 48369,
#  'ire': 26829,
#  'vulgarity': 54448,
#  'fusion': 21006,
#  'ignorance': 25131,
#  'arrogance': 4469,
#  'narcissism': 34241,
#  'dissembling': 15498,
#  'matters': 31711,
#  'great': 22354,
#  'composite': 11299,
#  'portrait': 39026,
#  'painted': 36860,
#  'outlets': 36432,
#  'leavened': 29487,
#  'grudging': 22574,
#  'acknowledgment': 2254,
#  'touched': 51268,
#  'legitimate': 29583,
#  'concerns': 11383,
#  'immigration': 25287,
#  'terror': 50348,
#  'makes': 31052,
#  'idea': 25040,
#  'handing': 23084,
#  'nuclear': 35361,
#  'codes': 10761,
#  'unsettling': 53168,
#  'embracing': 17198,
#  'alternative': 3309,
#  'clinton': 10525,
#  'lunge': 30677,
#  'represents': 42496,
#  'leaves': 29489,
#  'slices': 46698,
#  'unwilling': 53284,
#  'unable': 52354,
#  'accept': 2113,
#  'seen': 45153,
#  'heretic': 23804,
#  'views': 54096,
#  'trade': 51371,
#  'taxes': 50001,
#  'government': 22143,
#  'clownish': 10621,
#  'bluster': 7161,
#  'casual': 9177,
#  'bigotry': 6648,
#  'make': 31047,
#  'temperamentally': 50206,
#  'odds': 35730,
#  'massive': 31631,
#  'based': 5879,
#  'folks': 20184,
#  'forms': 20406,
#  'quiet': 40729,
#  'step': 48237,
#  'away': 5231,
#  'work': 55682,
#  'behalf': 6202,
#  'ticket': 50831,
#  'fervently': 19444,
#  'hopes': 24458,
#  'fate': 19141,
#  'past': 37305,
#  'runners': 43874,
#  'rudy': 43821,
#  'giuliani': 21740,
#  'newt': 34760,
#  'gingrich': 21696,
#  'event': 18192,
#  'heart': 23540,
#  'soul': 47311,
#  'energy': 17476,
#  'saving': 44484,
#  'senate': 45272,
#  'kelly': 28192,
#  'ayotte': 5293,
#  'pat': 37327,
#  'toomey': 51163,
#  'ron': 43528,
#  'survive': 49280,
#  'end': 17405,
#  'knows': 28669,
#  'key': 28271,
#  'checks': 9806,
#  'balances': 5554,
#  'place': 38450,
#  'envision': 17714,
#  'outcomes': 36394,
#  'dan': 13323,
#  'schnur': 44718,
#  'spent': 47549,
#  'lifetime': 29916,
#  'vineyards': 54166,
#  'working': 55694,
#  'presidential': 39505,
#  'serving': 45425,
#  'communications': 11163,
#  'director': 15053,
#  'heads': 23491,
#  'unruh': 53135,
#  'institute': 26305,
#  'usc': 53441,
#  'virtually': 54203,
#  'guarantee': 22617,
#  'traditional': 51385,
#  'short': 45976,
#  'answer': 3821,
#  'save': 44478,
#  'term': 50298,
#  'impossible': 25443,
#  'conceive': 11364,
#  'leaders': 29427,
#  'forfeit': 20350,
#  'formal': 20387,
#  'need': 34479,
#  'fly': 20119,
#  'flag': 19844,
#  'brand': 7700,
#  'somewhat': 47207,
#  'viable': 54008,
#  'future': 21016,
#  'toxic': 51328,
#  'strategist': 48525,
#  'stu': 48672,
#  'stevens': 48285,
#  'believes': 6276,
#  'fade': 18872,
#  'single': 46392,
#  'nonetheless': 35078,
#  'agrees': 2827,
#  'trigger': 51743,
#  'effort': 16831,
#  'stutzman': 48733,
#  'veteran': 53974,
#  'helped': 23721,
#  'spearhead': 47457,
#  '2003': 629,
#  'recall': 41515,
#  'arnold': 4419,
#  'schwarzenegger': 44786,
#  'foresees': 20327,
#  'emerging': 17215,
#  'safe': 44068,
#  'harbor': 23186,
#  'disaffected': 15080,
#  'help': 23720,
#  'likely': 29960,
#  'ballots': 5592,
#  'conscience': 11645,
#  'devastating': 14693,
#  'solid': 47152,
#  'options': 36132,
#  'senators': 45275,
#  'kirk': 28516,
#  'opposed': 36084,
#  'fact': 18847,
#  'beat': 6078,
#  'attempting': 4933,
#  'bid': 6613,
#  'confront': 11546,
#  'obstacles': 35640,
#  'getting': 21571,
#  'late': 29265,
#  'calendar': 8626,
#  'laws': 29367,
#  'prohibit': 39866,
#  'multiple': 33856,
#  'lines': 30037,
#  'congressional': 11586,
#  'avoid': 5199,
#  'association': 4754,
#  'abandon': 1853,
#  'contender': 11852,
#  'shows': 46046,
#  'leaving': 29490,
#  'major': 31039,
#  'fraught': 20610,
#  'write': 55845,
#  'alaska': 3020,
#  'lisa': 30102,
#  'murkowski': 33931,
#  '2010': 640,
#  'succeed': 48894,
#  'thinkers': 50631,
#  'contemplating': 11840,
#  'demonstrates': 14205,
#  'perils': 37776,
#  'posed': 39041,
#  'looking': 30392,
#  'wrong': 55858,
#  'direction': 15046,
#  'defector': 13890,
#  'biggest': 6640,
#  'rape': 41129,
#  'accuser': 2203,
#  'skips': 46569,
#  'press': 39514,
#  'conference': 11479,
#  'citing': 10259,
#  'threats': 50715,
#  'gpd': 22168,
#  'general': 21400,
#  'posting': 39095,
#  'department': 14319,
#  'share': 45669,
#  'posts': 39108,
#  'sources': 47336,
#  'information': 26004,
#  'readers': 41334,
#  'managed': 31165,
#  'shiite': 45846,
#  'militia': 32659,
#  'close': 10576,
#  'tal': 49748,
#  'afar': 2647,
#  'turkey': 52089,
#  'warned': 54695,
#  'limits': 30007,
#  'november': 35298,
#  'rudaw': 43807,
#  'erbil': 17842,
#  'kurdistan': 28903,
#  'region': 41992,
#  'hashd': 23323,
#  'al': 2996,
#  'shaabi': 45528,
#  'said': 44108,
#  'thursday': 50799,
#  'forces': 20273,
#  '15': 267,
#  'kilometers': 28434,
#  'turkmen': 52096,
#  'town': 51318,
#  'clear': 10427,
#  'continuously': 11896,
#  'advancing': 2570,
#  'nearing': 34449,
#  'mosul': 33580,
#  'raqqa': 41166,
#  'road': 43343,
#  'karim': 28025,
#  'nuri': 35429,
#  'spokesperson': 47669,
#  'told': 51083,
#  'hoped': 24451,
#  'hours': 24589,
#  'supply': 49163,
#  'isis': 26937,
#  'strongholds': 48648,
#  'iraq': 26821,
#  'syria': 49590,
#  'iranian': 26819,
#  'received': 41536,
#  'air': 2905,
#  'support': 49165,
#  'coalition': 10696,
#  'outset': 36481,
#  'role': 43476,
#  'offensive': 35771,
#  'city': 10269,
#  'predominantly': 39355,
#  'captured': 8914,
#  'ago': 2813,
#  'group': 22543,
#  'large': 29214,
#  'swathes': 49385,
#  'land': 29118,
#  'entering': 17627,
#  'fear': 19248,
#  'brutalize': 8104,
#  'population': 38975,
#  'sunnis': 49062,
#  'shiites': 45847,
#  'week': 54933,
#  'turkish': 52092,
#  'recep': 41542,
#  'tayyip': 50017,
#  'erdogan': 17845,
#  'presence': 39479,
#  'sensitive': 45311,
#  'definitely': 13940,
#  'regard': 41969,
#  'involvement': 26765,
#  'positively': 39055,
#  'sinjar': 46405,
#  'clearly': 10435,
#  'saturday': 44442,
#  'totally': 51254,
#  'sunni': 49061,
#  'muslims': 33978,
#  'judge': 27737,
#  'religious': 42222,
#  'affiliation': 2670,
#  'added': 2385,
#  'terrorizes': 50358,
#  'response': 42721,
#  'related': 42162,
#  '19': 469,
#  'reads': 41343,
#  'filed': 19595,
#  'harris': 23279,
#  'lay': 29381,
#  'struggling': 48666,
#  'dying': 16506,
#  'surrounding': 49259,
#  'officers': 35787,
#  'breath': 7792,
#  'officer': 35786,
#  'yelled': 56113,
#  'fuck': 20860,
#  'insisted': 26238,
#  'man': 31161,
#  'handcuffed': 23071,
#  'encapsulates': 17359,
#  'words': 55677,
#  'disregard': 15465,
#  'police': 38798,
#  'regularly': 42028,
#  'black': 6856,
#  'america': 3438,
#  'watched': 54766,
#  'michael': 32495,
#  'slager': 46616,
#  'execute': 18398,
#  'walter': 54619,
#  'scott': 44856,
#  'daring': 13400,
#  'tuning': 52061,
#  'trial': 51688,
#  'chicago': 9910,
#  'dante': 13381,
#  'servin': 45424,
#  'charged': 9687,
#  'involuntary': 26762,
#  'manslaughter': 31284,
#  'killing': 28425,
#  '22': 718,
#  'rekia': 42155,
#  'boyd': 7615,
#  '2012': 643,
#  'eric': 17857,
#  'garner': 21243,
#  'staten': 48082,
#  'island': 26957,
#  'tamir': 49810,
#  'rice': 43098,
#  'cleveland': 10461,
#  'tulsa': 52036,
#  'video': 54059,
#  'law': 29351,
#  'enforcement': 17485,
#  'critically': 12746,
#  'injuring': 26120,
#  'citizens': 10263,
#  ...}

# %%
cv.inverse_transform(count_train)
# Out:
# [array([],
#        dtype='<U91'),
#  array(['page', 'spectrum', 'political', 'increase', 'gets', 'opposite',
#         'effect', 'sure', 'increases', 'doomsaying', 'left', 'bush',
#         'republican', 'glp', 'notice', 'office', 'trump', 'sayers', 'doom',
#         'think', 'violation', 'copyright', 'report'],
#        dtype='<U91'),
#  array(['center', 'candidates', 'quotes', '131', 'numbers', '43', 'photos',
#         '232', 'election'],
#        dtype='<U91'),
#  array(['chandler', 'kyle', 'love', 'stuff', 'good', 'garcia', 'lorena',
#         'soon', 'coming', 'knowing', 'laugh', 'food', 'joke', 'little',
#         'fun', 'solitary', 'sending', 'whisper', 'like', 'microwave',
#         'humility', 'neeson', 'liam', 'chance', 'brag', 'going', 'time',
#         'movies', 'saddest', 'list', 'schindler', 'course', 'day', 'talked',
#         'best', 'roundup', 'unbelievable', 'miss', 'don', 'people',
#         'notable', 'today', 'mind', 'wonder', 'email', 'quotes'],
#        dtype='<U91'),
#  array(['head', 'rogue', 'gone', 'bankers', 'case', 'isn', 'apple',
#         'rotten', 'crime', 'partners', 'paid', 'highly', 'directors',
#         'board', 'scandal', 'forced', 'recently', 'stumpf', 'john', 'ceo',
#         'profits', 'boosting', 'transactions', 'bogus', 'fees', 'collected',
#         'forged', 'signatures', 'moved', 'money', 'knowledge', 'set',
#         'services', 'online', 'fake', 'request', 'didn', 'cards', 'debit',
#         'credit', 'issued', 'secretly', 'million', 'half', 'subtle', 'wasn',
#         'systemic', 'thievery', 'robbers', 'syndicate', 'turned', 'bosses',
#         'fired', 'fail', 'quota', 'meeting', 'constantly', 'monitored',
#         'accounts', 'customer', 'load', 'expected', 'shutterstock', 'photo',
#         'account', 'checking', 'simple', 'wanted', 'depositors', 'common',
#         'products', 'unnecessary', 'myriad', 'selling', 'quotas', 'extreme',
#         'meet', 'frontline', 'demanding', '2009', 'sales', 'pressure',
#         'high', 'pushed', 'service', 'culture', 'customers', 'bank', 'rob',
#         'employees', 'forcing', 'literally', 'years', 'profiteering',
#         'executives', 'investors', 'defraud', 'books', 'cook', 'giants',
#         'finance', 'thing', 'depravity', 'corporate', 'level',
#         'unimaginable', 'previously', 'reach', 'slime', 'ethical', 'deeper',
#         'burrowing', 'comes', 'bailout', 'crash', 'street', 'wall', '2008',
#         'bottomed', 'greed', 'banker', 'big', 'surely', 'thought', 'just',
#         '139', 'rotting', 'fargo', 'wells', 'course', 'email'],
#        dtype='<U91'),
#  array(['biggest', 'defector', 'direction', 'wrong', 'looking', 'posed',
#         'perils', 'demonstrates', 'contemplating', 'thinkers', 'succeed',
#         '2010', 'murkowski', 'lisa', 'alaska', 'write', 'fraught', 'major',
#         'leaving', 'shows', 'contender', 'abandon', 'association', 'avoid',
#         'congressional', 'lines', 'multiple', 'prohibit', 'laws',
#         'calendar', 'late', 'getting', 'obstacles', 'confront', 'bid',
#         'attempting', 'beat', 'fact', 'opposed', 'kirk', 'senators',
#         'options', 'solid', 'devastating', 'conscience', 'ballots',
#         'likely', 'help', 'disaffected', 'harbor', 'safe', 'emerging',
#         'foresees', 'schwarzenegger', 'arnold', 'recall', '2003',
#         'spearhead', 'helped', 'veteran', 'stutzman', 'effort', 'trigger',
#         'agrees', 'nonetheless', 'single', 'fade', 'believes', 'stevens',
#         'stu', 'strategist', 'toxic', 'future', 'viable', 'somewhat',
#         'brand', 'flag', 'fly', 'need', 'formal', 'forfeit', 'leaders',
#         'conceive', 'impossible', 'term', 'save', 'answer', 'short',
#         'traditional', 'guarantee', 'virtually', 'usc', 'institute',
#         'unruh', 'heads', 'director', 'communications', 'serving',
#         'presidential', 'working', 'vineyards', 'lifetime', 'spent',
#         'schnur', 'dan', 'outcomes', 'envision', 'place', 'balances',
#         'checks', 'key', 'knows', 'end', 'survive', 'ron', 'toomey', 'pat',
#         'ayotte', 'kelly', 'senate', 'saving', 'energy', 'soul', 'heart',
#         'event', 'gingrich', 'newt', 'giuliani', 'rudy', 'runners', 'past',
#         'fate', 'hopes', 'fervently', 'ticket', 'behalf', 'work', 'away',
#         'step', 'quiet', 'forms', 'folks', 'based', 'massive', 'odds',
#         'temperamentally', 'make', 'bigotry', 'casual', 'bluster',
#         'clownish', 'government', 'taxes', 'trade', 'views', 'heretic',
#         'seen', 'accept', 'unable', 'unwilling', 'slices', 'leaves',
#         'represents', 'lunge', 'clinton', 'alternative', 'embracing',
#         'unsettling', 'codes', 'nuclear', 'handing', 'idea', 'makes',
#         'terror', 'immigration', 'concerns', 'legitimate', 'touched',
#         'acknowledgment', 'grudging', 'leavened', 'outlets', 'painted',
#         'portrait', 'composite', 'great', 'matters', 'dissembling',
#         'narcissism', 'arrogance', 'ignorance', 'fusion', 'vulgarity',
#         'ire', 'stirred', 'policy', 'governance', 'theory', 'principled',
#         'square', 'difficult', 'weren', 'lever', 'pulling', 'hard',
#         'administration', 'colleagues', 'way', 'summarizes', 'patrick',
#         'dennis', 'chairman', 'fcc', 'onetime', 'aide', 'reagan', 'canon',
#         'deviations', 'deplore', 'columns', 'commentary', 'weekly',
#         'review', 'world', 'voices', 'personalities', 'msnbc', 'comments',
#         'times', 'pages', 'editorial', 'assaults', 'sulfurous', 'want',
#         'parallel', 'offers', 'important', 'crook', 'vote', 'challenged',
#         'ethically', 'touting', 'sticker', 'bumper', 'remembered',
#         'campaign', 'overwhelmingly', 'edwards', 'edwin', 'outgoing',
#         'rejected', 'roundly', 'proclaimed', 'louisiana', 'runoff',
#         'gubernatorial', 'duke', 'david', 'klansman', '1991', 'issue',
#         'faced', 'reelection', 'easily', 'remained', 'dixon', 'alan', 'sen',
#         'independent', 'instead', 'line', 'bolted', 'acolytes', 'placing',
#         'horrified', 'state', 'secretary', 'lieutenant', 'nominations',
#         'demagogue', 'minded', 'conspiracy', 'cultish', 'larouche',
#         'followers', 'ballot', 'overshadowed', 'march', 'easy', 'votes',
#         'disputed', '000', 'fewer', 'race', 'earlier', 'mansion',
#         'illinois', 'footsteps', 'father', 'following', 'believe', 'reason',
#         'iii', 'stevenson', 'adlai', 'senator', '1986', 'chances',
#         'sacrificed', 'politician', 'occasion', 'temperament', 'unfit',
#         'chosen', 'belief', 'arises', 'peril', 'particular', 'hold',
#         'ranks', 'defection', 'explains', 'influence', 'battle', 'worse',
#         'country', 'bad', 'hillary', 'decades', 'campaigns', 'levels',
#         'involved', 'sycophantic', 'structural', 'described', 'self',
#         'says', 'school', 'old', 'feelings', 'strong', 'provoked',
#         'possibility', 'contest', 'outcome', 'critical', 'insiders',
#         'preferences', 'argues', 'decides', 'book', 'influential', 'thesis',
#         'undermine', 'unacceptable', 'branded', 'assailing', 'defending',
#         'vocal', 'ingraham', 'laura', 'coulter', 'ann', 'levin', 'mark',
#         'hannity', 'sean', 'limbaugh', 'rush', 'tribunes', 'media',
#         'alienated', 'holders', 'officials', 'moving', 'radical', 'sense',
#         'ideological', 'yes', 'example', 'landslide', 'lost', 'hands',
#         'sat', 'simply', 'emergence', 'disempowered', 'countless', 'backed',
#         'openly', 'connally', 'texas', 'labor', 'nixon', 'richard',
#         'neutrality', 'position', 'cio', 'afl', 'meany', 'mcgovern', 'hero',
#         'nominated', 'divided', 'deeply', 'flames', 'went', 'split',
#         'supported', 'democrat', 'johnson', 'lyndon', 'endorsed',
#         'establishment', 'voice', 'official', 'semi', 'tribune', 'herald',
#         'shockingly', 'endorse', 'refused', 'romney', 'michigan',
#         'rockefeller', 'nelson', 'york', 'new', 'things', 'liberal',
#         'goldwater', 'barry', 'champion', 'divisive', 'nominating',
#         'succeeded', 'conservatives', '1964', 'losing', 'defections',
#         'significant', 'dramatic', 'cases', 'voters', 'shift', 'small',
#         'relatively', 'anti', 'similar', 'wallace', 'george', 'alabama',
#         'later', 'power', 'balance', 'holding', 'representatives', 'thrown',
#         'choice', 'deadlocked', 'college', 'electoral', 'california',
#         'ohio', 'dewey', 'tom', 'defeated', 'barely', 'truman', 'harry',
#         'president', 'won', 'dixiecrats', 'democratic', 'states',
#         'thurmond', 'strom', 'governor', 'carolina', 'walk', 'delegations',
#         'southern', 'led', 'plank', 'embrace', '1948', 'south',
#         'supremacists', 'segregationists', 'welcoming', 'north', 'cause',
#         'embraced', 'rights', 'twice', 'democrats', 'happened',
#         'decisively', 'factions', 'different', 'accommodating', 'pattern',
#         'long', 'broke', 'come', 'politics', 'examples', 'striking', 'war',
#         'civil', 'guarantees', 'exactly', 'speaking', 'historically',
#         'impulse', 'movement', 'insurgent', 'triumph', 'represent',
#         'victory', 'fronts', 'unity', 'nominee', 'disaster', 'apparatus',
#         'control', 'total', 'house', 'white', 'win', 'reasonable',
#         'offered', 'year', '2016', 'suggests', 'insurgencies', 'rules',
#         'landscape', 'look', 'choices', 'painful', 'soldiers', 'foot',
#         'contributors', 'leave', 'turn', 'threat', 'run', 'running',
#         'right', 'operatives', 'character', 'personal', 'questions',
#         'ideology', 'driven', 'history', 'american', 'indivisible', 'deep',
#         'fissure', 'create', 'nomination', 'suggesting', 'strongly',
#         'positions', 'ground', 'stake', 'banners', 'convention',
#         'handshakes', 'resolved', 'kind', 'battles', 'intraparty', 'usual',
#         'stripes', 'moderate', 'republicans', 've', 'conversations',
#         'private', 'stronger', 'rhetoric', 'fascist', 'labeled', 'flatly',
#         'boot', 'max', 'expert', 'security', 'national', 'conservative',
#         'prominent', 'enemy', 'helping', 'driver', 'drunk', 'unhinged',
#         'conservatism', 'cancer', 'foes', 'primary', 'called', 'candidate',
#         'rally', 'asked', 'suddenly', 'gop', 'bearer', 'standard', 'wins',
#         'happens', 'question', 'plausible', 'increasingly', 'troubling',
#         'far', 'face', 'loses', 'prospect', 'temporarily', 'angst', 'party',
#         'inside', 'stay', 'intention', 'declared', 'night', 'tuesday',
#         'fears', 'eased', 'donald', 'highly', 'recently', 'john', 'moved',
#         'simple', 'wanted', 'meet', 'high', 'rob', 'years', 'thing',
#         'level', 'reach', 'thought', 'just', 'like', 'chance', 'time',
#         'talked', 'best', 'don', 'candidates', 'election', 'political',
#         'gets', 'sure', 'bush', 'republican', 'office', 'trump', 'think'],
#        dtype='<U91'),
#  array(['filed', 'reads', '19', 'related', 'response', 'terrorizes',
#         'added', 'affiliation', 'religious', 'judge', 'muslims', 'sunni',
#         'totally', 'saturday', 'clearly', 'sinjar', 'positively',
#         'involvement', 'regard', 'definitely', 'sensitive', 'presence',
#         'erdogan', 'tayyip', 'recep', 'turkish', 'week', 'shiites',
#         'sunnis', 'population', 'brutalize', 'fear', 'entering', 'land',
#         'swathes', 'large', 'group', 'ago', 'captured', 'predominantly',
#         'city', 'offensive', 'role', 'outset', 'coalition', 'support',
#         'air', 'received', 'iranian', 'syria', 'iraq', 'strongholds',
#         'isis', 'supply', 'hours', 'hoped', 'told', 'spokesperson', 'nuri',
#         'karim', 'road', 'raqqa', 'mosul', 'nearing', 'advancing',
#         'continuously', 'clear', 'town', 'turkmen', 'kilometers', '15',
#         'forces', 'thursday', 'said', 'shaabi', 'al', 'hashd', 'region',
#         'kurdistan', 'erbil', 'rudaw', 'november', 'limits', 'warned',
#         'turkey', 'afar', 'tal', 'close', 'militia', 'shiite', 'managed',
#         'readers', 'information', 'sources', 'posts', 'share', 'department',
#         'posting', 'general', 'gpd', 'threats', 'citing', 'conference',
#         'press', 'skips', 'accuser', 'rape', 'opposed', 'world',
#         'editorial', 'issue', 'line', 'earlier', 'country', 'says',
#         'critical', 'officials', 'backed', 'divided', 'president', 'led',
#         'north', 'different', 'control', '2016', 'stay', 'board', 'half',
#         'years', 'just', 'people', 'trump'],
#        dtype='<U91'),
#  array(['complicated', 'apparently', 'let', 'figuring', 'basic', 'murder',
#         'kill', 'unjustly', 'charging', 'doing', 'celebrate', 'tried',
#         'killings', 'protest', 'agony', 'writhe', 'constricts', 'present',
#         'injustice', 'historical', 'weight', 'value', 'communicate',
#         'watch', 'collective', 'change', 'affairs', 'unjust', 'submit',
#         'happy', 'ultimate', 'finally', 'constant', 'parole', 'probation',
#         'jail', 'saddling', 'stranglehold', 'communities', 'overpolicing',
#         'stultifying', 'justifies', 'class', 'lack', 'supposed', 'logic',
#         'point', 'limited', 'making', 'executing', 'yelling', 'color',
#         'number', 'disproportionate', 'americans', 'sufficient', 'children',
#         'adequately', 'allow', 'live', 'manage', 'reminders', 'wrongdoing',
#         'justifications', 'bills', 'interminably', 'weekend', 'ride',
#         'pleasures', 'enjoy', 'able', 'precariousness', 'fines', 'sentence',
#         'prison', 'subject', 'child', 'arrears', 'poor', 'slip', 'continue',
#         'actually', 'conditions', 'negative', 'order', 'demand',
#         'structures', 'commentators', 'pundits', 'levied', 'charges', 'ran',
#         'reminded', 'invaded', 'privatization', 'acts', 'combat', 'harder',
#         'multigenerational', 'friends', 'chatting', 'standing', 'gun',
#         'toy', 'playing', 'taillight', 'broken', 'freely', 'denial',
#         'predicated', 'exists', 'illuminates', 'wage', 'minimum', 'fight',
#         'waging', 'workers', 'fast', 'abysmal', 'served', 'fitness',
#         'assessments', 'discriminate', 'eateries', 'including',
#         'businesses', 'legislation', 'passed', 'indiana', 'tampering',
#         'insecure', 'names', 'throat', 'hand', 'needed', 'employment',
#         'fair', 'schools', 'restaurants', 'congress', 'lynching', 'trouble',
#         'lot', 'having', 'roosevelt', 'remember', 'harlem', 'grew',
#         'blacks', 'picnic', '1940', 'decision', 'interview', 'france',
#         'living', 'returned', 'baldwin', 'james', 'prophet', 'writer',
#         'famous', '1977', 'devalued', 'profane', 'sacred', 'dear',
#         'condition', 'endemic', 'profanity', 'barrage', 'taunted', 'body',
#         'seeped', 'chose', 'deserved', 'taunts', 'chorus', 'came', 'lose',
#         'did', 'result', 'confrontation', 'deputy', 'pretend',
#         'underprepared', 'placed', 'form', 'underwritten', 'privately',
#         'heavily', 'policed', 'brown', 'tactics', 'test', 'global',
#         'allowed', 'sounds', 'essentially', 'helpful', 'training',
#         'external', '11', 'wake', 'measures', 'counterterrorism', 'learn',
#         'uae', 'travel', 'militarized', 'exacerbate', 'instance',
#         'unspecified', 'purchase', 'enable', 'actions', 'endanger',
#         'governmental', 'escape', 'impact', 'monies', 'neoliberal', 'funds',
#         'scrutiny', 'public', 'uses', 'specific', 'donations', 'cash',
#         'infusions', 'allows', 'scheme', 'results', 'local', 'impacts',
#         'significantly', 'funding', 'investigations', 'criminal', 'aid',
#         'equipment', 'upgrade', 'used', 'nypd', 'according', 'foundation',
#         'gave', 'emirates', 'arab', 'united', 'conclude', 'issues',
#         'racial', 'progress', 'linear', 'narrative', 'trite', 'pessimistic',
#         'feel', 'moment', 'neoliberalism', 'terms', 'logics', 'streets',
#         'sport', 'sanctioned', 'fodder', 'provide', 'lives', 'appalling',
#         'weekends', 'cops', 'approval', 'sign', 'men', 'force', 'play',
#         'pay', 'sheriff', 'county', 'breathe', 'refusal', 'tacit',
#         'explicit', 'kkk', 'lynchings', 'participation', 'complicity',
#         'life', 'held', 'illusions', 'social', 'racialized', 'patrols',
#         'slave', 'connections', 'policing', 'origins', 'given',
#         'consequences', 'fatal', 'care', 'medical', 'administer',
#         'refusing', 'citizens', 'injuring', 'critically', 'enforcement',
#         'law', 'video', 'tulsa', 'cleveland', 'rice', 'tamir', 'island',
#         'staten', 'garner', 'eric', '2012', 'boyd', 'rekia', '22',
#         'killing', 'manslaughter', 'involuntary', 'charged', 'servin',
#         'dante', 'chicago', 'trial', 'tuning', 'daring', 'scott', 'walter',
#         'execute', 'slager', 'michael', 'watched', 'america', 'black',
#         'regularly', 'police', 'disregard', 'words', 'encapsulates',
#         'handcuffed', 'man', 'insisted', 'fuck', 'yelled', 'officer',
#         'breath', 'officers', 'surrounding', 'dying', 'struggling', 'lay',
#         'harris', 'religious', 'regard', 'week', 'large', 'city', 'support',
#         'told', 'spokesperson', 'clear', '15', 'forces', 'said', 'write',
#         'shows', 'avoid', 'getting', 'fact', 'options', 'trigger',
#         'working', 'place', 'balances', 'checks', 'away', 'forms', 'based',
#         'make', 'government', 'seen', 'makes', 'policy', 'governance',
#         'way', 'world', 'times', 'want', 'offers', 'vote', 'campaign',
#         'state', 'march', 'hold', 'country', 'bad', 'decades', 'self',
#         'old', 'sense', 'lost', 'hands', 'refused', 'york', 'new',
#         'liberal', 'losing', 'significant', 'cases', 'anti', 'similar',
#         'president', 'carolina', 'south', 'long', 'come', 'control',
#         'white', 'year', 'choices', 'leave', 'threat', 'run', 'right',
#         'personal', 'american', 'kind', 'private', 'far', 'case', 'money',
#         'million', 'systemic', 'robbers', 'fail', 'simple', 'wanted',
#         'high', 'service', 'culture', 'customers', 'thing', 'street', 'big',
#         'surely', 'just', 'food', 'like', 'going', 'time', 'miss', 'people',
#         'mind', 'left', 'office'],
#        dtype='<U91'),
#  array(['silent', 'assassinated', 'slain', 'defiant', 'scared', 'anymore',
#         'afraid', 'pelloux', 'wednesday', 'edition', 'latest', 'copies',
#         'thousands', 'staffers', 'talented', 'leader', 'cartoon',
#         'published', 'islamic', 'poking', 'publish', 'firebombed', 'attend',
#         'cameron', 'british', 'values', 'celebrating', 'sunday',
#         'columnist', 'malaysia', 'traveled', 'accomplice', 'alleged',
#         'boumeddiene', 'lived', 'intelligence', 'western', 'recruiter',
#         'european', 'premier', 'beghal', 'djamel', 'rifle', 'kalashnikov',
#         'ammunition', 'rounds', '240', 'arrested', 'bombing', 'subway',
#         '1995', 'incarcerated', 'algerian', 'free', 'attempt', 'strike',
#         'drone', 'cia', 'acted', 'cleric', 'scholar', 'born', 'recording',
#         'authenticity', 'confirm', 'independently', 'trip', 'financed',
#         'awlaki', 'anwar', 'carry', 'sent', 'shot', 'affiliate', 'iraqis',
#         'inflicted', 'torture', 'television', 'shown', 'injustices', 'saw',
#         'got', 'deposition', 'ready', 'wanting', 'record', 'court', '400',
#         'obtained', 'documents', 'semitism', 'jihad', 'brother', 'younger',
#         'weapons', 'receiving', 'months', 'elder', 'extremists', 'islamist',
#         'ties', 'attackers', 'dug', 'detained', 'bloodshed', 'deployed',
#         '80', 'suspects', 'woods', 'fled', 'stole', 'threatened',
#         'reportedly', '34', '32', 'cotterets', 'villers', 'attendant',
#         'station', 'gas', 'morning', 'lead', 'followed', 'tignous',
#         'honore', 'wolinski', 'cabu', 'pen', 'cartoonists', 'charbonnier',
#         'stephane', 'cartoonist', 'editor', 'included', 'executed',
#         'individuals', 'burst', 'provocative', 'known', 'satirical',
#         'entered', 'hooded', 'erupted', 'explain', 'safety', 'bus',
#         'awaiting', 'lifted', 'accompanied', 'students', 'eventually',
#         'son', 'young', 'pick', 'hoping', 'elementary', 'dunant', 'henri',
#         'outside', 'understands', 'teddy', 'days', 'standoffs', 'violent',
#         'deadly', 'talking', 'apt', 'language', 'military', 'weapon',
#         'religion', 'muslim', 'committed', 'saying', 'violence', 'respond',
#         'countrymen', 'urged', 'act', 'semitic', 'deaths', 'speech',
#         'market', 'stormed', 'rescued', '20', 'gunfire', 'climax', 'goele',
#         'en', 'dammartin', 'minutes', 'resolution', 'lockdown', 'dozens',
#         'swarmed', 'disand', 'pascal', 'union', 'heard', 'witnesses',
#         'scene', 'bfmtv', 'claiming', 'played', 'crisis', 'miles', '25',
#         '40', 'vincennes', 'porte', 'near', 'setting', 'othis', 'mayor',
#         'corneille', 'hiding', 'dead', 'word', 'nearby', 'landed',
#         'helicopters', 'holed', 'brothers', 'building', 'roof', 'silence',
#         'relative', 'pierced', 'explosions', 'gunshots', 'shortly',
#         'shuttered', 'shops', 'closed', 'roads', 'stuck', 'locked', 'area',
#         'itele', 'channel', 'parliament', 'albarello', 'yves', 'martyrs',
#         'die', 'gunmen', 'normal', 'civilians', 'dressed', 'business',
#         'arrived', '30', 'gunman', 'shook', 'radio', 'info', 'didier',
#         'identified', 'salesman', 'recent', 'traditionally', 'degree',
#         'demonstrated', 'source', 'sophistication', 'discussing',
#         'bulletin', 'homeland', 'fbi', 'beings', 'human', 'dignity', 'hope',
#         'freedom', 'stand', 'tennessee', 'crowd', 'tomorrow', 'stands',
#         'know', 'wants', 'obama', 'barack', 'françois', 'netanyahu',
#         'benjamin', 'prime', 'conversation', 'characterized', 'israeli',
#         'store', 'grocery', 'kosher', 'armed', 'standoff', 'survived',
#         'killed', 'tweeted', 'washington', 'spokesman', 'albasha',
#         'mohammed', 'attack', 'link', 'peninsula', 'arabian', 'qaeda',
#         'possible', 'investigation', 'launched', 'molins', 'organizations',
#         'terrorist', 'contacts', 'aware', 'authorities', '2011', 'yemen',
#         'visited', 'slaughter', 'knew', 'investigators', 'molin',
#         'francois', 'prosecutor', 'paris', '2014', 'calls', 'phone', '500',
#         'exchanged', 'boumedienne', 'hayat', 'coulibaly', 'amedy', 'taker',
#         'girlfriend', 'kouachi', 'cherif', 'suspect', 'wife', 'tonight',
#         'relieved', 'nation', 'cazeneuve', 'bernard', 'minister',
#         'interior', '04', '01', 'proud', 'hollande', 'woman', 'pursuit',
#         'attacks', 'prevent', 'healing', 'french', 'hostage', 'dozen',
#         'freeing', 'magazine', 'hebdo', 'charlie', 'offices', 'massacre',
#         'hostages', 'policewoman', 'shooting', 'suspected', 'terrorists',
#         'friday', 'raids', 'pair', 'cnn', 'kill', 'tried', 'number',
#         'americans', 'children', 'demand', 'acts', 'combat', 'friends',
#         'including', 'names', 'schools', 'lot', 'france', 'prophet',
#         'profane', 'came', 'did', 'form', 'heavily', 'tactics', 'training',
#         'learn', 'travel', 'according', 'united', 'men', 'held', 'fatal',
#         'enforcement', 'law', 'killing', 'black', 'police', 'man',
#         'officer', 'officers', 'muslims', 'week', 'fear', 'large', 'ago',
#         'syria', 'iraq', 'told', 'spokesperson', 'kilometers', '15',
#         'thursday', 'said', 'al', 'sources', 'department', 'conference',
#         'press', '2010', 'late', 'safe', 'future', 'answer', 'working',
#         'spent', 'work', 'away', 'quiet', 'government', 'seen', 'idea',
#         'terror', 'patrick', 'want', 'david', 'issue', 'remained', '000',
#         'battle', 'country', 'involved', 'described', 'says', 'school',
#         'old', 'officials', 'hands', 'simply', 'went', 'official',
#         'dramatic', 'cases', 'small', 'anti', 'similar', 'later',
#         'president', 'states', 'led', 'twice', 'different', 'long',
#         'politics', 'war', 'speaking', 'unity', 'year', 'foot', 'leave',
#         'questions', 'history', 'american', 'kind', 've', 'security',
#         'called', 'rally', 'asked', 'night', 'moved', 'set', 'didn',
#         'issued', 'wasn', 'meeting', 'photo', 'wanted', 'thought', 'soon',
#         'food', 'fun', 'like', 'going', 'time', 'day', 'best', 'don',
#         'people', 'today', 'page', 'left', 'think'],
#        dtype='<U91'),
#  array(['methods', 'preparation', 'opting', 'certain', 'intake', 'oatmeal',
#         'strawberries', 'garbanzos', 'nicely', 'quite', 'fits', 'vitamin',
#         'consuming', 'meat', 'type', 'iron', 'rely', 'diets', 'plant',
#         'follow', 'cauliflower', 'beans', 'oregano', 'fresh', '_blank',
#         'target', 'news', 'herbs', 'www', 'pizza', 'sauce', 'tomato',
#         'heated', 'better', 'lycopene', 'reap', 'vinegar', 'balsamic',
#         'virgin', 'extra', 'drizzled', 'chopped', 'salad', 'carotenoid',
#         'fat', 'staples', 'mediterranean', 'tomatoes', 'oil', 'olive',
#         'alzheimer', 'disease', 'protect', 'catechins', 'available',
#         'antioxidants', 'mixing', 'discovered', 'researchers', 'university',
#         'purdue', 'cup', 'juice', 'adding', 'start', 'content',
#         'antioxidant', 'extraordinary', 'drinking', 'lemon', 'tea', 'green',
#         'percent', 'pinch', 'tiny', 'sprinkling', 'add', 'curry', 'amounts',
#         'generous', 'contains', 'dish', 'cooking', 'ingredients',
#         'supplements', 'piperine', 'interestingly', 'absorbed', 'poorly',
#         'tends', 'properties', 'inflammatory', 'curcumin', 'ingredient',
#         'active', 'pepper', 'uptake', 'carbohydrates', 'serotonin',
#         'melatonin', 'brain', 'tryptophan', 'acid', 'amino', 'pairing',
#         'effective', 'stood', 'combination', 'true', 'asleep', 'fall',
#         'struggled', 'warm', 'glass', 'grandmother', 'honey', 'milk',
#         'absorption', 'nutrient', 'enhance', 'try', 'smart', 'benefits',
#         'maximize', 'processed', 'sugar', 'fried', 'preferable', 'fats',
#         'healthy', 'grains', 'produce', 'rich', 'diet', 'contain', 'absorb',
#         'prepared', 'vegetables', 'fruits', 'organic', 'eating', 'favor',
#         'stacking', 'nutritious', 'eat', 'conscious', 'naturalnews',
#         'turmeric', 'pairings', 'nutrients', 'tags', 'isabelle', 'health',
#         'boost', 'foods', 'eaten', 'mixology', 'known', 'human', 'pair',
#         'tried', 'making', 'child', 'hand', 'body', 'test', 'significantly',
#         'used', 'black', 'clear', 'sources', 'looking', 'help', 'effort',
#         'heart', 'step', 'based', 'odds', 'make', 'world', 'want', 'easily',
#         'easy', '000', 'reason', 'small', 'anti', 'reasonable', 'offered',
#         'choices', 'cancer', 'simple', 'comes', 'good', 'food', 'like',
#         'going', 'time', 'people', 'increase', 'sure'],
#        dtype='<U91'),
#  array(['contributed', 'calif', 'irvine', 'zezima', 'katie', 'rochester',
#         'weigel', 'springs', 'reported', 'keefe', 'pants', 'nice', 'trumps',
#         'breakfast', 'bugging', 'dazzled', 'alternate', 'unpledged', 'talk',
#         'bribe', 'gift', 'monetary', 'view', 'colo', 'arapahoe',
#         'chairwoman', 'hoffman', 'joy', 'supporters', 'wouldn',
#         'benefactor', 'depend', 'homes', 'renting', 'ways', 'delegation',
#         'mother', 'wendy', 'bought', 'suggestion', 'exasperated',
#         'inducements', 'swayed', 'interviewed', 'nevertrump', 'tweet',
#         'twitter', 'somebody', 'determined', 'organization', 'frazier',
#         'catherine', 'spokeswoman', 'hear', 'exposed', 'happen', 'nbc',
#         'manafort', 'paul', 'manager', 'ethics', 'woo', 'plan', 'specifics',
#         'declined', 'unseemly', 'exposure', 'aside', 'putting', 'optics',
#         'dangerous', 'pretty', 'systematic', 'doubt', 'suspicious',
#         'scrutinize', 'violations', 'focus', 'stepped', 'justice', 'noted',
#         'attorneys', 'apply', 'statutes', 'outright', 'sell', 'forbid',
#         'probably', 'bribery', 'absolutely', 'goes', 'west', 'wild',
#         'started', 'story', 'untold', 'revolution', 'detailed', 'shirley',
#         'craig', 'biographer', 'wavering', 'boone', 'stewart', 'jimmy',
#         'wayne', 'entertainers', 'recruiting', 'hollywood', 'match',
#         'marathon', 'witcover', 'jules', 'celebration', 'bicentennial',
#         'forrestal', 'uss', 'carrier', 'aircraft', 'deck', 'flight',
#         'hosted', 'dinner', 'lunch', 'entire', 'invited', 'uncommitted',
#         'bring', 'presidency', 'trappings', 'prestige', 'leveraged',
#         'contests', 'trickier', 'winning', 'keeps', 'leads', 'table',
#         'seat', 'attention', 'deals', 'vast', 'apparent', 'readily',
#         'january', 'islands', 'cayman', 'attorney', 'toner', 'items',
#         'ahead', 'weeks', 'subsistence', 'unseen', 'flow', 'gifts', 'means',
#         'coordination', 'disclosed', 'does', 'contribution', 'provided',
#         'perk', 'unclear', 'herman', 'anthony', 'problem', 'cabo', 'decide',
#         'tested', 'payments', 'assistance', 'dollars', 'messages', 'immune',
#         'colorado', 'unsuccessfully', '27', 'carlson', 'gregory',
#         'unsettled', 'feeling', 'guardrails', 'bound', 'elected', '200',
#         'nearly', 'details', 'family', 'hobbies', 'background', 'data',
#         'reams', 'collects', 'room', 'strategists', 'floated', 'lobby',
#         'groups', 'guidance', 'offer', 'pacs', 'open', 'prepare', 'rivals',
#         'majority', 'vows', 'team', 'kings', 'll', 'represented', 'lawyer',
#         'kappel', 'brett', 'bidding', 'alliance', 'kasich', 'gov', 'mix',
#         'july', '237', 'secure', 'edge', 'tumble', 'rough', 'season',
#         'relentlessness', 'envelope', 'push', 'possibly', 'stakes', 'heat',
#         'fec', 'counsel', 'associate', 'gross', 'kenneth', 'territory',
#         'uncharted', 'discern', 'trying', 'opinions', 'commission',
#         'paging', 'furiously', '1976', 'ronald', 'vs', 'ford', 'gerald',
#         'contested', 'florida', 'resort', 'golf', 'luxury', 'owned', 'say',
#         'staff', 'senior', 'prior', 'cover', 'experts', 'legal', 'expenses',
#         'committee', 'lodging', 'costs', 'defray', 'selected', 'sums',
#         'unlimited', 'delegate', 'permitted', 'donor', 'individual',
#         'nationals', 'foreign', 'contractors', 'federal', 'unions',
#         'corporations', '1980s', 'established', 'regulations', 'falsehoods',
#         'dismissed', 'shenanigans', 'crooked', 'goodies', 'luring',
#         'accused', 'unfair', 'accusations', 'jockeying', 'lock', 'efforts',
#         'barred', 'holds', 'pursue', 'game', 'persuasion', 'turning',
#         'freewheeling', 'pac', 'super', 'funded', 'courtesy', 'rooms',
#         'hotel', 'activists', 'swag', 'expensive', 'stocked', 'bags',
#         'welcome', 'dining', 'wining', 'supporter', 'cruz', 'ted',
#         'wealthy', 'jet', 'accoutered', 'gold', 'rides', 'delegates',
#         'wooing', 'imagine', 'target', 'adding', 'try', 'eat', 'boost',
#         'thousands', 'sunday', 'trip', 'financed', 'shown', 'months',
#         'awaiting', 'outside', 'days', 'scene', '40', 'building', 'recent',
#         'know', 'washington', 'possible', 'knew', 'let', 'tried', 'value',
#         'watch', 'lack', 'allow', 'live', 'weekend', 'able', 'charges',
#         'ran', 'combat', 'fight', 'fast', 'including', 'hand', '1977',
#         'came', 'tactics', 'travel', 'unspecified', 'public', 'specific',
#         'cash', 'criminal', 'used', 'according', 'feel', 'terms', 'play',
#         'pay', 'county', 'connections', 'given', 'citizens', 'law',
#         'cleveland', 'michael', 'added', 'saturday', 'week', 'group', 'ago',
#         'city', 'support', 'clear', 'said', 'limits', 'warned',
#         'department', 'general', 'press', 'looking', 'laws', 'getting',
#         'harbor', 'veteran', 'effort', 'single', 'need', 'save',
#         'presidential', 'end', 'pat', 'accept', 'way', 'reagan', 'want',
#         'campaign', 'david', 'easily', 'independent', 'state', 'votes',
#         'race', 'believe', 'senator', 'battle', 'country', 'bad',
#         'campaigns', 'says', 'old', 'possibility', 'contest', 'book',
#         'officials', 'texas', 'labor', 'michigan', 'york', 'new',
#         'relatively', 'anti', 'ohio', 'delegations', 'led', 'democrats',
#         'long', 'war', 'nominee', 'house', 'white', 'win', 'offered',
#         'year', 'rules', 'look', 'personal', 'convention', 'kind',
#         'republicans', 've', 'conversations', 'private', 'candidate',
#         'asked', 'gop', 'far', 'party', 'stay', 'donald', 'case', 'paid',
#         'board', 'recently', 'john', 'transactions', 'forged', 'money',
#         'expected', 'account', 'meet', 'high', 'years', 'finance', 'comes',
#         'thought', 'just', 'food', 'little', 'like', 'going', 'day', 'best',
#         'don', 'people', 'candidates', '43', 'election', 'political',
#         'left', 'republican', 'trump', 'think', 'report'],
#        dtype='<U91'),
#  array(['execution', 'calling', 'correcting', 'real', 'elections', 'fix',
#         'network', 'shadowy', 'crazy', 'maybe', 'rival', 'candour', 'rare',
#         'fashion', 'calm', 'fucking', 'politicians', 'idiot', 'minors',
#         'images', 'illicit', 'graphic', 'suffer', '9th', 'cleared', 'desk',
#         'person', 'petty', 'shared', 'bullshit', 'shit', 'proof', 'shred',
#         'illegality', 'insinuation', 'cynical', 'relevant', 'polling',
#         '8th', 'server', 'publicised', 'reopening', 'remains', 'explained',
#         'bang', 'gotta', 'ya', 'job', 'spend', 'investigating', 'specify',
#         'implicated', 'manufacturing', 'wilfully', 'politicizing',
#         'altogether', 'scraping', 'failing', 'comey', 'replacing',
#         'admitted', 'female', 'verge', 'comment', 'supporters', 'probably',
#         'elected', 'details', 'll', 'trying', 'federal', 'accused',
#         'better', 'add', 'defiant', 'sent', 'morning', 'days', 'act', 'fbi',
#         'investigation', 'investigators', 'wrongdoing', 'actually', 'james',
#         'public', 'gave', 'united', 'moment', 'given', 'refusing',
#         'america', 'added', 'role', 'support', 'november', 'information',
#         'director', 'fate', 'clinton', 'way', 'campaign', 'remained',
#         'instead', 'bad', 'hillary', 'official', 'president', 'democratic',
#         'states', 'come', 'right', 'personal', 'candidate', 'rally',
#         'asked', 'donald', 'scandal', 'fired', 'thing', 'just', 'like',
#         'day', 'people', 'email', 'office', 'trump'],
#        dtype='<U91'),
#  array(['defeat', 'marching', 'eclipsing', 'reversed', 'roles', 'backers',
#         'opposition', 'current', 'forget', 'troops', 'stage', 'forward',
#         'invest', 'understand', 'planner', 'events', 'griebe', 'sarah',
#         'handshake', 'waiting', 'cheering', 'lustily', 'cheer',
#         'preliminaries', 'lasted', 'steenburgen', 'mary', 'banks',
#         'elizabeth', 'fields', 'sally', 'actors', 'array', 'members',
#         'women', 'speakers', 'preliminary', '17', 'introduced', 'airport',
#         'la', 'appearances', 'notion', 'alive', 'kept', 'beachgoers',
#         'selfies', 'angeles', 'los', 'spanish', 'community', 'message',
#         'upbeat', 'vigor', 'campaigned', 'prevailed', 'version', 'older',
#         'army', 'mobilized', 'fallen', 'resembling', 'honor', 'highest',
#         'institution', 'venerable', 'officially', 'joining', 'devolve',
#         'displacing', 'argument', 'main', 'points', 'percentage',
#         'matchups', 'hypothetical', 'caucuses', 'primaries', 'polls',
#         'achieve', 'feat', 'generation', 'exuberance', '1960s',
#         'rebellious', 'wed', 'youth', 'focal', 'status', 'structure',
#         'elite', 'resentment', 'anonymity', 'extent', 'recognition',
#         'outsider', 'salute', 'stop', 'bedfellows', 'tandem', 'arguing',
#         'embarrassing', 'referred', 'spicer', 'raised', 'interviewers',
#         'use', 'probe', 'shocking', 'needs', 'breakout', 'fabulous',
#         'reflect', 'allocate', 'model', 'proportion', 'math', 'alter',
#         'net', 'command', '14', 'june', 'columbia', 'district',
#         'participants', 'caucus', 'cast', 'reflecting', 'pledged',
#         'presumptive', 'zone', 'eastern', 'jersey', 'soundings', 'round',
#         'finish', 'difference', 'corruption', 'rigging', 'rule',
#         'coronations', 'leveling', 'threatening', 'crowds', 'stadium',
#         'red', 'feeding', 'dragon', 'slaying', 'hierarchy', 'vanquishing',
#         'populist', 'undercut', 'multi', 'final', 'disappointing',
#         'jeopardy', 'campaigning', 'achieved', 'engaged', 'energized',
#         'sight', 'goal', 'maintain', 'underdog', 'essential', 'eyes',
#         'observer', 'predicament', 'assess', 'philadelphia', 'collapse',
#         'utter', 'barring', 'rico', 'puerto', 'tallies', '383', 'magic',
#         'reached', 'promise', 'possibilities', 'prospects', 'speak',
#         'faith', 'listened', 'believers', 'legions', 'harsh', 'sound',
#         'dream', 'marvelous', 'voting', 'grandchildren', 'brought',
#         'sanders', 'touchstone', 'journey', 'hopeful', 'symbol', 'monica',
#         'santa', 'coastal', 'pacific', 'reaching', 'pier', 'ending',
#         'aspiration', 'ribbon', 'middle', 'wound', '66', 'route',
#         'legendary', 'bernie', 'politicians', 'server', 'remains',
#         'unpledged', 'supporters', 'depend', 'happen', 'pretty', 'sell',
#         'probably', 'absolutely', 'goes', 'west', 'started', 'hollywood',
#         'winning', 'leads', 'attention', 'islands', 'means', 'does',
#         'majority', 'july', 'contested', 'say', 'accusations', 'delegates',
#         'imagine', 'quite', 'meat', 'virgin', 'add', 'sunday', 'included',
#         'saying', 'die', 'fbi', 'hope', 'stand', 'crowd', 'spokesman',
#         'prevent', 'point', 'making', 'number', 'weekend', 'able',
#         'continue', 'exists', 'including', 'needed', 'congress', 'did',
#         'results', 'progress', 'narrative', 'moment', 'lives', 'garner',
#         'america', 'clearly', 'told', 'clear', 'town', 'forces', 'said',
#         'posed', 'beat', 'helped', 'short', 'knows', 'end', 'energy',
#         'heart', 'event', 'past', 'make', 'clinton', 'difficult', 'hard',
#         'way', 'world', 'important', 'vote', 'campaign', 'issue', 'easily',
#         'state', 'ballot', 'easy', 'votes', 'fewer', 'chances', 'hillary',
#         'feelings', 'strong', 'contest', 'argues', 'sean', 'position',
#         'hero', 'went', 'split', 'supported', 'establishment', 'official',
#         'new', 'voters', 'power', 'college', 'california', 'president',
#         'won', 'democratic', 'states', 'southern', 'democrats', 'different',
#         'come', 'politics', 'speaking', 'movement', 'victory', 'unity',
#         'nominee', 'house', 'win', 'year', '2016', 'rules', 'look', 'run',
#         'right', 'questions', 'create', 'nomination', 'convention',
#         'republicans', 've', 'private', 'national', 'primary', 'candidate',
#         'gop', 'happens', 'far', 'prospect', 'party', 'night', 'tuesday',
#         'donald', 'paid', 'highly', 'board', 'expected', 'years', '2008',
#         'big', 'thought', 'little', 'going', 'time', 'day', 'best', 'don',
#         'people', 'today', 'mind', 'email', 'center', 'candidates',
#         'numbers', 'republican', 'trump', 'think', 'report'],
#        dtype='<U91'),
#  array(['defeating', 'registered', '67', 'thirds', 'fare', 'electability',
#         '63', 'atheist', '51', 'liability', 'potential', 'greater',
#         'believing', '53', '42', '23', 'mormon', '69', 'beliefs', 'matter',
#         'adults', 'characteristic', 'neutral', 'christian', 'evangelical',
#         '75', 'catholic', 'jewish', 'majorities', 'god', 'shares',
#         'declining', 'steadily', 'veterans', 'surprising', '13', 'month',
#         'survey', 'possesses', 'remaining', 'trait', 'continues',
#         'longtime', '2007', 'independents', '44', '31', 'overall',
#         'negatively', 'viewed', 'lawmaker', '46', 'september', 'stable',
#         '65', '36', 'period', 'increased', 'leaning', 'entirely', '37',
#         '55', 'flipped', 'approach', 'ideas', '50', 'proven', 'valued',
#         'especially', 'required', 'necessarily', 'experience', 'regardless',
#         'consider', 'presidents', 'narrowed', 'parties', 'heating',
#         'fields', 'members', 'fallen', 'points', 'percentage',
#         'hypothetical', 'primaries', 'difference', 'faith', 'reaching',
#         'person', 'remains', 'view', 'wouldn', 'focus', 'contests',
#         'january', 'does', 'tested', 'elected', 'nearly', 'groups',
#         'opinions', 'prior', 'certain', 'record', 'months', '80',
#         'military', 'muslim', 'saying', '20', '30', 'recent', 'washington',
#         'limited', 'americans', 'weekend', 'negative', 'pundits', 'harder',
#         'served', 'including', 'congress', 'came', 'public', 'issues',
#         'given', '2012', '22', 'religious', 'positively', 'large',
#         'support', '15', 'said', 'share', 'general', 'major', 'likely',
#         'presidential', 'past', 'make', 'matters', 'want', 'important',
#         'vote', 'campaign', 'issue', 'remained', 'march', 'believe',
#         'campaigns', 'contest', 'official', 'new', 'voters', 'shift',
#         'similar', 'later', 'president', 'democratic', 'different',
#         'nominee', 'house', 'white', 'year', '2016', 'nomination',
#         'positions', 'republicans', 'candidate', 'far', 'party', 'half',
#         'years', 'just', 'good', 'chance', 'time', 'day', 'best',
#         'candidates', 'numbers', '43', 'election', 'political', 'republican'],
#        dtype='<U91'),
#  array(['destroying', 'motto', 'com', 'amazon', 'east', 'touring', 'tips',
#         'jacket', 'flak', 'author', 'cassandra', 'blogger', 'correspondent',
#         'journalist', 'freelance', 'stillwater', 'jane', 'wars', 'neo',
#         'nigeria', 'libya', 'ukraine', 'palestine', 'damage', 'collateral',
#         'haste', 'post', 'bearing', 'victims', 'ppps', 'grieve', 'whine',
#         'attacking', 'rest', 'gobbling', 'complex', 'practically', 'occupy',
#         'movements', 'chicano', 'various', 'protestors', 'pps', 'bismarck',
#         'capitol', 'reservation', 'figure', 'ps', 'thankful', 'truly',
#         'really', 'thanksgiving', 'propose', 'dogs', 'hurricane', 'bravely',
#         'protecting', 'sioux', 'goodness', 'thank', 'wide', 'site',
#         'advertisement', 'bullets', 'rubber', 'shoot', 'spray', 'arrest',
#         'harass', 'tear', 'payer', 'tax', 'hundreds', 'death', 'heroic',
#         'reaction', 'dakota', 'rock', 'tribe', 'indian', 'courageous',
#         'mainly', 'happening', 'anybody', 'boom', 'industrial', 'fueled',
#         'carbon', 'thanks', '00', '650', 'interval', 'thrived',
#         'civilization', 'certainly', 'shite', 'holy', 'scare', 'designed',
#         'climate', 'nightmare', 'approaching', 'rapidly', 'screwed',
#         'tells', 'basically', 'scranton', 'roy', 'written', 'anthropocene',
#         'learning', 'entitled', 'reading', 'currently', 'cc', 'flickr',
#         'matter', 'stable', 'consider', 'alive', 'honor', 'stop', 'middle',
#         'aside', 'pretty', 'probably', 'dinner', 'bring', 'vast', 'dollars',
#         'trying', 'oil', 'available', 'pepper', 'true', 'tags', 'latest',
#         'thousands', 'bombing', 'gas', 'days', 'military', 'building',
#         'die', 'beings', 'human', 'stand', 'attack', 'yemen', 'let',
#         'doing', 'change', 'americans', 'actually', 'standing', 'congress',
#         'having', 'helpful', 'militarized', 'according', 'lives', 'pay',
#         'america', 'black', 'police', 'syria', 'iraq', 'veteran', 'spent',
#         'place', 'knows', 'make', 'square', 'way', 'world', 'instead',
#         'book', 'succeeded', 'losing', 'small', 'north', 'war', 'house',
#         'white', 'right', 'years', 'street', 'wall', 'just', 'like',
#         'people', 'today', 'political'],
#        dtype='<U91'),
#  array(['early', 'reform', 'pushing', 'obamacare', 'dismantling', 'tax',
#         'obama', 'killing', 'administration', 'rules', 'list'],
#        dtype='<U91'),
#  array(['turnips', 'forehead', 'hit', 'lies', 'spouting', 'sturgeon',
#         'nicola', 'liking', 'guilty', 'hair', 'crimes', 'hanging', 'poppy',
#         'wearing', 'stocks', 'range', 'punishments', 'lame', 'horse',
#         'curse', 'lady', 'spy', 'sainsbury', 'shortchanged', '48', 'dealt',
#         'accuse', 'arse', 'toe', 'deserves', 'disagrees', 'brilliant',
#         'unanimous', 'legality', 'decorator', 'unemployed', 'degsy',
#         'florist', 'sandra', 'barristers', 'argued', 'convenes', 'hobbs',
#         'accountant', 'tools', 'garden', 'borrowed', 'disputes',
#         'witchcraft', 'dealing', 'makeshift', 'creation', 'dissatisfaction',
#         'britons', 'eu', 'opinion', 'popular', 'brexit', '16', '07',
#         'courts', 'demented', 'brexiters', 'roy', 'network', 'supporters',
#         'justice', 'room', 'legal', 'got', 'court', 'tomorrow', 'french',
#         'having', 'decision', 'living', 'came', '11', 'local', 'men', 'man',
#         'judge', 'totally', 'week', 'said', 'share', 'biggest', 'based',
#         'seen', 'times', 'old', 'cases', 'anti', 'won', 'led', 'long', 've',
#         'far', 'case', 'set', 'good', 'people'],
#        dtype='<U91'),
#  array(['shrinking', 'afford', 'stamps', 'rent', 'babies', 'saved', 'savvy',
#         'financially', 'sees', 'frustrations', 'connection', 'permission',
#         'creates', 'angry', 'economy', 'changes', 'taken', 'income',
#         'lower', 'society', 'cohort', 'aggrieved', 'hart', 'peter',
#         'shafted', 'grown', 'polarization', 'continuing', 'reflects',
#         'component', 'advancement', 'subordinate', 'facts', 'blue',
#         'unwillingness', 'philosophy', 'apocalyptic', 'animates', 'phrase',
#         'uttering', 'taunt', 'timid', 'inspired', 'appear', 'couple',
#         'carried', 'bernardino', 'san', 'mess', 'askance', 'corrosive',
#         'criticized', 'carson', 'ben', 'neurosurgeon', 'ruining',
#         'activities', 'focusing', 'prevents', 'tex', 'contenders', 'picked',
#         'overseas', 'insulting', 'limit', 'everybody', 'border', 'mexico',
#         'china', 'doesn', 'honest', 'frankly', 'disparaging', 'fox',
#         'megyn', 'moderator', 'august', 'clarion', 'sounded', 'bull',
#         'bend', 'adjacent', 'hitler', 'incorrect', 'decade', 'maher',
#         'comedian', 'edgy', 'broadly', 'yearning', 'fundamental', 'filter',
#         'passing', 'thinks', 'appeals', 'plain', 'authentic', 'hunger',
#         'adviser', 'axelrod', 'loud', 'satisfying', 'leading', 'arena',
#         'quad', 'expression', 'stifling', 'aimed', 'mccarthyism',
#         'liberals', 'prejudice', 'eliminate', 'distressing', 'material',
#         'warnings', 'receive', 'upsetting', 'protected', 'space', 'ongoing',
#         'academia', 'flared', 'companion', 'changed', 'disrespectful',
#         'pet', 'contending', 'animal', 'slurs', 'obvious', 'adopting',
#         'began', 'campuses', '1990s', 'raged', 'debate', 'agree', 'sharply',
#         'dropped', 'prefacing', 'pollsters', 'kinds', 'backlash', 'pc',
#         'racist', 'action', 'affirmative', 'devices', 'silencing',
#         'allegations', 'heartlessness', 'differences', 'validation',
#         'label', 'luntz', 'frank', 'pollster', 'feels', 'schmidt', 'steve',
#         'laughed', 'smirked', 'directed', 'condescension', 'cultural',
#         'tremendous', 'nonwhites', '61', '72', 'whites', '81', '62', 'felt',
#         'sentiment', 'proposition', 'agreed', '68', 'dickinson',
#         'fairleigh', 'poll', 'october', 'frustration', 'mainstream',
#         'channeling', 'temperature', 'raises', 'ad', 'tv', 'minds',
#         'changing', 'lips', 'biting', 'advised', 'brookings', 'galston',
#         'william', 'expunging', 'underground', 'sentiments', 'powerful',
#         'driving', 'diverse', 'grows', 'endure', 'intolerance', 'sexism',
#         'racism', 'express', 'emboldened', 'inexcusable', 'excuse',
#         'antipathy', 'growing', 'argue', 'recovery', 'economic', 'illegal',
#         'terrorism', 'confronts', 'seemingly', 'explanation', 'suggested',
#         'purpose', 'dictate', 'letting', 'tired', 'correct', 'politically',
#         'thinking', 'runner', 'retired', 'hilton', 'showed', 'helps',
#         'administrator', 'offending', 'mouth', 'mean', 'transgender',
#         'wrote', 'christmas', 'merry', 'couldn', 'arts', 'prestigious',
#         'campus', 'correctness', 'worked', 'cuthbertson', 'cathy', 'hit',
#         'early', 'wars', 'post', 'thank', 'learning', '63', 'potential',
#         '53', 'god', 'month', 'independents', 'ideas', '50', 'necessarily',
#         'understand', 'women', 'notion', 'institution', 'argument',
#         'structure', 'elite', 'command', 'red', 'sound', 'brought',
#         'sanders', 'middle', 'bernie', 'calling', 'job', 'calif', 'talk',
#         'somebody', 'noted', 'probably', 'hosted', 'presidency', 'does',
# ...
#         'contra', 'borders', 'israel', 'picture', 'tank', 'peaceful',
#         'policies', 'strategy', 'challenge', 'marks', 'russians', 'ethnic',
#         'crimea', 'russian', 'putin', 'interests', 'aggression', 'produced',
#         'process', 'russia', 'overwhelming', 'socialist', 'iran', 'signs',
#         'violating', 'referendum', 'uncertain', 'return', '18', 'depth',
#         'alternatives', 'despite', 'continued', 'cuts', 'giant', 'tensions',
#         'puppet', 'fiercely', 'discouraged', 'remove', 'fault', 'hot',
#         'arizona', 'permission', 'mess', 'border', 'thinks', 'mccarthyism',
#         'prejudice', '1990s', 'debate', 'differences', 'felt', 'mainstream',
#         'powerful', 'racism', 'seemingly', 'thinking', 'mean', 'deserves',
#         'early', 'destroying', 'east', 'wars', 'libya', 'ukraine', 'wide',
#         'tax', 'reaction', 'climate', 'veterans', 'especially', 'current',
#         'understand', 'elizabeth', 'june', 'eastern', 'populist', 'final',
#         'brought', 'sanders', 'bernie', 'supporters', 'ways', 'dangerous',
#         'west', 'story', 'presidency', 'elected', 'possibly', 'gross',
#         'territory', 'uncharted', 'say', 'foreign', '1980s', 'super',
#         'wealthy', 'delegates', 'rely', 'follow', 'fresh', 'news', 'start',
#         'rich', 'favor', 'published', 'islamic', 'values', 'western',
#         'sent', 'torture', 'weapons', 'lead', 'eventually', 'violent',
#         'military', 'know', 'wants', 'obama', 'barack', 'washington',
#         'qaeda', '2011', '2014', 'tried', 'value', 'change', 'class',
#         'making', 'americans', 'including', 'needed', 'congress',
#         'decision', 'chose', 'came', 'confrontation', 'tactics', 'actions',
#         'public', 'gave', 'united', 'issues', 'moment', 'lives', 'sign',
#         'life', 'given', 'consequences', 'america', 'response', 'muslims',
#         'clearly', 'fear', 'large', 'group', 'role', 'coalition', 'support',
#         'syria', 'iraq', 'al', 'turkey', 'share', 'department', 'press',
#         'wrong', 'major', 'fact', 'helped', 'somewhat', 'traditional',
#         'presidential', 'working', 'place', 'end', 'past', 'bigotry',
#         'government', 'clinton', 'policy', 'way', 'world', 'want',
#         'campaign', 'issue', 'sen', 'state', 'secretary', 'march',
#         'temperament', 'country', 'hillary', 'decades', 'involved', 'old',
#         'provoked', 'possibility', 'insiders', 'media', 'officials', 'went',
#         'establishment', 'official', 'new', 'liberal', 'voters', 'anti',
#         'george', 'choice', 'president', 'won', 'democratic', 'states',
#         'southern', 'democrats', 'war', 'speaking', 'victory', 'control',
#         'house', 'white', 'year', '2016', 'choices', 'soldiers', 'turn',
#         'running', 'american', 'create', 'nomination', 'suggesting',
#         'republicans', 'helping', 'called', 'candidate', 'rally', 'face',
#         'party', 'inside', 'donald', 'recently', 'money', 'knowledge',
#         'didn', 'wasn', 'turned', 'photo', 'pressure', 'pushed', 'street',
#         'wall', 'little', 'like', 'talked', 'people', 'today', 'political',
#         'left', 'republican', 'trump', 'think'],
#        dtype='<U91'),
#  array(['clumped', 'rendell', 'decennial', 'ebb', 'governorships',
#         'browner', '188', 'midterms', 'shrunk', 'corn', 'gerrymandering',
#         'mused', 'sexy', 'diminished', 'solidly', 'spectacularly', '257',
#         'elleithee', 'mayors', 'suburban', 'timed', 'salt', 'disadvantage',
#         'teams', 'secular', 'coincide', 'congressmen', 'lesbian',
#         'distributed', 'boundaries', '1920s', 'seed', 'rural', 'pays',
#         'remembers', 'cluster', 'whiter', 'seats', 'governors',
#         'efficiently', 'areas', 'census', 'districts', 'purposes',
#         'resources', '60', 'successes', 'lamented', 'hollowed', 'cold',
#         'easier', 'draw', 'electorates', 'mo', 'ed', 'houston', 'piece',
#         'pennsylvania', 'facing', 'identity', 'electorate', 'crushed',
#         'higher', 'timing', 'perfectly', 'nationwide', 'gains', 'drawn',
#         'races', 'legislatures', 'legislative', 'legacy', 'cities', 'surge',
#         'priority', 'assuming', 'congressman', 'midst', 'luck', 'lake',
#         'urban', 'turnout', 'midterm', 'price', 'failure', 'church',
#         'redistricting', 'legislature', 'took', 'include', 'low', 'utah',
#         'huge', 'farm', 'sees', 'doesn', 'diverse', 'couldn', 'reform',
#         'truly', 'hundreds', 'fueled', 'climate', 'currently', '13', '46',
#         'campaigned', 'older', 'district', 'red', 'elections', 'maybe',
#         'remains', 'presidency', 'winning', 'seat', 'vast', 'january',
#         'problem', 'elected', 'majority', 'gov', 'stakes', 'say',
#         'committee', 'regulations', 'tea', 'health', 'got', 'younger',
#         'crisis', 'obama', '2011', '2014', 'offices', 'change', 'number',
#         'live', 'manage', 'hand', 'lot', 'came', 'lose', 'result', 'local',
#         'held', 'care', 'america', 'words', 'city', 'november', 'close',
#         '2010', 'congressional', 'senators', 'help', 'effort', 'single',
#         'presidential', 'senate', 'make', 'makes', 'great', 'state',
#         'fewer', 'mansion', 'reason', 'hold', 'worse', 'bad', 'says',
#         'lost', 'texas', 'official', 'new', 'voters', 'holding',
#         'president', 'democratic', 'states', 'governor', 'democrats',
#         'happened', 'different', 'come', 'control', 'house', 'white', 'win',
#         'turn', 'right', 'positions', 'republicans', 'national', 'driver',
#         'gop', 'party', 'turned', '2009', 'years', 'level', 'street',
#         'wall', 'just', 'like', 'going', 'time', 'don', 'election',
#         'political', 'left', 'republican', 'office', 'think'],
#        dtype='<U91'),
#  array(['duplicate', 'simplifying', 'distributionally', 'pains', '2040',
#         'cbo', 'invigorate', 'marr', 'juxtapose', 'showering', 'bark',
#         'prospered', 'doles', 'weathering', 'shoring', 'mindful', 'dots',
#         'anxieties', 'budgeted', 'freezes', 'consolidating', 'capita',
#         'grants', 'aca', 'hawks', 'lighter', 'emergencies', 'synopsis',
#         'imposing', 'fairer', 'outlines', 'emphasize', 'streamlining',
#         'simpler', 'boomers', 'dave', 'nonpartisan', 'balanced',
#         'enhancing', 'tree', 'lacking', 'pell', 'households', 'unforeseen',
#         '775', 'sheet', 'refute', 'budgets', 'burdens', 'drag', '2025',
#         'connect', 'flawed', 'output', 'rewrite', 'strengthen',
#         'entitlements', 'overhaul', 'welfare', 'quick', 'georgia',
#         'justified', 'estimates', 'dismiss', 'fundamentally', 'scale',
#         'efficient', 'pave', 'aging', 'committees', 'proposals', 'signaled',
#         'representative', 'considerably', 'entitlement', 'deficit',
#         'deficits', 'flesh', 'indicates', 'investments', 'recession',
#         'hill', 'sacrifice', 'criticism', '2001', 'promised', 'cutting',
#         'implied', 'navigate', 'definitive', 'charge', 'investment',
#         'effects', 'prosperity', 'meaning', 'faces', 'crucial', 'path',
#         'chuck', 'favoring', 'replace', 'grow', 'straight', 'jeb', 'merely',
#         'projection', 'benefit', 'overcome', 'tend', 'plays', 'acknowledge',
#         'emphasis', 'gains', 'education', 'growth', 'measure', 'robust',
#         'repeal', 'rising', 'modest', 'priorities', 'primarily', 'activity',
#         'supports', 'reforms', 'disagree', 'compared', 'draft', 'proposal',
#         'fiscal', 'medicaid', 'medicare', 'downward', 'writes', 'appears',
#         'average', 'steep', 'mobility', 'nod', 'hitting', 'camp', 'plans',
#         'block', 'code', 'zero', 'jobs', 'upward', 'debt', 'families',
#         'policies', 'skepticism', 'spending', 'announces', 'critics', 'mr',
#         'estimated', 'fairness', 'savings', 'met', 'ordinary', 'asks',
#         'trillion', 'budget', 'breaks', 'price', 'rise', 'baby', 'buy',
#         'took', 'sweeping', 'affect', 'affordable', 'credits', 'programs',
#         'annual', 'insurance', 'subsidies', '2015', 'low', 'provides',
#         'proposed', 'reduction', 'cuts', 'rep', 'millions', 'defense', '10',
#         'economy', 'changes', 'income', 'lower', 'component', 'focusing',
#         'contenders', 'doesn', 'decade', 'fundamental', 'leading', 'agree',
#         'mainstream', 'economic', 'showed', 'reform', 'pushing',
#         'obamacare', 'capitol', 'tax', 'potential', 'neutral', 'declining',
#         'overall', 'entirely', 'approach', 'especially', 'parties',
#         'opposition', 'current', '17', 'argument', 'main', 'needs', 'net',
#         'goal', 'middle', 'person', 'failing', 'wouldn', 'ways',
#         'determined', 'plan', 'probably', 'detailed', 'means', 'details',
#         'groups', 'open', 'gov', 'florida', 'say', 'cover', 'committee',
#         'costs', 'federal', 'efforts', 'holds', 'pursue', 'available',
#         'percent', 'try', 'smart', 'benefits', 'rich', 'favor', 'health',
#         'boost', 'wednesday', 'safety', 'act', 'speech', 'recent', 'obama',
#         'washington', 'attack', 'possible', 'calls', 'nation', 'let',
#         'class', 'point', 'americans', 'allow', 'harder', 'minimum',
#         'served', 'including', 'passed', 'congress', 'lot', 'form',
#         'heavily', 'funds', 'public', 'gave', 'feel', 'provide', 'approval',
#         'pay', 'social', 'care', 'law', 'cleveland', 'america', 'clearly',
#         'week', 'clear', 'thursday', 'said', 'information', 'share',
#         'leaving', 'avoid', 'congressional', 'getting', 'fact', 'likely',
#         'help', '2003', 'future', 'term', 'answer', 'short', 'presidential',
#         'working', 'senate', 'past', 'massive', 'government', 'taxes',
#         'idea', 'makes', 'policy', 'hard', 'chairman', 'instead', 'line',
#         'state', 'march', 'votes', 'decades', 'says', 'mark', 'example',
#         'went', 'new', 'things', 'liberal', 'balance', 'tom', 'president',
#         'led', 'cause', 'different', 'long', 'come', 'war', 'house', 'year',
#         '2016', 'foot', 'leave', 'run', 'right', 'history', 'deep',
#         'create', 'nomination', 'strongly', 'republicans', 'private',
#         'expert', 'national', 'conservative', 'gop', 'far', 'party',
#         'tuesday', 'case', 'money', 'issued', 'photo', 'meet', 'high',
#         'years', 'level', 'reach', 'thought', 'just', 'good', 'little',
#         'like', 'time', 'people', 'center', 'political', 'effect',
#         'increases', 'bush', 'republican', 'office'],
#        dtype='<U91'),
#  array(['elving', 'rips', '186', '239', 'scrap', 'benefited', 'achievement',
#         'implemented', 'honored', 'blog', 'timeline', 'replacement',
#         'provisions', 'expects', 'chamber', 'letters', 'veto', 'smaller',
#         'measure', 'repeal', 'controlled', 'notes', 'coverage', 'writes',
#         'voted', 'direct', 'milestone', 'associated', 'promises', 'date',
#         'signature', 'met', 'healthcare', 'affordable', 'npr', 'expect',
#         'panels', 'approved', 'millions', '10', 'doesn', 'wrote', '50',
#         'maybe', 'plan', 'majority', 'contain', 'health', 'latest',
#         'threatened', 'act', 'obama', '2014', 'kill', 'americans',
#         'actually', 'legislation', 'came', 'issues', 'provide', 'care',
#         'law', 'said', 'press', 'opposed', 'likely', 'effort', 'working',
#         'ron', 'senate', 'past', 'away', 'makes', 'times', 'important',
#         'vote', 'campaign', 'new', 'defeated', 'president', 'different',
#         'come', 'politics', 'house', 'white', 'republicans', 'gop',
#         'plausible', 'meeting', 'years', 'time', 'today', 'candidates',
#         'election', 'republican'],
#        dtype='<U91'),
#  array(['broward', '37am', 'weaponry', 'aerial', 'sanford', 'plethora',
#         'ww', 'stabilize', 'rein', 'coconut', 'clapper', 'hasten',
#         'displaced', 'bombardment', 'creek', 'ravaged', 'airspace',
#         'takfiri', 'daesh', 'militancy', 'damascus', 'drag', 'conflict',
#         'militant', 'enforced', 'intervention', 'reiterated', 'speaks',
#         'planes', 'nukes', 'jets', 'reuters', 'capable', 'isil', '57',
#         'assad', 'bashar', 'extensive', 'infrastructure', 'fighting',
#         'fighter', 'spark', 'afp', 'enter', 'risk', 'deploy', 'council',
#         'remarks', 'relations', 'oct', 'incredibly', 'removal',
#         'international', 'secondary', 'ally', 'allies', 'priority',
#         'proposal', 'advanced', 'nature', 'conducting', 'neighboring',
#         'claimed', 'syrian', 'unless', 'warning', 'listen', 'zones',
#         'russian', 'second', 'countries', 'caused', 'russia', 'iran',
#         'sponsored', 'offering', 'advisory', 'stock', 'orlando',
#         'situation', 'intent', 'millions', 'defense', '26', 'focusing',
#         'leading', 'debate', 'felt', 'october', 'mean', 'early', 'damage',
#         'complex', 'shoot', 'hundreds', 'defeating', 'month', 'required',
#         'airport', 'wed', 'arguing', 'referred', 'use', 'zone',
#         'threatening', 'final', 'talk', 'wouldn', 'focus', 'aircraft',
#         'groups', 'push', 'florida', 'foreign', 'anymore', 'thousands',
#         'intelligence', 'weapons', 'deployed', 'lead', 'military', '25',
#         'civilians', 'armed', 'killed', '2011', '2014', 'shooting',
#         'terrorists', 'raids', 'number', 'congress', 'interview', 'james',
#         'did', 'confrontation', 'united', 'lives', 'consequences', 'week',
#         'entering', 'city', 'air', 'syria', 'iraq', 'forces', 'said', 'al',
#         'warned', 'opposed', 'help', 'safe', 'fly', 'save', 'director',
#         'presidential', 'end', 'past', 'work', 'government', 'clinton',
#         'nuclear', 'terror', 'policy', 'world', 'vote', 'campaign',
#         'instead', 'march', 'earlier', 'following', 'iii', 'country',
#         'hillary', 'described', 'says', 'backed', 'supported',
#         'establishment', 'york', 'new', 'anti', 'power', 'college',
#         'president', 'democratic', 'states', 'war', 'speaking', 'nominee',
#         '2016', 'right', 'american', 'positions', 'ground', 'national',
#         'helping', 'called', 'candidate', 'rally', 'inside', 'tuesday',
#         'donald', 'recently', 'request', 'level', 'going', 'don', 'people',
#         'photos', 'republican', 'trump', 'think'],
#        dtype='<U91'),
#  array(['disciple', 'cooly', 'dumbfounded', 'besting', 'publicans',
#         'sendeth', 'maketh', 'despitefully', 'asketh', 'cloke', 'whosoever',
#         'disciples', 'attainment', 'sufi', 'brethren', 'verses', 'smite',
#         'prostrate', 'persecute', 'coat', 'grants', 'sword', 'injunction',
#         'ah', 'hath', 'surrendered', 'ye', 'compel', 'cried', 'sermon',
#         'gospel', 'overcame', 'fierce', 'thrust', 'teachings', 'testament',
#         'twain', 'anguish', 'mount', 'protracted', 'fulfill', 'rain',
#         'manner', 'bless', 'cheek', 'neighbour', 'thine', 'thy', 'thee',
#         'concept', 'addresses', 'christ', 'unto', 'perfection', 'neck',
#         'forth', 'mile', 'familiar', 'foe', 'replied', 'feet', 'compare',
#         'stupid', 'matt', 'quoted', 'shalt', 'thou', 'master', 'heaven',
#         'perfected', 'st', 'resist', 'shrugged', 'evil', 'vicious',
#         'strength', 'sun', 'recognizing', 'falling', 'hate', 'mortal',
#         'borrow', 'shall', 'perceived', 'addressed', 'typically', 'stopped',
#         'enemies', 'soldier', 'furious', 'jesus', 'reward', 'pray',
#         'extend', 'read', 'weakness', 'sue', '38', 'search', 'discover',
#         'rise', 'takes', 'matthew', 'taking', 'spared', 'rose', 'deliver',
#         'eye', 'tooth', 'perfect', 'driving', 'curse', '48', 'matter',
#         'fallen', 'honor', 'salute', 'stop', 'use', 'reflect', 'engaged',
#         'determined', 'story', 'bound', 'family', 'say', 'followed',
#         'heard', 'closed', 'killed', 'attack', 'let', 'kill', 'present',
#         'unjust', 'finally', 'point', 'children', 'combat', 'returned',
#         'did', 'issues', 'moment', 'life', 'fatal', 'law', 'man', 'said',
#         'share', 'opposed', 'single', 'away', 'great', 'father', 'battle',
#         'lost', 'new', 'things', 'different', 'come', 'war', 'turn',
#         'right', 'ground', 'enemy', 'asked', 'request', 'thing', 'just',
#         'love', 'good', 'like', 'day', 'don', 'mind'],
#        dtype='<U91'),
#  ...]

# %%
#transform test to match train
count_test = cv.transform(X_test)

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

nb1 = MultinomialNB()

nb1.fit(count_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print ("Classification rate for NB- Model 1 (Train):", round(nb1.score(count_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 1 (Test):", round(nb1.score(count_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 1 (Train): 94.67 %
# Classification rate for NB- Model 1 (Test): 89.34 %

# %% [markdown]
# ### Model 2: TFID Vectorizer- Text only

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tv = TfidfVectorizer(stop_words='english')

tfid_train = tv.fit_transform(X_train)

# %%
tfid_train.shape
# Out:
# (4244, 56922)

# %%
tfid_test = cv.transform(X_test)

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB

nb2 = MultinomialNB()

nb2.fit(tfid_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print ("Classification rate for NB- Model 2 (Train):", round(nb2.score(tfid_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 2 (Test):", round(nb2.score(tfid_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 2 (Train): 91.49 %
# Classification rate for NB- Model 2 (Test): 79.29 %

# %% [markdown]
# Without making any adjustments to the Vectorization methods, NB for count vectorizer performs better then for TFID vectorizer.

# %% [markdown]
# ### Model 3: Count vectorizer- Title only

# %%
X = realOrFake['title']
y = realOrFake['Fake']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=53)

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')

count_train2 = cv.fit_transform(X_train)

# %%
cv.vocabulary_
# Out:
# {'reader': 5763,
#  'refers': 5842,
#  'englishman': 2475,
#  'pat': 5161,
#  'condell': 1560,
#  'brexit': 1011,
#  'trump': 7360,
#  'election': 2394,
#  'america': 397,
#  'moment': 4616,
#  'truth': 7373,
#  'think': 7163,
#  'doom': 2237,
#  'sayers': 6236,
#  'office': 4947,
#  'bernie': 801,
#  'california': 1128,
#  'endgame': 2453,
#  'said': 6196,
#  'liam': 4157,
#  'neeson': 4785,
#  'lorena': 4251,
#  'garcia': 3035,
#  'kyle': 4027,
#  'chandler': 1285,
#  'say': 6235,
#  'wells': 7777,
#  'fargo': 2706,
#  'rotting': 6130,
#  'gop': 3136,
#  'mount': 4664,
#  'party': 5149,
#  'challenge': 1278,
#  'shiite': 6429,
#  'militia': 4539,
#  'says': 6238,
#  'close': 1437,
#  'tal': 7046,
#  'afar': 283,
#  'turkey': 7388,
#  'warned': 7714,
#  'limits': 4195,
#  'blood': 892,
#  'money': 4623,
#  'killer': 3976,
#  'cops': 1680,
#  'privatization': 5517,
#  'funding': 3008,
#  'racist': 5695,
#  'logic': 4234,
#  'police': 5357,
#  'charlie': 1308,
#  'hebdo': 3330,
#  'attack': 590,
#  'terrorists': 7129,
#  'killed': 3975,
#  'raids': 5707,
#  'food': 2902,
#  'mixology': 4588,
#  'eaten': 2348,
#  'foods': 2903,
#  'boost': 946,
#  'health': 3316,
#  'far': 2702,
#  'campaigns': 1141,
#  'win': 7818,
#  'support': 6947,
#  'republican': 5953,
#  'delegate': 1960,
#  'clinton': 1429,
#  'promises': 5555,
#  'scrap': 6284,
#  'pointless': 5348,
#  'fbi': 2733,
#  'elected': 2392,
#  'weekend': 7767,
#  'house': 3475,
#  'hope': 3447,
#  'voters': 7666,
#  'want': 7700,
#  'president': 5471,
#  'today': 7218,
#  'views': 7619,
#  'changed': 1287,
#  'thanksgiving': 7148,
#  'standing': 6755,
#  'rock': 6106,
#  'gaming': 3031,
#  'obamacare': 4911,
#  'brexiters': 1012,
#  'set': 6373,
#  'demented': 1976,
#  'people': 5208,
#  'courts': 1732,
#  'winning': 7829,
#  'war': 7704,
#  'political': 5363,
#  'correctness': 1692,
#  'life': 4175,
#  '10': 7,
#  'steps': 6798,
#  'rolling': 6115,
#  'perfect': 5213,
#  'joint': 3878,
#  'gingrich': 3089,
#  'attacks': 594,
#  'megyn': 4470,
#  'kelly': 3947,
#  'sex': 6383,
#  'advisor': 279,
#  'threat': 7174,
#  'blows': 903,
#  'online': 4976,
#  'parenthood': 5130,
#  'chief': 1342,
#  'goes': 3122,
#  'toe': 7220,
#  'attackers': 592,
#  'drama': 2263,
#  'docket': 2203,
#  'high': 3369,
#  'court': 1730,
#  'term': 7119,
#  'end': 2450,
#  'slate': 6547,
#  'big': 818,
#  'cases': 1205,
#  '28': 88,
#  'alternative': 386,
#  'uses': 7537,
#  'saving': 6232,
#  'mylar': 4719,
#  'emergency': 2424,
#  'blankets': 867,
#  'rally': 5717,
#  'hollywood': 3418,
#  'boulevard': 966,
#  '29': 90,
#  '16': 26,
#  'terror': 7126,
#  '147': 24,
#  'dead': 1889,
#  'kenya': 3954,
#  'university': 7474,
#  'defense': 1947,
#  'secretary': 6309,
#  'carter': 1200,
#  'used': 7534,
#  'personal': 5228,
#  'email': 2414,
#  'months': 4633,
#  'job': 3867,
#  'makes': 4328,
#  'history': 3400,
#  'declares': 1930,
#  'democratic': 1979,
#  'race': 5690,
#  'hillary': 3385,
#  'criminally': 1784,
#  'charged': 1302,
#  'students': 6871,
#  'arrested': 537,
#  'calif': 1127,
#  'school': 6264,
#  'shooting': 6450,
#  'plot': 5332,
#  'hawaii': 3297,
#  '205m': 69,
#  'critics': 1793,
#  'fear': 2737,
#  'complete': 1541,
#  'waste': 7732,
#  'south': 6655,
#  'carolina': 1191,
#  'black': 855,
#  'feelin': 2759,
#  'bern': 798,
#  'voter': 7665,
#  'listens': 4211,
#  'carefully': 1182,
#  'national': 4751,
#  'unity': 7470,
#  'sets': 6376,
#  'aryan': 552,
#  'website': 7762,
#  'huge': 3487,
#  'trouble': 7350,
#  'noticed': 4870,
#  'sick': 6485,
#  'thing': 7161,
#  'hidden': 3364,
#  'picture': 5265,
#  'liberty': 4166,
#  'writers': 7892,
#  'news': 4819,
#  'taking': 7045,
#  'presidential': 5472,
#  'power': 5421,
#  'shot': 6465,
#  'detroit': 2058,
#  'airport': 339,
#  'new': 4816,
#  'control': 1650,
#  'travelers': 7305,
#  'message': 4501,
#  'fellow': 2766,
#  'republicans': 5954,
#  'love': 4270,
#  'hate': 3286,
#  'revolution': 6038,
#  'establishment': 2532,
#  'holds': 3413,
#  'point': 5345,
#  'lead': 4096,
#  'despite': 2035,
#  'probe': 5523,
#  'update': 7509,
#  'axelrod': 643,
#  'slow': 6568,
#  'motion': 4657,
#  'implosion': 3589,
#  'day': 1885,
#  'israel': 3801,
#  'ancient': 417,
#  'papyrus': 5122,
#  'proves': 5603,
#  'jerusalem': 3850,
#  'belongs': 785,
#  'controlled': 1651,
#  'mossad': 4654,
#  '250': 82,
#  '000': 1,
#  'year': 7916,
#  'old': 4963,
#  'artifact': 549,
#  'ultimate': 7422,
#  'evidence': 2561,
#  'astronaut': 582,
#  'technology': 7095,
#  'romney': 6119,
#  'timely': 7204,
#  'trolling': 7344,
#  'possible': 5399,
#  'saudi': 6225,
#  'king': 3984,
#  'tried': 7331,
#  'jasta': 3834,
#  'law': 4082,
#  'koch': 4010,
#  'brothers': 1047,
#  'battle': 737,
#  'prevent': 5484,
#  'dark': 1869,
#  'disclosure': 2130,
#  'dakota': 1852,
#  'jail': 3821,
#  'time': 7202,
#  'muslim': 4715,
#  'migrant': 4528,
#  'dumped': 2315,
#  'baby': 650,
#  'road': 6095,
#  'left': 4121,
#  'tea': 7083,
#  'congressman': 1592,
#  'just': 3920,
#  'called': 1129,
#  'armed': 528,
#  'uprising': 7516,
#  'loses': 4257,
#  'nazi': 4765,
#  'shocking': 6443,
#  'truths': 7376,
#  'according': 205,
#  'fact': 2662,
#  'checking': 1326,
#  'rules': 6150,
#  'wall': 7694,
#  'street': 6848,
#  'journal': 3894,
#  'exposed': 2631,
#  'exactly': 2569,
#  'cost': 1701,
#  'bribe': 1014,
#  'avoid': 628,
#  'charges': 1304,
#  'carly': 1186,
#  'fiorina': 2823,
#  'swipes': 7010,
#  'look': 4241,
#  'face': 2655,
#  'defying': 1954,
#  'politics': 5368,
#  'footage': 2906,
#  'operation': 4991,
#  'jump': 3911,
#  'hitler': 3402,
#  'clash': 1403,
#  'khans': 3964,
#  'signs': 6500,
#  'cultural': 1827,
#  'divide': 2192,
#  'real': 5772,
#  'november': 4877,
#  'surprise': 6966,
#  'information': 3657,
#  'white': 7794,
#  'easter': 2344,
#  'egg': 2378,
#  'roll': 6112,
#  'exists': 2594,
#  'congress': 1590,
#  'banned': 705,
#  'fun': 3002,
#  'cameron': 1138,
#  'press': 5474,
#  'obama': 4910,
#  'tech': 7093,
#  'encryption': 2449,
#  'barack': 711,
#  'oh': 4955,
#  'bummer': 1086,
#  'debt': 1909,
#  'paula': 5177,
#  'jones': 3887,
#  'teachable': 7085,
#  'arabia': 509,
#  'economic': 2353,
#  'united': 7468,
#  'states': 6771,
#  'homicides': 3430,
#  '55': 131,
#  'percent': 5211,
#  'chicago': 1340,
#  'stays': 6783,
#  'vibrant': 7604,
#  'ewao': 2566,
#  'stephen': 6796,
#  'hawking': 3299,
#  'warns': 7718,
#  'stop': 6822,
#  'searching': 6299,
#  'aliens': 362,
#  'late': 4066,
#  '2016': 62,
#  'state': 6769,
#  'union': 7464,
#  'address': 248,
#  'comment': 1511,
#  'india': 3626,
#  'moves': 4673,
#  'severely': 6382,
#  'restrict': 6001,
#  'use': 7533,
#  'cash': 1206,
#  'forcing': 2917,
#  'economy': 2358,
#  'barter': 721,
#  'bugs': 1070,
#  'bunny': 1088,
#  'names': 4733,
#  'apparent': 483,
#  'vice': 7606,
#  'possibilities': 5397,
#  'twitter': 7406,
#  'panic': 5113,
#  'worried': 7875,
#  'carson': 1199,
#  'myths': 4725,
#  'men': 4484,
#  'believe': 777,
#  'southeast': 6656,
#  'asia': 558,
#  'unprecedented': 7487,
#  'letter': 4147,
#  'chair': 1273,
#  'chiefs': 1343,
#  'suggests': 6921,
#  'military': 4538,
#  'does': 2211,
#  'mess': 4500,
#  'created': 1765,
#  'brutal': 1054,
#  'anti': 457,
#  'ad': 240,
#  'highlights': 3373,
#  'plausibly': 5314,
#  'endorse': 2457,
#  '32': 101,
#  'emails': 2415,
#  'recovered': 5817,
#  'irs': 3786,
#  'targeting': 7068,
#  'amid': 401,
#  'allegations': 370,
#  'agency': 304,
#  'lied': 4173,
#  '20': 49,
#  'tweet': 7398,
#  'storm': 6828,
#  'saturday': 6223,
#  'continues': 1638,
#  'mock': 4595,
#  'friday': 2981,
#  'meltdown': 4473,
#  'arkansas': 526,
#  'north': 4862,
#  'legalize': 4127,
#  'medical': 4458,
#  'marijuana': 4377,
#  'federal': 2752,
#  'prohibition': 5550,
#  'fox': 2948,
#  'self': 6326,
#  'destructing': 2043,
#  'islamophobia': 3795,
#  'reagan': 5771,
#  'roger': 6109,
#  'ailes': 329,
#  'humiliation': 3495,
#  'sanders': 6208,
#  'split': 6706,
#  'votes': 7667,
#  'tuesday': 7382,
#  'primaries': 5496,
#  'giuliani': 3095,
#  'exoneration': 2598,
#  'supposed': 6952,
#  'country': 1723,
#  'justice': 3921,
#  'liberal': 4161,
#  'media': 4457,
#  'mocks': 4598,
#  'candidates': 1156,
#  'clown': 1445,
#  'car': 1173,
#  'diss': 2175,
#  '2006': 55,
#  'audio': 605,
#  'captures': 1172,
#  'proposing': 5574,
#  'rig': 6066,
#  'palestine': 5103,
#  'tough': 7250,
#  'guy': 3223,
#  'reconsider': 5810,
#  'debate': 1904,
#  'unhealthy': 7460,
#  'jobs': 3868,
#  'campaign': 1140,
#  'divisive': 2198,
#  'future': 3017,
#  'puts': 5652,
#  '00pm': 2,
#  'water': 7737,
#  'cooler': 1668,
#  '11': 12,
#  'secure': 6312,
#  'cellphone': 1247,
#  'renowned': 5922,
#  'harvard': 3282,
#  'psychologist': 5620,
#  'adhd': 252,
#  'largely': 4058,
#  'fraud': 2965,
#  'doubts': 2247,
#  'rise': 6084,
#  'report': 5941,
#  'freddie': 2969,
#  'gray': 3165,
#  'injured': 3669,
#  'raise': 5711,
#  'wage': 7680,
#  'paul': 5176,
#  'krugman': 4020,
#  'shatters': 6416,
#  'myth': 4724,
#  'afford': 291,
#  'workers': 7866,
#  'pay': 5182,
#  'nuclear': 4881,
#  'deal': 1895,
#  'reached': 5758,
#  'iran': 3773,
#  'free': 2971,
#  'jason': 3833,
#  'rezaian': 6043,
#  'venezuela': 7580,
#  'throws': 7182,
#  'towel': 7257,
#  'hyperinflation': 3518,
#  'print': 5506,
#  '200x': 59,
#  'higher': 3370,
#  'denominated': 1992,
#  'bills': 831,
#  'judith': 3906,
#  'miller': 4544,
#  'unsaid': 7491,
#  'speech': 6682,
#  'matters': 4430,
#  'pro': 5520,
#  'palestinian': 5104,
#  'propaganda': 5565,
#  'lowering': 4277,
#  'standards': 6754,
#  'takeaways': 7040,
#  'wrong': 7896,
#  'terrorism': 7127,
#  'immigration': 3572,
#  'shortage': 6459,
#  'lethal': 4145,
#  'injection': 3668,
#  'drugs': 2301,
#  'death': 1900,
#  'penalty': 5201,
#  'supreme': 6956,
#  'quid': 5677,
#  'quo': 5687,
#  'wikileaks': 7808,
#  'reveals': 6025,
#  'eyeing': 2651,
#  'ryan': 6178,
#  'relative': 5886,
#  'lenore': 4135,
#  'lee': 4120,
#  'unified': 7461,
#  'fractured': 2951,
#  'bombshell': 933,
#  'leaked': 4104,
#  'expose': 2630,
#  'muslims': 4716,
#  'got': 3139,
#  'administration': 255,
#  '14': 22,
#  'islamic': 3794,
#  'rebels': 5784,
#  'philippines': 5248,
#  'embrace': 2421,
#  'putin': 5650,
#  'morale': 4641,
#  'wait': 7682,
#  'baltimore': 694,
#  'riots': 6080,
#  'reshape': 5971,
#  'attorney': 602,
#  'general': 3057,
#  'loretta': 4252,
#  'lynch': 4293,
#  'agenda': 305,
#  'miami': 4518,
#  'break': 997,
#  'lays': 4093,
#  'tougher': 7251,
#  'worldview': 7874,
#  'loony': 4247,
#  'pseudo': 5616,
#  'christian': 1362,
#  'liberals': 4162,
#  'using': 7539,
#  'witchcraft': 7839,
#  'fog': 2893,
#  'christians': 1364,
#  'heads': 3312,
#  'video': 7614,
#  'google': 3135,
#  'deep': 1935,
#  'search': 6298,
#  'instead': 3694,
#  'brace': 981,
#  'results': 6003,
#  'john': 3873,
#  'mccain': 4437,
#  'withdraws': 7842,
#  'donald': 2228,
#  'best': 803,
#  'hispanics': 3397,
#  'walking': 7692,
#  'bomb': 928,
#  'don': 2227,
#  'fooled': 2904,
#  'victory': 7613,
#  'implode': 3585,
#  'quality': 5661,
#  'care': 1179,
#  'vets': 7600,
#  'important': 3591,
#  'times': 7205,
#  'va': 7544,
#  'illuminati': 3559,
#  'card': 1176,
#  'harbinger': 3271,
#  'things': 7162,
#  'come': 1498,
#  'man': 4344,
#  'son': 6633,
#  'illegal': 3554,
#  'immigrant': 3570,
#  'files': 2799,
#  'suits': 6926,
#  'feds': 2755,
#  'comey': 1502,
#  'foundation': 2942,
#  'connection': 1595,
#  'brink': 1031,
#  'uk': 7417,
#  'sends': 6343,
#  'tanks': 7060,
#  'drones': 2290,
#  '800': 156,
#  'soldiers': 6626,
#  'russian': 6170,
#  'border': 949,
#  'tensions': 7117,
#  'grow': 3189,
#  'actually': 238,
#  'did': 2076,
#  'million': 4545,
#  'waiting': 7684,
#  'elect': 2390,
#  '40': 113,
#  'detained': 2048,
#  'venezuelan': 7581,
#  'opposition': 5006,
#  'protests': 5600,
#  'wife': 7804,
#  'jihadist': 3860,
#  'wounded': 7885,
#  '100': 8,
#  'orlando': 5033,
#  'nightclub': 4839,
#  'massacre': 4409,
#  'knew': 4002,
#  'city': 1387,
#  'suvs': 6989,
#  'safe': 6191,
#  'field': 2785,
#  'rips': 6083,
#  'executive': 2588,
#  'action': 228,
#  'tighten': 7198,
#  'gun': 3212,
#  'laws': 4087,
#  'indoor': 3637,
#  'gardening': 3037,
#  'easy': 2346,
#  'nutritower': 4896,
#  'collective': 1476,
#  'evolutiongardening': 2564,
#  'business': 1103,
#  'walmart': 7697,
#  'boosts': 947,
#  'minimum': 4552,
#  'hour': 3473,
#  'view': 7618,
#  'isis': 3791,
#  'generals': 3059,
#  'choosing': 1356,
#  'leave': 4111,
#  'permanently': 5219,
#  'moderate': 4601,
#  'indonesia': 3636,
#  'protest': 5593,
#  'governor': 3147,
#  'turns': 7395,
#  'violent': 7631,
#  'demand': 1973,
#  'blasphemed': 869,
#  'islam': 3792,
#  'radio': 5701,
#  'derb': 2021,
#  'transcript': 7286,
#  'october': 4937,
#  '21': 71,
#  'magic': 4310,
#  'bricks': 1017,
#  'ps': 5615,
#  '199': 41,
#  'et': 2535,
#  'cetera': 1269,
#  'll': 4220,
#  'decide': 1922,
#  'biden': 816,
#  'probably': 5522,
#  'won': 7853,
#  'beat': 749,
#  'run': 6156,
#  'women': 7852,
#  'problem': 5525,
#  'woes': 7848,
#  'intensify': 3712,
#  'questions': 5675,
#  'melania': 4471,
#  'visa': 7639,
#  'happened': 3266,
#  'chairman': 1274,
#  'podesta': 5341,
#  'paid': 5096,
#  'month': 4632,
#  'banker': 701,
#  'ties': 7195,
#  'financial': 2812,
#  'crisis': 1789,
#  '33': 102,
#  'missing': 4574,
#  'cruz': 1818,
#  'thrilled': 7179,
#  'drop': 2291,
#  'iowa': 3769,
#  'poll': 5369,
#  'lies': 4174,
#  'begins': 763,
#  'legend': 4130,
#  'art': 546,
#  'cashin': 1207,
#  'presidency': 5470,
#  'world': 7872,
#  'order': 5014,
#  'gold': 3126,
#  'great': 3166,
#  'depression': 2013,
#  'peacenik': 5195,
#  'nude': 4882,
#  'emerged': 2423,
#  'ayahuasca': 645,
#  'tent': 7118,
#  'visions': 7641,
#  'fate': 2725,
#  'threatens': 7177,
#  'representative': 5949,
#  'firing': 2830,
#  'squad': 6727,
#  'nypd': 4903,
#  'source': 6653,
#  'weiner': 7772,
#  'laptop': 4055,
#  'away': 636,
#  'better': 806,
#  'borders': 950,
#  'applies': 494,
#  'chlorine': 1350,
#  'aleppo': 354,
#  'interview': 3730,
#  'socrates': 6618,
#  'empire': 2435,
#  'near': 4773,
#  'fools': 2905,
#  'change': 1286,
#  'poland': 5352,
#  'establishing': 2531,
#  'territorial': 7125,
#  'force': 2914,
#  'fight': 2790,
#  'nasa': 4747,
#  'films': 2807,
#  'ufo': 7414,
#  'flying': 2888,
#  'past': 5159,
#  'powers': 5425,
#  'agree': 316,
#  'inside': 3684,
#  'deliberations': 1967,
#  'launch': 4076,
#  'delivers': 1969,
#  'emotional': 2433,
#  'eulogy': 2542,
#  'beau': 753,
#  'talks': 7052,
#  'wire': 7833,
#  '50': 125,
#  'chance': 1284,
#  'success': 6903,
#  '17': 28,
#  'records': 5814,
#  'deadliest': 1891,
#  'celebrate': 1241,
#  'halloween': 3238,
#  'math': 4422,
#  'surging': 6965,
#  'polls': 5371,
#  'denial': 1985,
#  'china': 1348,
#  'trigger': 7333,
#  'global': 3107,
#  'recession': 5798,
#  'mega': 4467,
#  'donors': 2236,
#  'helped': 3346,
#  'billion': 827,
#  'cory': 1698,
#  'booker': 941,
#  'criminal': 1781,
#  'destroys': 2041,
#  'american': 398,
#  'dream': 2273,
#  'leads': 4101,
#  'nationally': 4753,
#  'weaker': 7747,
#  'hold': 3410,
#  'busted': 1106,
#  'directly': 2110,
#  'tied': 7193,
#  'steal': 6786,
#  'toxic': 7261,
#  'chemicals': 1335,
#  'children': 1346,
#  'makeup': 4329,
#  'study': 6873,
#  'project': 5551,
#  'veritas': 7587,
#  'pac': 5084,
#  'accepts': 199,
#  'foreign': 2922,
#  'donations': 2231,
#  'balance': 683,
#  'hopeful': 3448,
#  'tone': 7229,
#  'argument': 518,
#  'nigel': 4836,
#  'farage': 2703,
#  'held': 3339,
#  'heathrow': 3327,
#  'return': 6017,
#  'visit': 7642,
#  'mysterious': 4720,
#  'brown': 1050,
#  'substance': 6896,
#  'nose': 4865,
#  'revealing': 6024,
#  'predicts': 5446,
#  'massive': 4412,
#  'intends': 3710,
#  'eliminate': 2406,
#  'years': 7917,
#  'okay': 4960,
#  'act': 226,
#  'like': 4185,
#  'onion': 4975,
#  'finest': 2818,
#  'cleveland': 1420,
#  'department': 1997,
#  'reach': 5757,
#  'policing': 5359,
#  'adopts': 262,
#  'landmark': 4046,
#  'resolution': 5980,
#  'calling': 1130,
#  'ban': 695,
#  'weapons': 7753,
#  'dueling': 2309,
#  'dc': 1887,
#  'speeches': 6683,
#  'running': 6159,
#  'award': 634,
#  'journalist': 3896,
#  'exposes': 2632,
#  'true': 7357,
#  'origin': 5029,
#  'supporters': 6949,
#  'osmanisnin': 5038,
#  'swing': 7009,
#  'vanishing': 7567,
#  'presstv': 5477,
#  'nato': 4757,
#  'pushes': 5649,
#  'buildup': 1075,
#  'plans': 5307,
#  'russia': 6169,
#  'breaking': 999,
#  'gets': 3078,
#  'warrant': 7720,
#  'computer': 1548,
#  'gary': 3040,
#  'johnson': 3874,
#  'weld': 7775,
#  'shift': 6425,
#  'focus': 2890,
#  'answering': 450,
#  'outside': 5057,
#  'debates': 1905,
#  'zarif': 7943,
#  'lavrov': 4081,
#  'syria': 7025,
#  'moscow': 4651,
#  'bush': 1101,
#  'answers': 451,
#  'second': 6306,
#  'ex': 2567,
#  'assistant': 576,
#  'director': 2111,
#  'calls': 1131,
#  'clintons': 1431,
#  'crime': 1778,
#  'family': 2692,
#  'claims': 1396,
#  'cesspool': 1267,
#  'agrees': 318,
#  'provide': 5604,
#  'private': 5516,
#  'mail': 4318,
#  'server': 6365,
#  'miss': 4569,
#  'syrian': 7026,
#  'air': 335,
#  'space': 6662,
#  'pills': 5273,
#  'chat': 1316,
#  'hand': 3250,
#  'girl': 3092,
#  'told': 7223,
#  'talk': 7050,
#  'wundergroundmusic': 7902,
#  'com': 1494,
#  'reinventing': 5879,
#  'image': 3561,
#  'secret': 6308,
#  'memo': 4481,
#  'admits': 259,
#  'obvious': 4924,
#  '12': 16,
#  '63': 141,
#  'minute': 4559,
#  'videos': 7615,
#  'connects': 1596,
#  'false': 2686,
#  'flag': 2841,
#  'really': 5776,
#  'masters': 4416,
#  'offer': 4942,
#  'choice': 1351,
#  'right': 6069,
#  'arms': 531,
#  '01': 3,
#  'rogue': 6110,
#  'hot': 3470,
#  'dogs': 2214,
#  'bacon': 666,
#  'processed': 5530,
#  'meats': 4454,
#  'cause': 1227,
#  'cancer': 1151,
#  'organization': 5023,
#  'makeover': 4326,
#  'latest': 4068,
#  'long': 4239,
#  'line': 4198,
#  'resets': 5970,
#  'ohio': 4956,
#  '170': 29,
#  'deadly': 1894,
#  'biker': 824,
#  'gang': 3032,
#  'shootout': 6452,
#  'texas': 7142,
#  'restaurant': 5995,
#  'patience': 5169,
#  'respond': 5988,
#  'usa': 7531,
#  'rudeness': 6143,
#  'climate': 1424,
#  'leader': 4097,
#  'plan': 5302,
#  'measures': 4452,
#  'france': 2958,
#  'screams': 6285,
#  'master': 4413,
#  'allah': 367,
#  'punches': 5633,
#  'teacher': 7086,
#  'pupils': 5637,
#  'wow': 7886,
#  'josh': 3892,
#  'earnest': 2336,
#  'admitted': 260,
#  'stunning': 6881,
#  'jesse': 3851,
#  'matthew': 4431,
#  'hannah': 3263,
#  'graham': 3157,
#  'slaying': 6550,
#  'progress': 5547,
#  'drone': 2289,
#  'program': 5546,
#  'transparency': 7297,
#  'digital': 2089,
#  'wins': 7830,
#  'travel': 7304,
#  'conor': 1597,
#  'mcgregor': 4443,
#  'guide': 3206,
#  'york': 7928,
#  'driving': 2288,
#  'taxi': 7079,
#  'seven': 6380,
#  'cents': 1258,
#  '67': 144,
#  'mile': 4533,
#  'mckinsey': 4446,
#  'footnote': 2909,
#  'jtmcphee': 3899,
#  ...}

# %%
cv.inverse_transform(count_train2)
# Out:
# [array(['truth', 'moment', 'america', 'election', 'trump', 'brexit',
#         'condell', 'pat', 'englishman', 'refers', 'reader'],
#        dtype='<U18'), array(['office', 'sayers', 'doom', 'think', 'trump'],
#        dtype='<U18'), array(['endgame', 'california', 'bernie'],
#        dtype='<U18'), array(['say', 'chandler', 'kyle', 'garcia', 'lorena', 'neeson', 'liam',
#         'said'],
#        dtype='<U18'), array(['rotting', 'fargo', 'wells'],
#        dtype='<U18'), array(['challenge', 'party', 'mount', 'gop', 'trump'],
#        dtype='<U18'), array(['limits', 'warned', 'turkey', 'afar', 'tal', 'close', 'says',
#         'militia', 'shiite'],
#        dtype='<U18'), array(['police', 'logic', 'racist', 'funding', 'privatization', 'cops',
#         'killer', 'money', 'blood', 'america'],
#        dtype='<U18'), array(['raids', 'killed', 'terrorists', 'attack', 'hebdo', 'charlie'],
#        dtype='<U18'), array(['health', 'boost', 'foods', 'eaten', 'mixology', 'food'],
#        dtype='<U18'), array(['delegate', 'republican', 'support', 'win', 'campaigns', 'far'],
#        dtype='<U18'), array(['elected', 'fbi', 'pointless', 'scrap', 'promises', 'clinton'],
#        dtype='<U18'), array(['hope', 'house', 'weekend', 'california', 'bernie'],
#        dtype='<U18'), array(['changed', 'views', 'today', 'president', 'want', 'voters'],
#        dtype='<U18'), array(['rock', 'standing', 'thanksgiving'],
#        dtype='<U18'), array(['obamacare', 'gaming'],
#        dtype='<U18'), array(['courts', 'people', 'demented', 'set', 'brexiters'],
#        dtype='<U18'), array(['correctness', 'political', 'war', 'winning', 'trump'],
#        dtype='<U18'), array(['joint', 'perfect', 'rolling', 'steps', '10', 'life'],
#        dtype='<U18'), array(['online', 'blows', 'threat', 'advisor', 'sex', 'kelly', 'megyn',
#         'attacks', 'gingrich', 'trump'],
#        dtype='<U18'), array(['attackers', 'toe', 'goes', 'chief', 'parenthood'],
#        dtype='<U18'), array(['cases', 'big', 'slate', 'end', 'term', 'court', 'high', 'docket',
#         'drama', 'set'],
#        dtype='<U18'), array(['blankets', 'emergency', 'mylar', 'saving', 'uses', 'alternative',
#         '28', 'life'],
#        dtype='<U18'), array(['16', '29', 'boulevard', 'hollywood', 'rally', '10', 'trump'],
#        dtype='<U18'), array(['university', 'kenya', 'dead', '147', 'terror', 'attack'],
#        dtype='<U18'), array(['job', 'months', 'email', 'personal', 'used', 'carter', 'secretary',
#         'defense'],
#        dtype='<U18'), array(['race', 'democratic', 'declares', 'history', 'makes', 'clinton',
#         'win'],
#        dtype='<U18'), array(['charged', 'criminally', 'hillary', 'election', 'trump'],
#        dtype='<U18'), array(['plot', 'shooting', 'school', 'calif', 'arrested', 'students'],
#        dtype='<U18'), array(['waste', 'complete', 'fear', 'critics', '205m', 'hawaii', 'life',
#         'obamacare', 'support'],
#        dtype='<U18'), array(['bern', 'feelin', 'black', 'carolina', 'south', 'voters'],
#        dtype='<U18'), array(['website', 'aryan', 'sets', 'unity', 'national', 'carefully',
#         'listens', 'voter', 'trump'],
#        dtype='<U18'), array(['news', 'writers', 'liberty', 'picture', 'hidden', 'thing', 'sick',
#         'noticed', 'trouble', 'huge', 'hillary', 'clinton', 'america'],
#        dtype='<U18'), array(['power', 'presidential', 'taking'],
#        dtype='<U18'), array(['travelers', 'control', 'new', 'airport', 'detroit', 'shot', 'news',
#         'uses'],
#        dtype='<U18'), array(['republicans', 'fellow', 'message'],
#        dtype='<U18'), array(['establishment', 'revolution', 'hate', 'love', 'trump'],
#        dtype='<U18'), array(['update', 'probe', 'despite', 'lead', 'point', 'holds', 'hillary',
#         'fbi', 'clinton'],
#        dtype='<U18'), array(['implosion', 'motion', 'slow', 'axelrod', 'republican', 'party'],
#        dtype='<U18'), array(['day', 'lead', 'hillary', 'clinton', 'election'],
#        dtype='<U18'), array(['belongs', 'jerusalem', 'proves', 'papyrus', 'ancient', 'israel'],
#        dtype='<U18'), array(['mossad', 'controlled', 'trump'],
#        dtype='<U18'), array(['technology', 'astronaut', 'evidence', 'ultimate', 'artifact',
#         'old', 'year', '000', '250', 'ancient'],
#        dtype='<U18'), array(['trolling', 'timely', 'romney', 'trump'],
#        dtype='<U18'), array(['law', 'jasta', 'tried', 'king', 'saudi', 'possible', 'courts'],
#        dtype='<U18'), array(['dakota', 'disclosure', 'dark', 'prevent', 'battle', 'brothers',
#         'koch', 'south', 'money'],
#        dtype='<U18'), array(['left', 'road', 'baby', 'dumped', 'migrant', 'muslim', 'time',
#         'jail', 'dead'],
#        dtype='<U18'), array(['loses', 'uprising', 'armed', 'called', 'just', 'congressman',
#         'tea', 'party', 'trump'],
#        dtype='<U18'), array(['rules', 'checking', 'fact', 'according', 'truths', 'shocking',
#         'nazi', 'trump'],
#        dtype='<U18'), array(['charges', 'avoid', 'bribe', 'cost', 'exactly', 'exposed',
#         'journal', 'street', 'wall', 'just', 'hillary', 'fbi'],
#        dtype='<U18'), array(['face', 'look', 'swipes', 'fiorina', 'carly', 'trump'],
#        dtype='<U18'), array(['politics', 'defying', 'fear'],
#        dtype='<U18'), array(['hitler', 'jump', 'operation', 'footage', 'high'],
#        dtype='<U18'), array(['divide', 'cultural', 'signs', 'khans', 'clash', 'new', 'political',
#         'trump'],
#        dtype='<U18'), array(['information', 'surprise', 'november', 'real', 'hillary', 'fbi',
#         'clinton'],
#        dtype='<U18'), array(['fun', 'banned', 'congress', 'exists', 'roll', 'egg', 'easter',
#         'white', 'house'],
#        dtype='<U18'), array(['encryption', 'tech', 'obama', 'press', 'cameron', 'set'],
#        dtype='<U18'), array(['bummer', 'oh', 'barack', 'obama', 'president'],
#        dtype='<U18'), array(['jones', 'paula', 'debt'],
#        dtype='<U18'), array(['states', 'united', 'economic', 'arabia', 'teachable', 'saudi',
#         'threat', 'moment'],
#        dtype='<U18'), array(['vibrant', 'stays', 'chicago', 'percent', '55', 'homicides'],
#        dtype='<U18'), array(['late', 'aliens', 'searching', 'stop', 'warns', 'hawking',
#         'stephen', 'ewao'],
#        dtype='<U18'), array(['address', 'union', 'state', '2016', 'barack', 'obama', 'checking',
#         'fact'],
#        dtype='<U18'), array(['bunny', 'bugs', 'barter', 'economy', 'forcing', 'cash', 'use',
#         'restrict', 'severely', 'moves', 'india', 'comment'],
#        dtype='<U18'), array(['twitter', 'possibilities', 'vice', 'apparent', 'names',
#         'presidential', 'trump'],
#        dtype='<U18'), array(['carson', 'worried', 'panic', 'time', 'establishment', 'win', 'gop',
#         'trump'],
#        dtype='<U18'), array(['asia', 'southeast', 'believe', 'men', 'myths'],
#        dtype='<U18'), array(['does', 'military', 'suggests', 'chiefs', 'chair', 'letter',
#         'unprecedented', 'hillary', 'joint', 'president', 'want'],
#        dtype='<U18'), array(['endorse', 'plausibly', 'highlights', 'ad', 'anti', 'brutal',
#         'created', 'mess', 'republicans', 'new', 'clinton', 'gop', 'trump'],
#        dtype='<U18'), array(['lied', 'agency', 'allegations', 'amid', 'targeting', 'irs',
#         'recovered', 'emails', '32', '000', 'probe', 'chief'],
#        dtype='<U18'), array(['meltdown', 'friday', 'mock', 'continues', 'saturday', 'storm',
#         'tweet', '20', 'clinton', 'trump'],
#        dtype='<U18'), array(['prohibition', 'federal', 'marijuana', 'medical', 'legalize',
#         'north', 'arkansas', 'dakota', 'despite', 'voters'],
#        dtype='<U18'), array(['humiliation', 'ailes', 'roger', 'reagan', 'islamophobia',
#         'destructing', 'self', 'fox', 'obama', 'new', 'news', 'moment'],
#        dtype='<U18'), array(['primaries', 'tuesday', 'votes', 'split', 'sanders', 'clinton'],
#        dtype='<U18'), array(['justice', 'country', 'supposed', 'exoneration', 'giuliani',
#         'hillary', 'fbi'],
#        dtype='<U18'), array(['diss', 'car', 'clown', 'candidates', 'mocks', 'media', 'liberal',
#         'presidential', 'republican'],
#        dtype='<U18'), array(['palestine', 'rig', 'proposing', 'captures', 'audio', '2006',
#         'hillary', 'clinton', 'election'],
#        dtype='<U18'), array(['debate', 'reconsider', 'guy', 'tough', 'sanders', 'says', 'trump'],
#        dtype='<U18'), array(['jobs', 'unhealthy', 'america'],
#        dtype='<U18'), array(['future', 'divisive', 'campaign', '2016', 'says'],
#        dtype='<U18'), array(['puts', 'debate', 'defense', 'clinton', 'trump'],
#        dtype='<U18'), array(['11', 'cooler', 'water', '00pm', '2016'],
#        dtype='<U18'), array(['cellphone', 'secure'],
#        dtype='<U18'), array(['fraud', 'largely', 'adhd', 'psychologist', 'harvard', 'renowned',
#         'says'],
#        dtype='<U18'), array(['injured', 'gray', 'freddie', 'report', 'rise', 'doubts'],
#        dtype='<U18'), array(['pay', 'workers', 'afford', 'myth', 'shatters', 'krugman', 'paul',
#         'wage', 'raise', 'boost'],
#        dtype='<U18'), array(['rezaian', 'jason', 'free', 'iran', 'reached', 'deal', 'nuclear'],
#        dtype='<U18'), array(['bills', 'denominated', 'higher', '200x', 'print', 'hyperinflation',
#         'towel', 'throws', 'venezuela'],
#        dtype='<U18'), array(['matters', 'speech', 'unsaid', 'miller', 'judith', 'left', 'trump'],
#        dtype='<U18'), array(['standards', 'lowering', 'propaganda', 'palestinian', 'pro',
#         'truth', 'america'],
#        dtype='<U18'), array(['takeaways', 'debate', 'democratic'],
#        dtype='<U18'), array(['immigration', 'terrorism', 'wrong', 'trump'],
#        dtype='<U18'), array(['supreme', 'penalty', 'death', 'drugs', 'injection', 'lethal',
#         'shortage', 'court'],
#        dtype='<U18'), array(['lee', 'lenore', 'relative', 'ryan', 'eyeing', 'reveals',
#         'wikileaks', 'quo', 'quid', 'supreme', 'pro', 'paul', 'campaign',
#         'comment', 'email', 'court', 'clinton'],
#        dtype='<U18'), array(['fractured', 'unified', 'ryan', 'paul', 'gop'],
#        dtype='<U18'), array(['administration', 'got', 'muslims', 'expose', 'leaked', 'bombshell',
#         'emails', 'obama'],
#        dtype='<U18'), array(['philippines', 'rebels', 'islamic', '14', 'dead', 'attack'],
#        dtype='<U18'), array(['putin', 'embrace', 'continues', 'trump'],
#        dtype='<U18'), array(['agenda', 'lynch', 'loretta', 'general', 'attorney', 'reshape',
#         'riots', 'baltimore', 'wait', 'morale', 'police'],
#        dtype='<U18'), array(['miami', 'takeaways', 'debate', 'republican'],
#        dtype='<U18'), array(['worldview', 'tougher', 'lays', 'break', 'obama', 'clinton'],
#        dtype='<U18'), array(['video', 'heads', 'christians', 'fog', 'witchcraft', 'using',
#         'liberals', 'christian', 'pseudo', 'loony', 'says'],
#        dtype='<U18'), array(['results', 'brace', 'instead', 'search', 'deep', 'google'],
#        dtype='<U18'), array(['donald', 'withdraws', 'mccain', 'john', 'support', 'trump'],
#        dtype='<U18'), array(['hispanics', 'best', 'debate', 'sanders', 'clinton'],
#        dtype='<U18'), array(['implode', 'victory', 'fooled', 'don', 'bomb', 'walking',
#         'campaign', 'time', 'moment', 'trump'],
#        dtype='<U18'), array(['va', 'times', 'important', 'vets', 'care', 'quality', 'wait',
#         'secretary', 'says'],
#        dtype='<U18'), array(['come', 'things', 'harbinger', 'card', 'illuminati'],
#        dtype='<U18'), array(['feds', 'suits', 'files', 'immigrant', 'illegal', 'son', 'man',
#         'killed'],
#        dtype='<U18'), array(['connection', 'foundation', 'comey', 'clinton'],
#        dtype='<U18'), array(['grow', 'tensions', 'border', 'russian', 'soldiers', '800',
#         'drones', 'tanks', 'sends', 'uk', 'brink', 'war'],
#        dtype='<U18'), array(['did', 'actually', 'things', 'congress', 'year'],
#        dtype='<U18'), array(['elect', 'waiting', 'million', 'hillary', 'dead', 'voters',
#         'clinton'],
#        dtype='<U18'), array(['protests', 'opposition', 'venezuelan', 'detained', '40', 'injured',
#         '20'],
#        dtype='<U18'), array(['knew', 'massacre', 'nightclub', 'orlando', '100', 'wounded',
#         'jihadist', 'wife', 'muslim', 'killed', 'says'],
#        dtype='<U18'), array(['city', 'presidential', 'sex'],
#        dtype='<U18'), array(['safe', 'suvs', 'video', 'shocking', 'think'],
#        dtype='<U18'), array(['laws', 'gun', 'tighten', 'action', 'executive', 'rips', 'field',
#         'obama', 'control', 'gop'],
#        dtype='<U18'), array(['business', 'evolutiongardening', 'collective', 'nutritower',
#         'easy', 'gardening', 'indoor', 'uk', 'comment', 'news'],
#        dtype='<U18'), array(['hour', 'minimum', 'boosts', 'walmart', 'wage'],
#        dtype='<U18'), array(['generals', 'isis', 'view', 'putin', 'clinton', 'trump'],
#        dtype='<U18'), array(['permanently', 'leave', 'choosing', 'states', 'united', 'people'],
#        dtype='<U18'), array(['islam', 'blasphemed', 'demand', 'violent', 'turns', 'governor',
#         'protest', 'indonesia', 'moderate', '100', 'christian', 'muslims',
#         'death', '000'],
#        dtype='<U18'), array(['cetera', 'et', '199', 'ps', 'bricks', 'magic', '21', 'october',
#         'transcript', 'derb', 'radio'],
#        dtype='<U18'), array(['decide', 'll', '2016', 'year', 'clinton', 'says'],
#        dtype='<U18'), array(['run', 'beat', 'won', 'probably', 'biden', 'clinton'],
#        dtype='<U18'), array(['problem', 'women', 'trump'],
#        dtype='<U18'), array(['happened', 'visa', 'melania', 'questions', 'intensify', 'woes',
#         'campaign', 'amid', 'trump'],
#        dtype='<U18'), array(['crisis', 'financial', 'ties', 'banker', 'month', 'paid', 'podesta',
#         'chairman', 'run', 'foundation', 'john', 'cash', '000'],
#        dtype='<U18'), array(['missing', '33', 'emails', '000', 'hillary'],
#        dtype='<U18'), array(['poll', 'iowa', 'drop', 'thrilled', 'cruz', 'despite'],
#        dtype='<U18'), array(['begins', 'lies', 'knew', 'end', 'clinton'],
#        dtype='<U18'), array(['depression', 'great', 'gold', 'order', 'world', 'presidency',
#         'cashin', 'art', 'legend', 'panic', 'new', 'trump', 'brexit'],
#        dtype='<U18'), array(['peacenik', 'donald', 'information', 'president', 'trump'],
#        dtype='<U18'), array(['visions', 'tent', 'ayahuasca', 'emerged', 'nude', 'ryan', 'paul',
#         'just', 'new', 'news', 'hope', 'republican', 'party', 'gop'],
#        dtype='<U18'), array(['fate', 'ties', 'iran', 'deal', 'nuclear', 'obama'],
#        dtype='<U18'), array(['threatens', 'leave', 'carson', 'republican', 'party'],
#        dtype='<U18'), array(['squad', 'firing', 'representative', 'called', 'just', 'hillary',
#         'republican', 'killed'],
#        dtype='<U18'), array(['away', 'laptop', 'weiner', 'source', 'nypd', 'evidence', 'hillary',
#         'life'],
#        dtype='<U18'), array(['borders', 'better', 'america'],
#        dtype='<U18'), array(['aleppo', 'chlorine', 'applies', 'isis'],
#        dtype='<U18'), array(['change', 'fools', 'near', 'empire', 'socrates', 'interview',
#         '2016', 'day', 'life', 'hope', 'endgame'],
#        dtype='<U18'), array(['fight', 'force', 'territorial', 'establishing', 'poland',
#         'russian', 'new', 'defense', 'threat'],
#        dtype='<U18'), array(['past', 'flying', 'ufo', 'films', 'nasa', 'footage', 'new'],
#        dtype='<U18'), array(['agree', 'powers', 'world', 'iran', 'deal', 'nuclear'],
#        dtype='<U18'), array(['launch', 'deliberations', 'inside', 'campaign', 'hillary',
#         'clinton'],
#        dtype='<U18'), array(['beau', 'eulogy', 'emotional', 'delivers', 'biden', 'obama'],
#        dtype='<U18'), array(['success', 'chance', '50', 'wire', 'talks', 'iran', 'nuclear'],
#        dtype='<U18'), array(['deadliest', 'records', '17', '2016', 'chicago', 'shot', 'dead',
#         'weekend'],
#        dtype='<U18'), array(['halloween', 'celebrate', 'christians'],
#        dtype='<U18'), array(['denial', 'polls', 'surging', 'math', 'republicans', 'hillary'],
#        dtype='<U18'), array(['recession', 'global', 'trigger', 'china'],
#        dtype='<U18'), array(['billion', 'helped', 'donors', 'mega', 'raise', 'hillary', 'clinton'],
#        dtype='<U18'), array(['dream', 'american', 'destroys', 'criminal', 'booker', 'cory',
#         'justice', 'america'],
#        dtype='<U18'), array(['hold', 'weaker', 'nationally', 'leads', 'poll', 'race', 'party',
#         'gop', 'trump'],
#        dtype='<U18'), array(['steal', 'tied', 'directly', 'busted', 'foundation', 'plot',
#         'clinton', 'election'],
#        dtype='<U18'), array(['study', 'makeup', 'children', 'chemicals', 'toxic', 'halloween'],
#        dtype='<U18'), array(['donations', 'foreign', 'accepts', 'pac', 'veritas', 'project',
#         'bombshell', 'pro', 'clinton'],
#        dtype='<U18'), array(['11', 'cooler', 'water', '00pm', '2016'],
#        dtype='<U18'), array(['argument', 'tone', 'hopeful', 'balance', 'change', 'clinton',
#         'challenge'],
#        dtype='<U18'), array(['nose', 'substance', 'brown', 'mysterious', 'visit', 'return',
#         'heathrow', 'held', 'farage', 'nigel', 'trump'],
#        dtype='<U18'), array(['years', 'eliminate', 'intends', 'massive', 'predicts', 'revealing',
#         'recession', 'interview', 'debt', 'national', 'trump'],
#        dtype='<U18'), array(['finest', 'onion', 'like', 'act', 'okay', 'near', 'source',
#         'donald', 'report', 'news', 'america', 'trump'],
#        dtype='<U18'), array(['policing', 'reach', 'department', 'cleveland', 'deal', 'justice'],
#        dtype='<U18'), array(['weapons', 'ban', 'calling', 'resolution', 'landmark', 'adopts',
#         'nuclear', 'votes'],
#        dtype='<U18'), array(['speeches', 'dc', 'dueling', 'clash', 'clinton', 'trump'],
#        dtype='<U18'), array(['running', 'hillary', 'term'],
#        dtype='<U18'), array(['osmanisnin', 'supporters', 'origin', 'true', 'exposes',
#         'journalist', 'award', 'american', 'ties', 'isis', 'comment',
#         'hillary', 'terror', 'war', 'winning', 'clinton'],
#        dtype='<U18'), array(['donald', 'states', 'united', 'president', 'america', 'trump'],
#        dtype='<U18'), array(['vanishing', 'swing', 'politics', 'voters'],
#        dtype='<U18'), array(['russia', 'plans', 'buildup', 'pushes', 'nato', 'presstv', 'near',
#         'military'],
#        dtype='<U18'), array(['computer', 'warrant', 'gets', 'breaking', 'department', 'weiner',
#         'search', 'video', 'emails', 'state', 'fbi'],
#        dtype='<U18'), array(['debates', 'outside', 'answering', 'focus', 'shift', 'weld',
#         'johnson', 'gary', 'questions'],
#        dtype='<U18'), array(['moscow', 'syria', 'lavrov', 'zarif', 'russia', 'hold', 'talks',
#         'iran'],
#        dtype='<U18'), array(['second', 'answers', 'bush', 'questions', 'debate', 'fiorina',
#         'gop', 'trump'],
#        dtype='<U18'), array(['cesspool', 'claims', 'family', 'crime', 'clintons', 'calls',
#         'director', 'assistant', 'ex', 'foundation', 'fbi'],
#        dtype='<U18'), array(['server', 'mail', 'private', 'provide', 'agrees', 'hillary', 'fbi',
#         'clinton'],
#        dtype='<U18'), array(['space', 'air', 'syrian', 'miss', 'russia', 'near', 'problem',
#         'moves', 'close'],
#        dtype='<U18'), array(['com', 'wundergroundmusic', 'talk', 'told', 'girl', 'hand', 'chat',
#         'pills', 'hour', 'guy'],
#        dtype='<U18'), array(['obvious', 'admits', 'memo', 'secret', 'image', 'reinventing',
#         'donald', 'republican', 'gop', 'trump'],
#        dtype='<U18'), array(['rogue', '01', 'arms', 'right', 'choice', 'offer', 'masters',
#         'really', 'flag', 'false', 'connects', 'videos', 'minute', '63',
#         '12', 'did', 'donald', 'muslims', 'targeting', 'state', 'left',
#         'think', 'trump'],
#        dtype='<U18'), array(['organization', 'cancer', 'cause', 'meats', 'processed', 'bacon',
#         'dogs', 'hot', 'world', 'declares', 'health'],
#        dtype='<U18'), array(['resets', 'line', 'long', 'latest', 'makeover', '2016', 'clinton'],
#        dtype='<U18'), array(['ohio', 'questions', 'easy', 'donald', 'rally', 'clinton', 'health',
#         'think', 'trump'],
#        dtype='<U18'), array(['restaurant', 'texas', 'shootout', 'gang', 'biker', 'deadly', '170',
#         'arrested', 'police', 'say'],
#        dtype='<U18'), array(['rudeness', 'usa', 'respond', 'patience', 'russia', 'run'],
#        dtype='<U18'), array(['measures', 'plan', 'leader', 'climate', 'change', 'obama', 'new'],
#        dtype='<U18'), array(['pupils', 'teacher', 'punches', 'allah', 'master', 'screams',
#         'france', 'muslim'],
#        dtype='<U18'), array(['stunning', 'admitted', 'earnest', 'josh', 'wow', 'true',
#         'obamacare'],
#        dtype='<U18'), array(['slaying', 'graham', 'hannah', 'matthew', 'jesse', 'charged'],
#        dtype='<U18'), array(['transparency', 'program', 'drone', 'progress', 'administration',
#         'report', 'obama', 'makes'],
#        dtype='<U18'), array(['wins', 'digital', '11', 'trump'],
#        dtype='<U18'), array(['york', 'guide', 'mcgregor', 'conor', 'travel', 'new'],
#        dtype='<U18'), array(['jtmcphee', 'footnote', 'mckinsey', 'mile', '67', 'cents', 'seven',
#         'taxi', 'driving', 'really', 'mysterious', '17', 'self', 'comment',
#         'cost'],
#        dtype='<U18'), array(['mckinley', 'blasts', 'delegation', 'ohio', 'change', 'mount'],
#        dtype='<U18'), array(['opinion', 'stage', 'missing', 'future', 'debate', 'president',
#         'gop'],
#        dtype='<U18'), array(['churkin', 'evacuations', 'adequate', 'carry', 'failed', 'aleppo',
#         'medical'],
#        dtype='<U18'), array(['budget', 'caps', 'spending', 'cuts', 'sequester', 'seeks', 'plan',
#         'raise', 'obama', 'end'],
#        dtype='<U18'), array(['test', 'slips', 'performance', 'student', 'national'],
#        dtype='<U18'), array(['warning', 'bit', 'shoppers', 'giving', 'tesco', 'year'],
#        dtype='<U18'), array(['marriage', 'weighs', 'jeb', 'bush', 'sex'],
#        dtype='<U18'), array(['truthfeed', 'netted', 'morocco', 'favors', 'play', 'million',
#         'pay', 'hillary', '28', 'big'],
#        dtype='<U18'), array(['vote', 'make', 'america'],
#        dtype='<U18'), array(['anymore', 'appear', 'rules'],
#        dtype='<U18'), array(['bonuses', 'enlistment', 'repayment', 'forced', 'halts',
#         'secretary', 'defense'],
#        dtype='<U18'), array(['killings', 'style', 'ambush', 'captured', 'suspect', 'iowa', 'cops'],
#        dtype='<U18'), array(['steroids', 'bargain', 'grand', 'tent', 'obama', 'hillary', 'big'],
#        dtype='<U18'), array(['lindsey', 'endorsement', 'picks', 'jeb', 'graham', 'bush'],
#        dtype='<U18'), array(['tokyo', 'contest', 'beauty', 'international', 'photo', 'miss',
#         'russia', 'day'],
#        dtype='<U18'), array(['concert', 'rap', 'counter', 'americans', 'revitalization', 'urban',
#         'announces', 'plan', 'donald', 'free', 'black', 'hillary',
#         'clinton', 'trump'],
#        dtype='<U18'), array(['ambushed', 'iowa', 'cops'],
#        dtype='<U18'), array(['hopes', 'tone', 'ryan', 'campaign', 'new', 'trump'],
#        dtype='<U18'), array(['ballots', 'paper', 'switches', 'county', 'texas', 'emergency'],
#        dtype='<U18'), array(['ttip', 'tpp', 'abandons', 'breaking', 'white', 'house'],
#        dtype='<U18'), array(['arrogance', '29th', 'october', 'transcript', 'derb', 'radio',
#         'power'],
#        dtype='<U18'), array(['domestic', 'planned', 'huckabee', 'terrorism', 'shooting',
#         'parenthood'],
#        dtype='<U18'), array(['prevented', 'great', 'nuclear', 'war'],
#        dtype='<U18'), array(['friends', 'gay', 'mike', 'huckabee', 'people'],
#        dtype='<U18'), array(['global', 'order', 'podesta', 'john', 'new'],
#        dtype='<U18'), array(['rubio', 'marco', 'boos', 'crowd', 'hispanic', 'stage'],
#        dtype='<U18'), array(['refuge', 'arctic', 'acres', 'protecting', 'propose', 'million',
#         'obama'],
#        dtype='<U18'), array(['offshore', 'fried', 'deep'],
#        dtype='<U18'), array(['burned', 'crashed', 'nominee', 'ready', 'supposedly', 'mortem',
#         'post', 'rubio', 'marco', 'gop'],
#        dtype='<U18'), array(['conducting', 'pipeline', 'covering', 'journalist', 'interview',
#         'protests', 'video', 'shot'],
#        dtype='<U18'), array(['millennials', 'racism', 'roof', 'dylann', 'charleston'],
#        dtype='<U18'), array(['strikes', 'disaffected', 'america'],
#        dtype='<U18'), array(['yield', 'intervention', 'choice', 'syria', 'russia', 'act',
#         'force', 'obama'],
#        dtype='<U18'), array(['divisions', 'actions', 'block', 'exposes', 'immigration', 'votes',
#         'obama', 'new', 'house', 'gop'],
#        dtype='<U18'), array(['regret', 'live', 'zika', 'fight', 'warns', 'congress', 'white',
#         'house'],
#        dtype='<U18'), array(['shows', 'veteran', 'anthem', 'try', 'alabama', 'univ', 'watch',
#         'protest', 'national', 'students'],
#        dtype='<U18'), array(['rifts', 'downplay', 'allies', 'boehner', 'gop'],
#        dtype='<U18'), array(['round', 'debates', 'checking', 'fact', 'gop'],
#        dtype='<U18'), array(['leaders', 'appeal', 'tries', 'nervous', 'democrats', 'grow',
#         'clinton', 'party'],
#        dtype='<U18'), array(['begins'],
#        dtype='<U18'), array(['15', 'feel', 'americans', 'years', 'poll', 'safe', 'new', 'war'],
#        dtype='<U18'), array(['yawn', 'file', 'oppo', 'hacked', 'mysteriously', 'dnc', 'big',
#         'trump'],
#        dtype='<U18'), array(['scholars', 'loved', 'little', 'gets', 'cash', 'trump'],
#        dtype='<U18'), array(['idea', 'violation', 'law', 'hillary', 'election'],
#        dtype='<U18'), array(['darkness', 'fades', 'christie', 'chris'],
#        dtype='<U18'), array(['electrify', 'surges', 'rubio', 'carolina', 'south'],
#        dtype='<U18'), array(['takeaways', 'debate', 'republican'],
#        dtype='<U18'), array(['presenter', 'weather', 'channel', 'tv', 'irish', 'halloween',
#         'killed'],
#        dtype='<U18'), array(['fired', 'base', 'jeb', 'bush', 'like', 'establishment'],
#        dtype='<U18'), array(['caucuses', 'ahead', 'optimistic', 'cautiously', 'iowa', 'clinton',
#         'trump'],
#        dtype='<U18'), array(['florida', '95', 'victory', 'votes', 'signs', 'point', 'trump'],
#        dtype='<U18'), array(['populism', 'experiment', 'leading', 'civil', 'long', 'new', 'war',
#         'republican', 'party', 'gop', 'trump'],
#        dtype='<U18'), array(['turn', 'server', 'private', 'justice', 'hillary', 'email',
#         'clinton'],
#        dtype='<U18'), array(['3rd', 'stirs', 'baton', 'passes', 'obama', 'charges', 'term',
#         'clinton'],
#        dtype='<U18'), array(['architect', 'security', 'festival', 'meat', 'dog', 'activists',
#         'rights', 'human', 'watch', 'china', 'targeting', 'comment',
#         'information'],
#        dtype='<U18'), array(['nomination', '90', 'chance', 'run', 'll', 'higher', 'percent',
#         'fiorina', 'carly', 'presidential', 'says', 'gop'],
#        dtype='<U18'), array(['ticks', 'unemployment', 'january', '257k', 'added', 'jobs',
#         'percent'],
#        dtype='<U18'), array(['prepare', 'ways', 'crisis', 'economic'],
#        dtype='<U18'), array(['lose', '202', 'daily', 'ways', '12', 'presidency', 'hillary',
#         'clinton'],
#        dtype='<U18'), array(['island', 'sufficient', 'beautiful', 'price', 'small', 'million',
#         'self'],
#        dtype='<U18'), array(['streamlining', '200m', 'spends', '2000', 'reuters', 'thomas',
#         'cuts', 'jobs'],
#        dtype='<U18'), array(['offguardian', 'democracy', 'endangers', 'neocons', 'russia',
#         'american'],
#        dtype='<U18'), array(['conservatism', 'religious', 'abandoning', 'youth', 'nigh',
#         'christian', 'country', 'white', 'end', 'america'],
#        dtype='<U18'), array(['narcissist', 'evil', 'lesser', 'trump'],
#        dtype='<U18'), array(['900k', 'star', 'leaks', 'woman', 'jackson', 'bad', 'secret',
#         'family', 'news', 'sick', 'sex'],
#        dtype='<U18'), array(['reid', 'kochs', 'plan', 'beat'],
#        dtype='<U18'), array(['humanity', 'threats', 'biggest', 'exposed'],
#        dtype='<U18'), array(['enforcement', 'good', 'cities', 'sanctuary', 'steinle', 'kate',
#         'laws', 'death'],
#        dtype='<U18'), array(['questioner', 'doesn', 'donald', 'anti', 'muslim', 'challenge',
#         'trump'],
#        dtype='<U18'), array(['targets', 'assault', 'fierce', 'launches', 'france', 'syria',
#         'isis'],
#        dtype='<U18'), array(['worth', 'civilization', 'western', 'saving'],
#        dtype='<U18'), array(['mrs', 'weiner'],
#        dtype='<U18'), array(['target', 'airstrikes', 'syria', 'isis', 'just'],
#        dtype='<U18'), array(['modern', 'medieval', 'feudalism'],
#        dtype='<U18'), array(['manning', 'chelsea', 'torture', 'scandal', 'true', '2016'],
#        dtype='<U18'), array(['position', 'marriage', 'times', 'administration', 'lied', 'obama',
#         '16', 'sex', 'president'],
#        dtype='<U18'), array(['flint', 'fly', 'sparks', 'debate', 'sanders', 'clinton'],
#        dtype='<U18'), array(['vitamin', 'contain', '15', 'alternative', 'foods'],
#        dtype='<U18'), array(['pray', 'mass', 'iraqi', 'years', 'hold', 'christians', 'win',
#         'trump'],
#        dtype='<U18'), array(['products', 'management', 'wealth', 'crackdown', 'soars', 'bitcoin',
#         'launches', 'china'],
#        dtype='<U18'), array(['knows', 'candidate', 'begin', 'democrats', 'search', 'use', 'email'],
#        dtype='<U18'), array(['work', 'getting', 'prior', 'worked', 'illegally', 'proof', 'finds',
#         'ap', 'breaking', 'visa', 'melania', 'trump'],
#        dtype='<U18'), array(['roundup', 'monsanto', 'lawsuits'],
#        dtype='<U18'), array(['proposal', 'gun', 'wrong', 'control', 'hillary', 'clinton'],
#        dtype='<U18'), array(['unemployed', 'youths', '58', 'claim', 'misleading', 'percent',
#         'black', 'trump'],
#        dtype='<U18'), array(['hit', 'help', 'montel', 'blackmails', 'reporter', 'dirty', 'll',
#         'print', 'report', 'address', 'trump'],
#        dtype='<U18'), array(['living', 'sustainable', 'criminalizes', 'govt', 'rate',
#         'increasing', 'homes', 'tiny', 'banned'],
#        dtype='<U18'), array(['stretch', 'relax', 'necessary'],
#        dtype='<U18'), array(['rapists', 'freeloaders', 'alien', 'bored', 'coordinator',
#         'activities', 'wanted', 'sweden', 'help', 'illegal', 'muslim'],
#        dtype='<U18'), array(['businesses', 'backbone', 'instagram'],
#        dtype='<U18'), array(['scary', 'praise', 'unpatriotic', 'donald', 'putin', 'hillary',
#         'clinton', 'trump'],
#        dtype='<U18'), array(['stealing', 'movement', 'spearheading', 'agents', 'pieczenik',
#         'truthfeed', 'rogue', 'clintons', 'wikileaks', 'stop', 'white',
#         'house', 'fbi'],
#        dtype='<U18'), array(['rappers', 'lewd', 'promotes', 'michelle', 'obama'],
#        dtype='<U18'), array(['learned', 've', 'covering', 'seven', 'things', 'candidates',
#         'party'],
#        dtype='<U18'), array(['manager', 'deeper', 'problems', 'donald', 'campaign', 'trump'],
#        dtype='<U18'), array(['event', 'century', 'breathtaking', 'witness', 'world'],
#        dtype='<U18'), array(['raid', 'paris', 'mastermind', 'suspected', 'massacre', 'terror',
#         'killed'],
#        dtype='<U18'), array(['working', 'rich', 'appeal', 'try', 'candidates', 'voters'],
#        dtype='<U18'), array(['jets', '25', 'spent', 'private', 'million', 'foundation',
#         'hillary', 'clinton'],
#        dtype='<U18'), array(['explains', 'experts', 'ideology', 'simple', 'russia', 'america'],
#        dtype='<U18'), array(['100percentfedup', 'healthcare', 'reform', 'fantastic', 'plan',
#         'com', 'begins', 'bombshell', 'point', 'trump'],
#        dtype='<U18'), array(['bring', 'presidency', 'hillary'],
#        dtype='<U18'), array(['fda', 'walnuts', 'drugs', 'says'],
#        dtype='<U18'), array(['upgrade', '30mki', 'su', 'fighter', 'advanced', 'fgfa', 'discuss',
#         'russia', 'india'],
#        dtype='<U18'), array(['weak', 'different', 'saying', 'rivals', 'ways', 'rubio', 'marco',
#         'thing'],
#        dtype='<U18'), array(['account', 'intel', 'confidential', 'distribute', 'agreed',
#         'private', 'podesta', 'wikileaks', 'email', 'clinton'],
#        dtype='<U18'), array(['broiles', 'steven', 'shops', 'pot', 'hike', 'fee', 'proposes',
#         'member', 'council', 'seattle', 'massive', 'comment'],
#        dtype='<U18'), array(['personality', 'cult', 'match', 'strategist', 'ted', 'master',
#         'cruz', 'trump'],
#        dtype='<U18'), array(['7th', 'losers', 'winners', 'debate', 'presidential', 'republican'],
#        dtype='<U18'), array(['doing', 'notion', 'dispel', 'let', 'knows', 'donald', 'trump'],
#        dtype='<U18'), array(['jose', 'ivan', 'jeepney', 'philippine', 'riding', 'tutorial',
#         'comment'],
#        dtype='<U18'), array(['meets', 'leaders', 'ryan', 'unity', 'party', 'gop', 'trump'],
#        dtype='<U18'), array(['enter', 'sea', 'lake', 'fascinated', 'scientists', 'watch', 'come'],
#        dtype='<U18'), array(['justices', 'eyes', 'case', 'obamacare'],
#        dtype='<U18'), array(['jumpstart', 'vows', 'mogul', 'reboot', 'business', 'economy',
#         'trump'],
#        dtype='<U18'), array(['peace', 'encourage', 'policy', 'jeb', 'spending', 'plan', 'bush',
#         'foreign', 'military'],
#        dtype='<U18'), array(['pariah', 'rejects', 'video', 'deal', 'nuclear', 'congress'],
#        dtype='<U18'), array(['disappointing', 'irrelevant', 'disjointed', 'words', 'address',
#         'union', 'state', 'obama'],
#        dtype='<U18'), array(['sanctions', 'dems', 'senate', 'won', 'iran', 'support', 'say'],
#        dtype='<U18'), array(['takes', 'fight', 'clinton', 'trump'],
#        dtype='<U18'), array(['favorite', 'mexican', 'influenced', 'claiming', 'hosts', 'panders',
#         'hispanic', 'rap', 'truthfeed', 'radio', 'black', 'hillary', 'food'],
#        dtype='<U18'), array(['elections', 'rigged', 'modern', 'history'],
#        dtype='<U18'), array(['warn', 'apocalypse', 'wins', 'revolution', 'voters', 'clinton',
#         'trump'],
#        dtype='<U18'), array(['world', 'war'],
#        dtype='<U18'), array(['intrusion', 'sacked', 'elections', 'director', 'fbi'],
#        dtype='<U18'), array(['deliver', 'cheated', 'authority', 'brother', 'little', 'jeb',
#         'bush', 'helped', 'presidency', 'ultimate', 'america'],
#        dtype='<U18'), array(['ending', 'invaders', 'ages', 'afraid', 'services', 'protection',
#         'child', 'uk', 'workers', 'muslim', 'fear', 'court', 'challenge'],
#        dtype='<U18'), array(['takeaways', 'debate', 'presidential'],
#        dtype='<U18'), array(['handle', 'rattled', 'gets', 'donald', 'putin', 'press', 'trump'],
#        dtype='<U18'), array(['freedom', 'promote', 'christianity', 'religious', 'attack'],
#        dtype='<U18'), array(['flaw', 'murphy', 'seize', 'verb', 'noun', 'rubio', 'seeks',
#         'donald', 'trump'],
#        dtype='<U18'), array(['takeaways', 'debate', 'gop'],
#        dtype='<U18'), array(['reputation', 'sinking', 'williams', 'brian', 'stephanopoulos',
#         'george', 'media'],
#        dtype='<U18'), array(['porsche', 'primary', 'group', 'candidates', 'voters', 'gop',
#         'trump'],
#        dtype='<U18'), array(['officer', 'ill', 'mentally', 'gun'],
#        dtype='<U18'), array(['chart', '2016', 'hillary', 'big', 'clinton', 'challenge'],
#        dtype='<U18'), array(['iraq', 'lost'],
#        dtype='<U18'), array(['destroy', 'thiel', 'peter', 'strategy', 'haters', 'gawker',
#         'using', 'fear'],
#        dtype='<U18'), array(['check', '2016', 'fact', 'election'],
#        dtype='<U18'), array(['principles', 'conservative', 'failure', 'boehner', 'live', 'john'],
#        dtype='<U18'), array(['closer', 'candidates', 'believe', 'establishment', 'republicans',
#         'trump'],
#        dtype='<U18'), array(['sordid', 'tells', 'assange', 'elections', 'truth'],
#        dtype='<U18'), array(['serve', 'unfit', 'obama', 'president', 'trump'],
#        dtype='<U18'), array(['cable', 'news', 'trouble'],
#        dtype='<U18'), array(['communism', 'nature', 'deceptive', 'line', 'right', 'hillary',
#         'clinton'],
#        dtype='<U18'), array(['gettysburg', 'order', 'world', 'address', 'new', 'trump'],
#        dtype='<U18'), array(['spiraling', 'shootings', 'mass', 'appear', 'video', 'control'],
#        dtype='<U18'), array(['link', 'officials', 'donald', 'putin', 'fbi', 'trump'],
#        dtype='<U18'), array(['polarization', 'fix', 'american', 'politics', 'possible'],
#        dtype='<U18'), array(['boxed', 'debates', 'johnson', 'gary', 'did', 'just'],
#        dtype='<U18'), array(['doctors', 'silver', 'nukes', 'satan', 'pointed', 'russia', 'putin'],
#        dtype='<U18'), array(['kept', 'reportedly', 'counsel', 'use', 'white', 'dark', 'email',
#         'personal', 'house', 'clinton'],
#        dtype='<U18'), array(['investigation', 'reopened', 'comey', 'hillary'],
#        dtype='<U18'), array(['abortion', 'partisan', 'polarization'],
#        dtype='<U18'), array(['girlfriend', 'excuse', 'ex', 'man', 'victory', 'uses', 'trump'],
#        dtype='<U18'), array(['access', 'participation', 'refuse', 'departments', 'crackdown',
#         'pipeline', 'dakota', 'police'],
#        dtype='<U18'), array(['projects', 'navy', 'cooperation', 'expand', 'focus', 'russia',
#         'report', 'military', 'india'],
#        dtype='<U18'), array(['strongman', 'sounded', 'conservative', 'movement', '202', 'daily',
#         'like', 'trump'],
#        dtype='<U18'), array(['applebee', 'sue', 'praying', 'fajitas', 'burned', 'man'],
#        dtype='<U18'), array(['gave', 'mentioned', '2015', 'rights', 'private', 'actually',
#         'palestinian', 'speech', 'hillary', 'clinton'],
#        dtype='<U18'), array(['template', 'landslide', 'christie', 'chris', 'video', '2016',
#         'presidential', 'republican', 'win'],
#        dtype='<U18'), array(['covers', 'album', 'trumped', 'music', 'make', 'great', '10'],
#        dtype='<U18'), array(['public', 'broadest', 'forward', 'path', 'sioux', 'serve', 'turns',
#         'hillary', 'rock', 'standing'],
#        dtype='<U18'), array(['outlook', 'eastern', 'buck', 'bang', 'new'],
#        dtype='<U18'), array(['medicare', 'bipartisan', 'deadline', 'hours', 'heads', 'white',
#         'house'],
#        dtype='<U18'), array(['resolutions', 'unesco', 'urged', 'jews', 'french', 'rally'],
#        dtype='<U18'), array(['flipped', 'votes', 'clinton', 'trump'],
#        dtype='<U18'), array(['soon', 'venezuela'],
#        dtype='<U18'), array(['sbs', 'mom', 'suffer', 'bones', 'brittle', 'tennessee', 'children',
#         'care', 'state', 'charged'],
#        dtype='<U18'), array(['loss', 'nevada', 'sharpening', 'sanders', 'message', 'attacks',
#         'clinton'],
#        dtype='<U18'), array(['ran', 'proven', 'theories', 'conspiracy', 'true', 'donald',
#         'president', 'trump'],
#        dtype='<U18'), array(['fine', 'walks', 'gov', 'christie', 'gay', 'marriage', 'line'],
#        dtype='<U18'), array(['final', 'hill', 'capitol', 'kerry', 'tells', 'hold', 'iran',
#         'deal', 'nuclear', 'critics'],
#        dtype='<U18'), array(['shaped', 'flags', 'powder', 'fawkes', 'false', 'gun', 'guy',
#         'plot', 'history'],
#        dtype='<U18'), array(['aloof', 'democratic'],
#        dtype='<U18'), array(['gunman', 'accused', 'forgiveness', 'families', 'victims', 'roof',
#         'dylann', 'charleston'],
#        dtype='<U18'), array(['shuts', 'furloughed', '30', 'homeland', 'security', 'department',
#         '000', 'chief', 'says'],
#        dtype='<U18'), array(['hatred', 'limbaugh', 'rush', 'christianity', 'left', 'fear'],
#        dtype='<U18'), array(['pennsylvania', 'involved', 'officers', 'naming', 'bans', 'corrupt',
#         'shootings', 'governor', 'goes'],
#        dtype='<U18'), array(['meeting', 'groping', 'accuses', 'contestant', 'apprentice', 'job',
#         'trump'],
#        dtype='<U18'), array(['overrated', 'outrageously', 'midwesterner', 'backed', 'awkward',
#         'stood', 'walker', 'scott', 'chance', 'koch'],
#        dtype='<U18'), array(['fall', 'prices', 'oil', 'iran', 'reached', 'deal', 'nuclear'],
#        dtype='<U18'), array(['lesbian', 'service', 'deny', 'legal', 'indiana', 'bad', 'gay',
#         'states', '29', 'people', 'think'],
#        dtype='<U18'), array(['author', 'brothel', 'canadian', 'grandfather', 'rush', 'ran',
#         'gold', 'donald', 'says', 'trump'],
#        dtype='<U18'), array(['wars', 'vowing', 'leave', 'obama', 'end'],
#        dtype='<U18'), array(['supply', 'cut', 'attempt', 'nusra', 'al', 'govt', 'line', 'syrian',
#         'aleppo', 'isis', 'report', '2016', 'november', 'war'],
#        dtype='<U18'), array(['buchanan', 'wrought', 'hath', 'comment', 'trump', 'pat'],
#        dtype='<U18'), array(['runs', 'policy', 'foreign', 'obama', 'white', 'house'],
#        dtype='<U18'), array(['repeal', 'roadblock', 'hits', 'obamacare', 'gop'],
#        dtype='<U18'), array(['early', 'scandals', 'years', 'hillary', '29'],
#        dtype='<U18'), array(['dismissal', 'glee', 'markets', 'world', 'hillary', 'email', 'rally'],
#        dtype='<U18'), array(['retaliate', 'french', 'hit', 'airstrikes', 'massive', 'islamic',
#         'state', 'attacks'],
#        dtype='<U18'), array(['insurance', 'vows', 'eyes', 'cruz', 'video', 'law', 'obamacare',
#         'scrap'],
#        dtype='<U18'), array(['looking', 'mate', 'expected', 'soon', 'dog', 'running', 'attack',
#         'trump'],
#        dtype='<U18'), array(['unarmed', 'graphic', 'officer', 'shows', 'man', 'video', 'white',
#         'black', 'shooting'],
#        dtype='<U18'), array(['know', 'need', 'bombshells', '26', 'wikileaks', 'hillary'],
#        dtype='<U18'), array(['osteoarthritis', 'knee', 'seeds', 'sesame'],
#        dtype='<U18'), array(['debut', 'kalma', 'vs', 'cahill', 'album'],
#        dtype='<U18'), array(['hearing', 'heated', 'benghazi', 'role', 'defends', 'hill',
#         'clinton'],
#        dtype='<U18'), array(['steadies', 'passionate', 'convention', 'early', 'day',
#         'democratic', 'end', 'drama'],
#        dtype='<U18'), array(['discovered', 'biggest', 'fraud', 'states', 'united', 'history',
#         'election'],
#        dtype='<U18'), array(['hellscape', 'postapocalyptic', 'plan', 'hillary', 'clinton'],
#        dtype='<U18'), array(['lost', 'good', 'rights', 'gay', 'republicans', 'thing'],
#        dtype='<U18'), array(['sign', 'ark', 'freedom', 'religious', 'won', 'governor'],
#        dtype='<U18'), array(['lasted', 'nice', 'democracy'],
#        dtype='<U18'), array(['camp', 'fema', 'land', 'page', 'facebook'],
#        dtype='<U18'), array(['trending', 'spiritcooking', 'twitter'],
#        dtype='<U18'), array(['harder', 'hitting', 'islamic', 'state', 'obama', 'says'],
#        dtype='<U18'), array(['stymied', 'investigations', 'multiple', 'agents', 'clintons', 'fbi'],
#        dtype='<U18'), array(['chant', 'closed', 'fraternity', 'oklahoma', 'video', 'racist'],
#        dtype='<U18'), array(['ante', 'ups', 'indiana', 'trump'],
#        dtype='<U18'), array(['hedgehogs', 'trampolining', 'like', 'say'],
#        dtype='<U18'), array(['kills', 'bomber', 'explosion', 'istanbul', 'isis', '10'],
#        dtype='<U18'), array(['cracks', 'finally', 'cher', 'travel', 'time'],
#        dtype='<U18'), array(['prefer', 'cast', 'policy', 'position', 'vote', 'foreign'],
#        dtype='<U18'), array(['young', 'ivana', 'donald', 'video', 'baby', 'changed', 'says',
#         'trump'],
#        dtype='<U18'), array(['gays', 'execute', 'countries', 'contributions', 'dollar', 'multi',
#         'receives', 'getting', 'candidate', 'threats', 'gay', 'supporters',
#         'million', 'death', 'people', 'support', 'trump'],
#        dtype='<U18'), array(['proposed', 'slope', 'slippery', 'ban', 'muslims', 'trump'],
#        dtype='<U18'), array(['signals', '234', 'capture', 'astronomers', 'space', 'truth'],
#        dtype='<U18'), array(['carries', 'airstrikes', 'syria', 'russia', 'new'],
#        dtype='<U18'), array(['speaker', 'obstacles', 'monumental', 'ryan', 'paul', 'face'],
#        dtype='<U18'), array(['nasty', 'vagina', 'cat', 'matter', 'lives', 'frame', 'scheme',
#         'robbery', 'faking', 'caught', 'officer', 'woman', 'wife',
#         'comment', 'black', 'police'],
#        dtype='<U18'), array(['ticking', 'clock', 'republicans', 'alternative', 'obamacare'],
#        dtype='<U18'), array(['awesome', 'candidate', 'shows', 'donald', 'video', 'real',
#         'presidential', 'trump'],
#        dtype='<U18'), array(['drinking', 'gallons', 'desalinates', 'pipe', 'powered', 'solar',
#         'billion', 'water', 'year', 'california'],
#        dtype='<U18'), array(['scuttle', 'vows', 'boehner', 'fight', 'iran', 'deal', 'nuclear'],
#        dtype='<U18'), array(['belize', 'conservative', 'opinion', 'veritas', 'project', 'money'],
#        dtype='<U18'), array(['raises', 'freezer', 'stuck', 'woman', 'answers', 'questions',
#         'video'],
#        dtype='<U18'), array(['newsfeed', 'loyalists', 'workings', 'inner', 'facebook', 'exposes',
#         'report', 'control', 'clinton'],
#        dtype='<U18'), array(['british', 'know', 'russia', 'general', 'nuclear', 'warns', 'end',
#         'life', 'war'],
#        dtype='<U18'), array(['thousands', '700', 'leaves', 'earthquake', 'nepal', 'underway',
#         'effort', 'relief', 'global', 'injured', 'dead'],
#        dtype='<U18'), array(['decisions', 'opt', 'let', 'americans', 'make', 'act', 'care',
#         'obamacare', 'health'],
#        dtype='<U18'), array(['listen', 'ron', 'neocons', 'don', 'paul', 'trump'],
#        dtype='<U18'), array(['wanted', 'gets', 'fight', 'sanders'],
#        dtype='<U18'), array(['dealer', 'book', 'rare', 'murderer', 'sentencing'],
#        dtype='<U18'), array(['reason', 'worthy', 'flashes', 'vandals', 'guarding', 'homeless',
#         'fierce', 'star', 'woman', 'future', 'trump'],
#        dtype='<U18'), array(['wtf', 'uranium', 'sells', 'russia', '20', 'hillary', 'clinton'],
#        dtype='<U18'), array(['firecrackers', 'bursting', 'quits', 'arnab', 'ndtv', 'seen',
#         'haze', 'smoke', 'incredible', 'suspected', 'outside', 'office'],
#        dtype='<U18'), array(['story', 'dislike', 'hillary', 'goes', 'people', 'clinton', 'far'],
#        dtype='<U18'), array(['unlikely', 'city', 'obamacare'],
#        dtype='<U18'), array(['plague', 'mujahedin', 'creation', 'admits', 'hillary'],
#        dtype='<U18'), array(['growth', 'quarter', 'cent', 'settled', 'arguments', 'brexit'],
#        dtype='<U18'), array(['julian', 'assange', 'lose', '12', 'predicts', 'missing', 'day',
#         'trump'],
#        dtype='<U18'), array(['endorses', 'register', 'moines', 'des', 'rubio', 'iowa', 'clinton'],
#        dtype='<U18'), array(['wesker', 'albert', 'declare', 'social', 'cop', 'ga', 'fired',
#         'racism', 'using', 'media', 'comment', 'law', 'today'],
#        dtype='<U18'), array(['straight', 'msnbc', 'year', 'standing'],
#        dtype='<U18'), array(['tension', 'patrol', 'shots', 'fires', 'vessel', 'naval', 'korean',
#         'warning', 'near', 'north', 'amid', 'south', 'high'],
#        dtype='<U18'), array(['highs', 'way', 'prices', 'gold', 'time'],
#        dtype='<U18'), array(['failed', 'times', 'obama', 'israel', 'support'],
#        dtype='<U18'), array(['washington', 'brawl', 'expanding', 'quandary', 'comey', 'mess',
#         'email'],
#        dtype='<U18'), array(['pitch', 'sales', 'progressive', 'electoral', 'harder', 'dems',
#         'scary', 'getting', 'future'],
#        dtype='<U18'), array(['bird', 'drone', 'national'],
#        dtype='<U18'), array(['hear', 'willing', 'maybe', 'apologising', 'models', 'topshop',
#         'feel', 'like', 'sick'],
#        dtype='<U18'), array(['wh', 'grave', 'jeb', 'bush', 'donald', 'doubts', 'trump'],
#        dtype='<U18'), array(['google', 'hillary', 'win'],
#        dtype='<U18'), array(['spend', 'willing', 'billion', 'campaign', 'says', 'trump'],
#        dtype='<U18'), array(['hack', 'view', 'wikileaks', 'clinton', 'says'],
#        dtype='<U18'), array(['acceptable', 'mediterranean', 'sailing', 'warships', 'considers',
#         'nato', 'russian'],
# ...
#         'republicans'],
#        dtype='<U18'), array(['nears', 'girds', 'presidential', 'trouble', 'militia', 'election'],
#        dtype='<U18'), array(['hide', 'colluded', '65', 'list', 'crimes', 'presstitutes',
#         'corporate', 'exposes', 'wikileaks', 'clinton'],
#        dtype='<U18'), array(['thank', 'parties', 'libertarians', '3rd', 'donald', 'trump'],
#        dtype='<U18'), array(['narrow', 'caucus', 'ted', 'wins', 'iowa', 'cruz', 'sanders',
#         'lead', 'holds', 'clinton'],
#        dtype='<U18'), array(['place', 'council', 'rights', 'human', 'russia', 'arabia', 'loses',
#         'saudi', 'elected'],
#        dtype='<U18'), array(['donation', '20k', 'accepting', 'ally', 'caught', 'foreign',
#         'clinton'],
#        dtype='<U18'), array(['4th', 'sworn', 'ashton', 'obama', 'carter', 'secretary', 'defense'],
#        dtype='<U18'), array(['respect', 'joe', 'biden'],
#        dtype='<U18'), array(['climb', 'gains', 'rubio', 'slips', 'poll', 'cruz', 'fox', 'carson',
#         'news', 'race', 'gop', 'trump'],
#        dtype='<U18'), array(['map', 'redrawing', 'east', 'middle', 'islamic', 'state', 'battle'],
#        dtype='<U18'), array(['fla', 'creek', 'coconut', 'steals', 'smurf', 'snoozy', 'sleeps',
#         'fan', 'abc', 'news', 'hillary', 'rally'],
#        dtype='<U18'), array(['evolution', 'appease', 'hopefuls', 'stupid', 'wingnut', 'walker',
#         'scott', 'base', 'fox', '2016', 'news', 'party', 'gop'],
#        dtype='<U18'), array(['dialogue', 'racial', 'pretending', 'lying', 'comedy', 'quinn',
#         'colin', 'stop', 'race', 'correctness', 'political', 'people'],
#        dtype='<U18'), array(['hilarious', 'indian', 'sway', 'bollywood', 'fail', 'meant',
#         'american', 'video', 'ad', 'voters', 'trump'],
#        dtype='<U18'), array(['powerful', 'case', 'dnc', 'speech', 'hillary', 'makes', 'personal',
#         'clinton'],
#        dtype='<U18'), array(['hall', 'town', 'won', 'sanders', 'hillary', 'clinton', 'bernie'],
#        dtype='<U18'), array(['increase', 'minimum', 'wage', 'fraud'],
#        dtype='<U18'), array(['chosen', 'god', 'trump'],
#        dtype='<U18'), array(['wyoming', 'crushes', 'caucus', 'cruz', 'republican', 'trump'],
#        dtype='<U18'), array(['shake', 'tragedy', 'paris', '2016', 'race'],
#        dtype='<U18'), array(['ugly', 'good', 'bad', 'jeb', 'bush', '2016'],
#        dtype='<U18'), array(['damage', 'demands', 'planned', 'answers', 'does', 'control',
#         'parenthood', 'gop'],
#        dtype='<U18'), array(['playbook', 'wing', 'vast', 'reboots', 'conspiracy', 'right',
#         'hillary'],
#        dtype='<U18'), array(['feared', 'blackout', 'earth', 'solar', 'hits', 'storm',
#         'technology'],
#        dtype='<U18'), array(['floor', 'tense', 'senate', 'cities', 'sanctuary', 'block',
#         'debate', 'votes'],
#        dtype='<U18'), array(['35', 'canceling', 'leas', 'marc', 'nation', 'james', 'talk',
#         'radio'],
#        dtype='<U18'), array(['misstating', 'apologizes', 'homeless', 'service', 'veteran', 'va',
#         'military', 'secretary'],
#        dtype='<U18'), array(['fuck', 'ooh'],
#        dtype='<U18'), array(['papers', 'federalist', 'brutally', 'sexual', 'hypocrisy',
#         'assault', 'exposed', 'hillary'],
#        dtype='<U18'), array(['signal', 'latest', 'run', 'won', 'biden', 'president'],
#        dtype='<U18'), array(['war3', 'army', 'putins', 'coming', 'alert', 'world', 'video',
#         '2016', 'obama', 'year', 'new', 'news'],
#        dtype='<U18'), array(['thanking', 'newt', 'obsession', 'calling', 'women', 'actually',
#         'sex', 'kelly', 'megyn', 'says', 'gop'],
#        dtype='<U18'), array(['form', 'separation', 'signing', 'record', 'department', 'state',
#         'clinton'],
#        dtype='<U18'), array(['worse', 'polarization', 'getting', 'political'],
#        dtype='<U18'), array(['growing', 'huffpollster', 'good', 'economy', 'obama', 'news'],
#        dtype='<U18'), array(['preparation', 'assets', 'enemy', 'positioning', 'pre', 'rigged',
#         'states', 'united', 'election'],
#        dtype='<U18'), array(['derail', 'suddenly', 'feeling', 'weighs', 'sanders', 'press',
#         'bern', 'hillary'],
#        dtype='<U18'), array(['took', 'implodes', 'paid', 'hillary', 'support', 'trump'],
#        dtype='<U18'), array(['clean', 'folly', 'plan', 'obama', 'power'],
#        dtype='<U18'), array(['monopoly', 'blame', 'government', 'markets'],
#        dtype='<U18'), array(['discriminate', 'fair', 'identity', 'game', 'hatred', 'democrats',
#         'republicans', 'political'],
#        dtype='<U18'), array(['warmer', 'getting', 'play', 'pay', 'fbi'],
#        dtype='<U18'), array(['survive', 'live', 'does'],
#        dtype='<U18'), array(['lands', 'actions', 'supreme', 'immigration', 'obama', 'battle',
#         'court'],
#        dtype='<U18'), array(['pakistan', 'para', 'mqm', 'judicial', 'extra', 'alarmed', 'group',
#         'rights', 'human', 'killings', 'force', 'workers', 'military'],
#        dtype='<U18'), array(['dependence', 'week', 'number', 'oil', 'long', 'russia', 'end'],
#        dtype='<U18'), array(['aligning', 'kasich', 'cruz', 'problem', 'donald', 'stop', 'trump'],
#        dtype='<U18'), array(['org', 'countercurrents', 'fascism', 'india'],
#        dtype='<U18'), array(['answer', 'determination', 'silence', 'obvious', 'syria', 'break',
#         'self', 'support'],
#        dtype='<U18'), array(['saved', 'immediately', 'challenges', 'officials', 'claim',
#         'department', 'emails', 'state', 'clinton'],
#        dtype='<U18'), array(['pundits', 'isn', 'left', 'hillary', 'winning'],
#        dtype='<U18'), array(['reunite', 'pirates', 'somali', 'freed', 'hostages', 'filipino',
#         'families'],
#        dtype='<U18'), array(['reverse', 'referendum', 'blair', 'tony', 'second', 'suggests',
#         'brexit'],
#        dtype='<U18'), array(['grilling', 'withstands', 'seat', 'benghazi', 'hot', 'republicans',
#         'clinton'],
#        dtype='<U18'), array(['retake', 'op', 'mosul', 'isis', 'military'],
#        dtype='<U18'), array(['passion', 'stir', 'foes', 'immigration', 'slow'],
#        dtype='<U18'), array(['rockets', 'soyuz', 'shipping', 'stops', 'france', 'space', 'russia'],
#        dtype='<U18'), array(['constitution', 'inconsistent', 'sharia', 'comments', 'doubles',
#         'carson', 'muslim'],
#        dtype='<U18'), array(['destruction', 'west', 'reason'],
#        dtype='<U18'), array(['goal', 'main', 'majority', 'senate', 'scary', 'leader', 'don',
#         'new', 'gop'],
#        dtype='<U18'), array(['headfirst', 'fell', 'hard', 'tapped', 'map', 'night', 'college',
#         'disaster', 'electoral', 'hellscape', 'digital', 'john', 'king',
#         'news', 'election'],
#        dtype='<U18'), array(['lifting', 'snag', 'reportedly', 'sanctions', 'hit', 'appeal',
#         'talks', 'iran', 'nuclear', 'obama', 'makes', 'people'],
#        dtype='<U18'), array(['stuns', 'central', 'qatar', 'sudden', 'bank', 'billion', 'world',
#         'financial', 'hillary', 'clinton'],
#        dtype='<U18'), array(['yemen', 'airstrikes', 'calls', 'arabia', 'saudi', 'end'],
#        dtype='<U18'), array(['scoffs', 'mate', 'running', 'cruz', 'choosing', 'win', 'trump'],
#        dtype='<U18'), array(['nightmare', 'independent', 'donald', 'gop', 'trump'],
#        dtype='<U18'), array(['dolezal', 'rachel', 'opinion', 'right', 'black'],
#        dtype='<U18'), array(['equal', 'strongest', 'passed', 'nation', 'maryland', 'laws', 'pay'],
#        dtype='<U18'), array(['kennedy', 'scalia', 'justices', 'rights', 'gay', 'divide'],
#        dtype='<U18'), array(['craigslist', 'staged', 'paid', 'protests', 'reveals', 'anti',
#         'trump'],
#        dtype='<U18'), array(['bullied', 'smoked', 'jeb', 'bush', 'marijuana', 'school',
#         'students', 'high'],
#        dtype='<U18'), array(['helping', 'rhetoric', 'extreme', 'duke', 'leaders', 'cruz', 'say',
#         'trump'],
#        dtype='<U18'), array(['fundamentals', 'silver', 'gold', 'higher'],
#        dtype='<U18'), array(['widespread', 'escalate', 'portland', 'philly', 'nyc', 'la',
#         'major', 'crowds', 'violence', 'mass', 'cities', '95', 'dc',
#         'chance', 'begins'],
#        dtype='<U18'), array(['charts', 'easy', '2016', 'election'],
#        dtype='<U18'), array(['celebrity', 'campaign', 'trump'],
#        dtype='<U18'), array(['oval', 'prison', 'video', 'hillary', 'office'],
#        dtype='<U18'), array(['doj', 'dinners', 'official', 'multiple', 'investigation',
#         'chairman', 'campaign', 'hillary', 'email', 'clinton'],
#        dtype='<U18'), array(['awe', 'shock', 'jeb', 'launch', 'inside'],
#        dtype='<U18'), array(['hodges', 'dave', 'martin', 'buying', 'russia', 'china', 'paul',
#         'food', 'america'],
#        dtype='<U18'), array(['hoax', 'leads', 'riots', 'tweet', 'street'],
#        dtype='<U18'), array(['45th', 'donald', 'states', 'united', 'president', 'elected',
#         'trump'],
#        dtype='<U18'), array(['answer', 'abortion', 'americans', 'really', 'surprise', 'think'],
#        dtype='<U18'), array(['keeps', 'momentum', 'growing', 'carly'],
#        dtype='<U18'), array(['nci', 'korea', 'contract', '63mln', 'firm', 'army', 'wins', 'south'],
#        dtype='<U18'), array(['queen', 'bbc', 'mp', 'tory', 'trolled', 'newsnight', 'god', 'save',
#         'play', 'called', 'day', 'end'],
#        dtype='<U18'), array(['declining', 'sucking', 'civilization', 'blood'],
#        dtype='<U18'), array(['warn', 'iran', 'deal', 'nuclear', 'obama', 'republicans'],
#        dtype='<U18'), array(['appearing', 'event', 'huckabee', 'iowa', 'trump'],
#        dtype='<U18'), array(['ruined', 'conservatism', 'long', 'don', 'republican', 'party',
#         'trump'],
#        dtype='<U18'), array(['75', 'budgeting', 'good', 'years', 'war'],
#        dtype='<U18'), array(['resign', 'pass', 'wants', 'man', 'law', 'president'],
#        dtype='<U18'), array(['practices', 'ruthless', 'glimpse', 'playbooks', 'offer',
#         'business', 'university', 'trump'],
#        dtype='<U18'), array(['spotlight', 'shrinks', 'steals', 'fiorina', 'time', 'trump'],
#        dtype='<U18'), array(['changedachannel', 'guest', 'crooked', 'special', 'clintons',
#         'breaking'],
#        dtype='<U18'), array(['cataclysmic', 'barrel', 'bomb', 'campaign', '2016', 'information',
#         'close'],
#        dtype='<U18'), array(['prevail', 'allies', 'cruz', 'north', 'dakota', 'race', 'delegate'],
#        dtype='<U18'), array(['tonight', 'watch', 'things', 'debate'],
#        dtype='<U18'), array(['local', 'gear', 'bans', 'departments', 'assault', 'style',
#         'administration', 'military', 'obama', 'police'],
#        dtype='<U18'), array(['exit', 'prompted', 'comments', 'judge', 'george', 'gop', 'trump'],
#        dtype='<U18'), array(['larger', 'gruber', 'mandate', 'demands', 'architect', 'penalty',
#         'obamacare'],
#        dtype='<U18'), array(['debacle', 've', 'latest', 'debates', 'agree', 'donald', 'trump'],
#        dtype='<U18'), array(['colossal', 'reality', 'terrifying', 'failure', 'democracy', 'new',
#         'president', 'trump'],
#        dtype='<U18'), array(['treason', 'mishandling', 'classified', 'homeland', 'security',
#         'truthfeed', 'chairman', 'information', 'hillary'],
#        dtype='<U18'), array(['loose', 'realclearpolitics', 'let', 'york', 'debate', 'sanders',
#         'new', 'clinton'],
#        dtype='<U18'), array(['marvel', 'coming', 'aren', 'modern', 'jobs', 'day'],
#        dtype='<U18'), array(['doctor', 'agony', 'katasonov', 'valentin', 'america', 'trump'],
#        dtype='<U18'), array(['wants', 'democrats', 'just', 'want', 'bernie'],
#        dtype='<U18'), array(['prep', 'unorthodox', 'inside', 'debate', 'sanders', 'bernie'],
#        dtype='<U18'), array(['institution', 'facebook', 'polarization', 'political'],
#        dtype='<U18'), array(['slogan', 'suggests', 'used', 'clinton', 'racist', 'trump'],
#        dtype='<U18'), array(['doers', 'positive', 'combat', 'heal', 'pools', 'vertical',
#         'happen', 'veterans', 'help', 'make', 'seeks', 'wounded'],
#        dtype='<U18'), array(['gone', 'science', 'far'],
#        dtype='<U18'), array(['impact', 'caucuses', 'massive', 'iowa', 'presidential', 'race'],
#        dtype='<U18'), array(['hints', 'civil', 'warning', 'wins', 'second', 'hillary', 'threat',
#         'war', 'trump'],
#        dtype='<U18'), array(['ringing', 'tanden', 'neera', 'endorsement', 'really', 'wikileaks',
#         'hillary'],
#        dtype='<U18'), array(['hiring', 'attacked', 'benghazi', 'spent', 'americans', 'breaking',
#         'department', 'million', 'state', 'hillary', 'terrorists'],
#        dtype='<U18'), array(['trumpspeak', 'flaws', 'opinion'],
#        dtype='<U18'), array(['54', 'embassy', 'flies', 'cuba', 'flag', 'years', 'time'],
#        dtype='<U18'), array(['mins', '26', 'video', 'bombshell', 'wikileaks', 'election'],
#        dtype='<U18'), array(['hunt', 'continue', 'albert', 'rights', 'gay', 'divide',
#         'republicans'],
#        dtype='<U18'), array(['violates', 'spam', 'lawbreaking', 'airbnb', 'act', 'sends'],
#        dtype='<U18'), array(['125', 'sot', 'different', 'obama', 'hillary', 'trump'],
#        dtype='<U18'), array(['sanford', 'pundits', 'polarization', 'talk', 'tuesday', 'school',
#         'political'],
#        dtype='<U18'), array(['persist', 'disagreements', 'concerns', 'spreading', 'step',
#         'kerry', 'leaders', 'syria', 'world', 'terror', 'end', 'war'],
#        dtype='<U18'), array(['weeks', 'gap', 'closes', 'gravis', 'breitbart', 'tie',
#         'statistical', 'shows', 'latest', 'poll', 'donald', 'left', 'trump'],
#        dtype='<U18'), array(['mistake', 'opinion', 'com', '2016', 'hillary', 'clinton'],
#        dtype='<U18'), array(['going', 'wikileaks'],
#        dtype='<U18'), array(['means', 'recognition', 'enemy', 'francis', 'pope', 'religious',
#         'right', 'really', 'palestine'],
#        dtype='<U18'), array(['boggling', 'mind', 'satellite', 'hole', 'japan', 'took', 'lost',
#         'photo', 'proves', 'black'],
#        dtype='<U18'), array(['ways', 'running', 'donald', 'win', 'trump'],
#        dtype='<U18'), array(['members', 'guard', 'bonuses', 'won', 'pay', 'national',
#         'california'],
#        dtype='<U18'), array(['flocking', 'aren', 'sanders', 'black', 'voters', 'bernie'],
#        dtype='<U18'), array(['resource', 'abridged', 'finally', 'guide', 'november', 'day',
#         'election'],
#        dtype='<U18'), array(['pollster', 'debts', 'deadbeating', 'refusing', 'pay', 'campaign',
#         'trump'],
#        dtype='<U18'), array(['apologizes', 'responsibility', 'mail', 'hillary', 'clinton'],
#        dtype='<U18'), array(['priority', 'qaeda', 'acknowledges', 'government', 'al', 'syria'],
#        dtype='<U18'), array(['backers', 'helmets', 'grey', 'white'],
#        dtype='<U18'), array(['divides', 'chicago', 'street', 'weekend', 'america'],
#        dtype='<U18'), array(['isles', 'disputed', 'stationing', 'troops', 'tokyo', 'ban'],
#        dtype='<U18'), array(['breitbart', 'policy', 'syria', 'world', 'donald', 'lead',
#         'hillary', 'war', 'trump'],
#        dtype='<U18'), array(['truthful', 'checked', 'claim', 'scandal', 'fact', 'email',
#         'clinton'],
#        dtype='<U18'), array(['remain', 'issues', 'tricky', 'kerry', 'talks', 'iran', 'nuclear',
#         'says'],
#        dtype='<U18'), array(['ii', 'lucifer', 'temple', 'dog'],
#        dtype='<U18'), array(['efforts', 'bonus', 'retreats', 'pentagon', 'collection',
#         'enlistment'],
#        dtype='<U18'), array(['lost', 'won', 'clinton', 'trump'],
#        dtype='<U18'), array(['crushed', 'presidency', 'got', 'obama', 'democratic', 'party'],
#        dtype='<U18'), array(['helps', 'rich', 'budget', 'right', 'obama', 'just', 'republican',
#         'says'],
#        dtype='<U18'), array(['affordable', 'repeal', 'act', 'care', 'votes', 'house'],
#        dtype='<U18'), array(['ww', 'iii', 'policy', 'syria', 'lead', 'clinton', 'trump'],
#        dtype='<U18'), array(['perfection', 'parable', 'sufi', 'christ'],
#        dtype='<U18'), ...]

# %%
count_test2 = cv.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

nb3 = MultinomialNB()

nb3.fit(count_train2, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print ("Classification rate for NB- Model 3 (Train):", round(nb3.score(count_train2, y_train),4)*100,"%")
print ("Classification rate for NB- Model 3 (Test):", round(nb3.score(count_test2, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 3 (Train): 94.34 %
# Classification rate for NB- Model 3 (Test): 79.72 %

# %% [markdown]
# Applying count vectorization on the title only performed much worse than on the text only.

# %% [markdown]
# ### Model 4: TFID Vectorizer- Title only

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tv = TfidfVectorizer(stop_words='english')

tfid_train2 = tv.fit_transform(X_train)

# %%
tfid_test2 = cv.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

nb4 = MultinomialNB()

nb4.fit(tfid_train2, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print ("Classification rate for NB- Model 2 (Train):", round(nb4.score(tfid_train2, y_train),4)*100,"%")
print ("Classification rate for NB- Model 2 (Test):", round(nb4.score(tfid_test2, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 2 (Train): 95.15 %
# Classification rate for NB- Model 2 (Test): 79.96 %

# %% [markdown]
# ### Model 5: Count vectorizer- Title and text

# %%
X = realOrFake.loc[:, :'text']

# %%
print(X.shape)
print(y.shape)
# Out:
# (6335, 2)
# (6335,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=53)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (4244, 2)
# (4244,)

# %%
X_train.head()
# Out:
#                                                   title  \
# 2576  A Reader Refers Us To Englishman Pat Condell O...
# 1539  Do you think there will be as many doom sayers...
# 5163                        Bernie's California endgame
# 2615  They Said What?!: Find Out What Liam Neeson, L...
# 4270           Wells Fargo is Rotting from the Top Down
#
#                                                    text
# 2576
# 1539  Report Copyright Violation Do you think there ...
# 5163  The election in 232 photos, 43 numbers and 131...
# 2615  Email Ever wonder what’s on the mind of today’...
# 4270  Wells Fargo is Rotting from the Top Down Wells...

# %%
## addressing the two y columns 
import scipy.sparse as sp

title_vectorizer = CountVectorizer(stop_words='english')
title_vectors = title_vectorizer.fit_transform(X_train['title'])
title_test = title_vectorizer.transform(X_test['title'])

text_vectorizer = CountVectorizer(stop_words='english')
text_vectors = text_vectorizer.fit_transform(X_train['text'])
text_test = text_vectorizer.transform(X_test['text'])

combined_train = sp.hstack([title_vectors, text_vectors], format='csr')
combined_test = sp.hstack([title_test, text_test], format='csr')

# %%
print(combined_train.shape)
print(combined_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4244, 64881)
# (2091, 64881)
# (4244,)
# (2091,)

# %%
from sklearn.naive_bayes import MultinomialNB

nb5 = MultinomialNB()

nb5.fit(combined_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
## Best performance on training set so far
print ("Classification rate for NB- Model 5 (Train):", round(nb5.score(combined_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 5 (Test):", round(nb5.score(combined_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 5 (Train): 95.26 %
# Classification rate for NB- Model 5 (Test): 89.72 %

# %% [markdown]
# #### Bernoulli Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

nb5b = BernoulliNB()

nb5b.fit(combined_train, y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
## Did not perform better
print ("Classification rate for NB- Model 5 w Bernoulli (Train):", round(nb5b.score(combined_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 5 w Bernoulli (Test):", round(nb5b.score(combined_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 5 w Bernoulli (Train): 88.83 %
# Classification rate for NB- Model 5 w Bernoulli (Test): 83.36 %

# %% [markdown]
# ### Model 6: TFID vectorizer- Title and text

# %%
## addressing the two y columns 
import scipy.sparse as sp

title_tf_vectorizer = TfidfVectorizer(stop_words='english', max_df=0.7)
title_tf_vectors = title_tf_vectorizer.fit_transform(X_train['title'])
title_tf_test = title_tf_vectorizer.transform(X_test['title'])

text_tf_vectorizer = TfidfVectorizer(stop_words='english')
text_tf_vectors = text_tf_vectorizer.fit_transform(X_train['text'])
text_tf_test = text_tf_vectorizer.transform(X_test['text'])

combined_tf_train = sp.hstack([title_tf_vectors, text_tf_vectors], format='csr')
combined_tf_test = sp.hstack([title_tf_test, text_tf_test], format='csr')

# %%
print(combined_tf_train.shape)
print(combined_tf_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4244, 64881)
# (2091, 64881)
# (4244,)
# (2091,)

# %%
from sklearn.naive_bayes import MultinomialNB

nb6 = MultinomialNB()

nb6.fit(combined_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
## tied for best performance on test set
print ("Classification rate for NB- Model 6 (Train):", round(nb6.score(combined_tf_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 6  (Test):", round(nb6.score(combined_tf_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 6 (Train): 97.38 %
# Classification rate for NB- Model 6  (Test): 89.57 %

# %% [markdown]
# ### Model 7 and 8: Model 5 with new alpha

# %%
## addressing the two y columns 
import scipy.sparse as sp

title_vectorizer = CountVectorizer(stop_words='english')
title_vectors = title_vectorizer.fit_transform(X_train['title'])
title_test = title_vectorizer.transform(X_test['title'])

text_vectorizer = CountVectorizer(stop_words='english')
text_vectors = text_vectorizer.fit_transform(X_train['text'])
text_test = text_vectorizer.transform(X_test['text'])

combined_train = sp.hstack([title_vectors, text_vectors], format='csr')
combined_test = sp.hstack([title_test, text_test], format='csr')

# %%
from sklearn.naive_bayes import MultinomialNB

nb7 = MultinomialNB(alpha=0.50)

nb7.fit(combined_train, y_train)
# Out:
# MultinomialNB(alpha=0.5, class_prior=None, fit_prior=True)

# %%
print ("Classification rate for NB- Model 7 (Train):", round(nb7.score(combined_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 7 (Test):", round(nb7.score(combined_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 7 (Train): 96.02 %
# Classification rate for NB- Model 7 (Test): 90.1 %

# %%
from sklearn.naive_bayes import MultinomialNB

nb8 = MultinomialNB(alpha=0.10)

nb8.fit(combined_train, y_train)
# Out:
# MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True)

# %%
## best performance so far!
print ("Classification rate for NB- Model 8 (Train):", round(nb8.score(combined_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 8 (Test):", round(nb8.score(combined_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 8 (Train): 97.27 %
# Classification rate for NB- Model 8 (Test): 90.2 %

# %% [markdown]
# ### Model 9 and 10: Model 6 with tweaks to TFID Vectorizer

# %%
## using max_df to remove very common words
import scipy.sparse as sp

title_tf_vectorizer = TfidfVectorizer(stop_words='english', max_df=0.8)
title_tf_vectors = title_tf_vectorizer.fit_transform(X_train['title'])
title_tf_test = title_tf_vectorizer.transform(X_test['title'])

text_tf_vectorizer = TfidfVectorizer(stop_words='english', max_df=0.8)
text_tf_vectors = text_tf_vectorizer.fit_transform(X_train['text'])
text_tf_test = text_tf_vectorizer.transform(X_test['text'])

combined_tf_train = sp.hstack([title_tf_vectors, text_tf_vectors], format='csr')
combined_tf_test = sp.hstack([title_tf_test, text_tf_test], format='csr')

# %%
from sklearn.naive_bayes import MultinomialNB

nb9 = MultinomialNB()

nb9.fit(combined_tf_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
## this hurts performance a lot
print ("Classification rate for NB- Model 9 (Train):", round(nb9.score(combined_tf_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 9 (Test):", round(nb9.score(combined_tf_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 9 (Train): 94.89 %
# Classification rate for NB- Model 9 (Test): 88.19 %

# %%
## using min_df to remove uncommon words
import scipy.sparse as sp

title_tf_vectorizer = TfidfVectorizer(stop_words='english', min_df=0.1)
title_tf_vectors = title_tf_vectorizer.fit_transform(X_train['title'])
title_tf_test = title_tf_vectorizer.transform(X_test['title'])

text_tf_vectorizer = TfidfVectorizer(stop_words='english', min_df=0.1)
text_tf_vectors = text_tf_vectorizer.fit_transform(X_train['text'])
text_tf_test = text_tf_vectorizer.transform(X_test['text'])

combined_tf_train = sp.hstack([title_tf_vectors, text_tf_vectors], format='csr')
combined_tf_test = sp.hstack([title_tf_test, text_tf_test], format='csr')

# %%
from sklearn.naive_bayes import MultinomialNB

nb10 = MultinomialNB()

nb10.fit(combined_tf_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
## this hurts performance a lot
print ("Classification rate for NB- Model 10 (Train):", round(nb10.score(combined_tf_train, y_train),4)*100,"%")
print ("Classification rate for NB- Model 10 (Test):", round(nb10.score(combined_tf_test, y_test),4)*100,"%")
# Out:
# Classification rate for NB- Model 10 (Train): 84.52 %
# Classification rate for NB- Model 10 (Test): 82.54 %

# %% [markdown]
# ### Best outcome: Model 8- CountVectorizer with alpha of .01
